# %%
import json
import requests
from cobra.io.sbml import *
import pandas as pd

#############################################################################
#  Confidence Scores for rxns in generic model ##############################
#############################################################################

# read model
model = read_sbml_model('dataset/Recon2.2_formatted.xml')
print('Human Model is imported ... ')
# Out:
# CPLEX is available but could not load with error:
#   Traceback (most recent call last):
#     File "C:\Users\nadia\AppData\Roaming\Python\Python37\site-packages\optlang\__init__.py", line 43, in <module>
#       from optlang import cplex_interface
#     File "C:\Users\nadia\AppData\Roaming\Python\Python37\site-packages\optlang\cplex_interface.py", line 33, in <module>
#       from cplex.exceptions import CplexSolverError
#   ModuleNotFoundError: No module named 'cplex.exceptions'
# Human Model is imported ...

# %%
# format reaction names in Recon2
for idx,g in enumerate(model.reactions):
    if g.id == 'EX_3aib_D_e':
        model.reactions[idx].id = 'EX_3aib__D_e'
    if g.id.startswith('EX_') and g.id.endswith('_b'):
        new_id = g.id.replace(g.id[-2:],'_e')
        model.reactions[idx].id = new_id

# %%
print([i.id for i in model.reactions])
# Out:
# ['EX_10fthf_e', 'EX_11_cis_retfa_e', 'EX_13_cis_oretn_e', 'EX_13_cis_retn_e', 'EX_13_cis_retnglc_e', 'EX_1a25dhvitd3_e', 'EX_1glyc_hs_e', 'EX_1mncam_e', 'EX_23cump_e', 'EX_2425dhvitd2_e', 'EX_2425dhvitd3_e', 'EX_24nph_e', 'EX_25hvitd2_e', 'EX_25hvitd3_e', 'EX_2hb_e', 'EX_2mcit_e', 'EX_34dhoxpeg_e', 'EX_34dhphe_e', 'EX_34hpp_e', 'EX_35cgmp_e', 'EX_3aib_D_e', 'EX_3aib_e', 'EX_3bcrn_e', 'EX_3ddcrn_e', 'EX_3deccrn_e', 'EX_3hdececrn_e', 'EX_3hexdcrn_e', 'EX_3ivcrn_e', 'EX_3mlda_e', 'EX_3mob_e', 'EX_3mop_e', 'EX_3octdec2crn_e', 'EX_3octdeccrn_e', 'EX_3octdece1crn_e', 'EX_3tdcrn_e', 'EX_3tetd7ecoacrn_e', 'EX_3thexddcoacrn_e', 'EX_3ttetddcoacrn_e', 'EX_3ump_e', 'EX_4abut_e', 'EX_4abutn_e', 'EX_4hdebrisoquine_e', 'EX_4hphac_e', 'EX_4hpro_LT_e', 'EX_4mop_e', 'EX_4mptnl_e', 'EX_4mtolbutamide_e', 'EX_4nph_e', 'EX_4nphsf_e', 'EX_4pyrdx_e', 'EX_5HPET_e', 'EX_5adtststerone_e', 'EX_5adtststeroneglc_e', 'EX_5fthf_e', 'EX_5homeprazole_e', 'EX_5htrp_e', 'EX_5mta_e', 'EX_5mthf_e', 'EX_5oxpro_e', 'EX_6htststerone_e', 'EX_9_cis_retfa_e', 'EX_Asn_X_Ser_Thr_e', 'EX_C02470_e', 'EX_C02528_e', 'EX_C04849_e', 'EX_12HPET_e', 'EX_CE0074_e', 'EX_CE1940_e', 'EX_CE1950_e', 'EX_CE2011_e', 'EX_CE2250_e', 'EX_CE2838_e', 'EX_CE2839_e', 'EX_CE4633_e', 'EX_CE4881_e', 'EX_CE5797_e', 'EX_CE5798_e', 'EX_HC00229_e', 'EX_HC00250_e', 'EX_HC00342_e', 'EX_HC00822_e', 'EX_HC00955_e', 'EX_HC01104_e', 'EX_HC01361_e', 'EX_HC01440_e', 'EX_HC01441_e', 'EX_HC01444_e', 'EX_HC01446_e', 'EX_HC01577_e', 'EX_HC01609_e', 'EX_HC01610_e', 'EX_HC01700_e', 'EX_HC01787_e', 'EX_HC02154_e', 'EX_HC02160_e', 'EX_HC02161_e', 'EX_HC02172_e', 'EX_ddca_e', 'EX_wharachd_e', 'EX_HC02180_e', 'EX_HC02187_e', 'EX_HC02191_e', 'EX_HC02192_e', 'EX_CE5560_e', 'EX_HC02194_e', 'EX_HC02195_e', 'EX_HC02196_e', 'EX_HC02197_e', 'EX_HC02198_e', 'EX_HC02199_e', 'EX_HC02200_e', 'EX_HC02201_e', 'EX_HC02202_e', 'EX_HC02203_e', 'EX_HC02204_e', 'EX_HC02205_e', 'EX_HC02206_e', 'EX_HC02207_e', 'EX_HC02208_e', 'EX_HC02210_e', 'EX_HC02213_e', 'EX_HC02214_e', 'EX_HC02216_e', 'EX_HC02217_e', 'EX_HC02220_e', 'EX_Lcystin_e', 'EX_Rtotal_e', 'EX_Ser_Gly_Ala_X_Gly_e', 'EX_Ser_Thr_e', 'EX_T_antigen_e', 'EX_Tyr_ggn_e', 'EX_abt_e', 'EX_ac_e', 'EX_acac_e', 'EX_acald_e', 'EX_acetone_e', 'EX_acgalfucgalacgalfuc12gal14acglcgalgluside_hs_e', 'EX_acgalfucgalacgalfucgalacglcgal14acglcgalgluside_hs_e', 'EX_acgam_e', 'EX_ach_e', 'EX_acmana_e', 'EX_ade_e', 'EX_adn_e', 'EX_adocbl_e', 'EX_adp_e', 'EX_adprbp_e', 'EX_adprib_e', 'EX_adrn_e', 'EX_adrnl_e', 'EX_aflatoxin_e', 'EX_ahandrostanglc_e', 'EX_ahcys_e', 'EX_ahdt_e', 'EX_aicar_e', 'EX_ak2lgchol_hs_e', 'EX_akg_e', 'EX_ala_B_e', 'EX_ala_D_e', 'EX_ala_L_e', 'EX_alaala_e', 'EX_aldstrn_e', 'EX_amp_e', 'EX_andrstrn_e', 'EX_andrstrnglc_e', 'EX_anth_e', 'EX_antipyrene_e', 'EX_apnnox_e', 'EX_appnn_e', 'EX_aprgstrn_e', 'EX_aqcobal_e', 'EX_arab_L_e', 'EX_arach_e', 'EX_arachcoa_e', 'EX_arachd_e', 'EX_arg_L_e', 'EX_ascb_L_e', 'EX_asn_L_e', 'EX_asp_D_e', 'EX_asp_L_e', 'EX_atp_e', 'EX_avite1_e', 'EX_avite2_e', 'EX_eglc_e', 'EX_ehb_e', 'EX_eildglcur_e', 'EX_eilglcur_e', 'EX_eilirub_e', 'EX_eiocyt_e', 'EX_biomass_c', 'EX_etn_e', 'EX_eut_e', 'EX_evite_e', 'EX_ez_e', 'EX_c101crn_e', 'EX_c10crn_e', 'EX_c4crn_e', 'EX_c51crn_e', 'EX_c5dc_e', 'EX_c6crn_e', 'EX_c81coa_e', 'EX_c81crn_e', 'EX_c8crn_e', 'EX_ca2_e', 'EX_camp_e', 'EX_carn_e', 'EX_caro_e', 'EX_carveol_e', 'EX_cbasp_e', 'EX_cdp_e', 'EX_cdpea_e', 'EX_cgly_e', 'EX_chol_e', 'EX_cholate_e', 'EX_chsterol_e', 'EX_chtn_e', 'EX_cit_e', 'EX_citr_L_e', 'EX_cl_e', 'EX_clpnd_e', 'EX_cmp_e', 'EX_co2_e', 'EX_co_e', 'EX_coa_e', 'EX_core5_e', 'EX_core7_e', 'EX_core8_e', 'EX_coumarin_e', 'EX_creat_e', 'EX_crm_hs_e', 'EX_crmp_hs_e', 'EX_crn_e', 'EX_crtsl_e', 'EX_crtstrn_e', 'EX_crvnc_e', 'EX_csn_e', 'EX_ctp_e', 'EX_cyan_e', 'EX_cynt_e', 'EX_cys_L_e', 'EX_cysam_e', 'EX_cytd_e', 'EX_dad_2_e', 'EX_dag_hs_e', 'EX_datp_e', 'EX_dca_e', 'EX_dchac_e', 'EX_dcmp_e', 'EX_dcsptn1_e', 'EX_dctp_e', 'EX_dcyt_e', 'EX_dd2coa_e', 'EX_ddeccrn_e', 'EX_ddece1crn_e', 'EX_debrisoquine_e', 'EX_decd ...

# %%
# define null, true and false to avoid "NameError: name 'null' is not defined"
null = None
true = True
false = False

# store conf. scores for generic model's reactions, value is None if no conf.score is assigned
confidence_scores = {}

print('Starting database calls ...')
c=0
for idx,r in enumerate(model.reactions):
    print('Reaction ID:', r.id)
    try:
        # make a get request to BiGG models
        # bigg_response = requests.get(
        #     "http://bigg.ucsd.edu/api/v2/models/Recon3D/reactions/" + r.id)
        # bigg_json = bigg_response.content.decode("utf-8")
        # data = json.loads(bigg_json)
        # # store respective old identifier
        # old_id = data["old_identifiers"]

        bigg_response = requests.get("http://bigg.ucsd.edu/api/v2/universal/reactions/" + r.id)
        bigg_json = bigg_response.content.decode("utf-8")
        info = json.loads(bigg_json)
        # print('info:',info)
        old_id = info["old_identifiers"]

        for i in old_id:
            # call reaction from VMH using the respective old identifier
            vmh_res = requests.get(
                "https://www.vmh.life/_api/reactions/?abbreviation=" + i)

            vmh_json = vmh_res.content.decode("utf-8")
            vmh_confidence = json.loads(vmh_json)
            score = 0
            if vmh_res.status_code == 200 and len(vmh_confidence['results']):
                #print(vmh_res.status_code)

                # replace None to 0
                if vmh_confidence['results'][0]['mcs'] is None:
                    vmh_confidence['results'][0]['mcs'] = 0

                if r.id in list(confidence_scores.keys()):
                    print('ALREADY IN', r.id)

                # store confidence scores to the corresponding 'initial' identifier (found in BiGG model)
                score = vmh_confidence['results'][0]['mcs']
                #print('Confidence scores:',vmh_confidence['results'][0]['mcs'],i)
                break
          
        print(r.id, 'successfull')
        confidence_scores[r.id] = score
        c+=1

    except:
        confidence_scores[r.id] = 500
        print('rxn [%s] not found' % r.id)
        c+=1
    
    print('-------------------')

print('Database calls are done ...')

print('Dictionary with confidence scores:', confidence_scores)
print('c',c)
# Out:
# Starting database calls ...
# Reaction ID: EX_10fthf_e
# Confidence scores: 0 EX_10fthf[e]
# EX_10fthf_e successfull
# Reaction ID: EX_11_cis_retfa_e
# Confidence scores: 0 EX_11_cis_retfa[e]
# EX_11_cis_retfa_e successfull
# Reaction ID: EX_13_cis_oretn_e
# rxn [EX_13_cis_oretn_e] not found
# -------------------
# Reaction ID: EX_13_cis_retn_e
# Confidence scores: 0 EX_13_cis_retn[e]
# EX_13_cis_retn_e successfull
# Reaction ID: EX_13_cis_retnglc_e
# Confidence scores: 0 EX_13_cis_retnglc[e]
# EX_13_cis_retnglc_e successfull
# Reaction ID: EX_1a25dhvitd3_e
# Confidence scores: 0 EX_1a25dhvitd3[e]
# EX_1a25dhvitd3_e successfull
# Reaction ID: EX_1glyc_hs_e
# Confidence scores: 0 EX_1glyc_hs[e]
# EX_1glyc_hs_e successfull
# Reaction ID: EX_1mncam_e
# Confidence scores: 0 EX_1mncam[e]
# EX_1mncam_e successfull
# Reaction ID: EX_23cump_e
# Confidence scores: 0 EX_23cump[e]
# EX_23cump_e successfull
# Reaction ID: EX_2425dhvitd2_e
# Confidence scores: 0 EX_2425dhvitd2[e]
# EX_2425dhvitd2_e successfull
# Reaction ID: EX_2425dhvitd3_e
# Confidence scores: 0 EX_2425dhvitd3[e]
# EX_2425dhvitd3_e successfull
# Reaction ID: EX_24nph_e
# Confidence scores: 0 EX_24nph[e]
# EX_24nph_e successfull
# Reaction ID: EX_25hvitd2_e
# Confidence scores: 0 EX_25hvitd2[e]
# EX_25hvitd2_e successfull
# Reaction ID: EX_25hvitd3_e
# Confidence scores: 0 EX_25hvitd3[e]
# EX_25hvitd3_e successfull
# Reaction ID: EX_2hb_e
# Confidence scores: 0 EX_2hb[e]
# EX_2hb_e successfull
# Reaction ID: EX_2mcit_e
# Confidence scores: 0 EX_2mcit[e]
# EX_2mcit_e successfull
# Reaction ID: EX_34dhoxpeg_e
# Confidence scores: 0 EX_34dhoxpeg[e]
# EX_34dhoxpeg_e successfull
# Reaction ID: EX_34dhphe_e
# Confidence scores: 0 EX_34dhphe[e]
# EX_34dhphe_e successfull
# Reaction ID: EX_34hpp_e
# Confidence scores: 0 EX_34hpp[e]
# EX_34hpp_e successfull
# Reaction ID: EX_35cgmp_e
# Confidence scores: 0 EX_35cgmp[e]
# EX_35cgmp_e successfull
# Reaction ID: EX_3aib_D_e
# rxn [EX_3aib_D_e] not found
# -------------------
# Reaction ID: EX_3aib_e
# Confidence scores: 0 EX_3aib[e]
# EX_3aib_e successfull
# Reaction ID: EX_3bcrn_e
# Confidence scores: 0 EX_3bcrn[e]
# EX_3bcrn_e successfull
# Reaction ID: EX_3ddcrn_e
# Confidence scores: 0 EX_3ddcrn[e]
# EX_3ddcrn_e successfull
# Reaction ID: EX_3deccrn_e
# Confidence scores: 0 EX_3deccrn[e]
# EX_3deccrn_e successfull
# Reaction ID: EX_3hdececrn_e
# Confidence scores: 0 EX_3hdececrn[e]
# EX_3hdececrn_e successfull
# Reaction ID: EX_3hexdcrn_e
# Confidence scores: 0 EX_3hexdcrn[e]
# EX_3hexdcrn_e successfull
# Reaction ID: EX_3ivcrn_e
# Confidence scores: 0 EX_3ivcrn[e]
# EX_3ivcrn_e successfull
# Reaction ID: EX_3mlda_e
# Confidence scores: 0 EX_3mlda[e]
# EX_3mlda_e successfull
# Reaction ID: EX_3mob_e
# Confidence scores: 0 EX_3mob[e]
# EX_3mob_e successfull
# Reaction ID: EX_3mop_e
# Confidence scores: 0 EX_3mop[e]
# EX_3mop_e successfull
# Reaction ID: EX_3octdec2crn_e
# Confidence scores: 0 EX_3octdec2crn[e]
# EX_3octdec2crn_e successfull
# Reaction ID: EX_3octdeccrn_e
# Confidence scores: 0 EX_3octdeccrn[e]
# EX_3octdeccrn_e successfull
# Reaction ID: EX_3octdece1crn_e
# Confidence scores: 0 EX_3octdece1crn[e]
# EX_3octdece1crn_e successfull
# Reaction ID: EX_3tdcrn_e
# Confidence scores: 0 EX_3tdcrn[e]
# EX_3tdcrn_e successfull
# Reaction ID: EX_3tetd7ecoacrn_e
# Confidence scores: 0 EX_3tetd7ecoacrn[e]
# EX_3tetd7ecoacrn_e successfull
# Reaction ID: EX_3thexddcoacrn_e
# Confidence scores: 0 EX_3thexddcoacrn[e]
# EX_3thexddcoacrn_e successfull
# Reaction ID: EX_3ttetddcoacrn_e
# Confidence scores: 0 EX_3ttetddcoacrn[e]
# EX_3ttetddcoacrn_e successfull
# Reaction ID: EX_3ump_e
# Confidence scores: 0 EX_3ump[e]
# EX_3ump_e successfull
# Reaction ID: EX_4abut_e
# Confidence scores: 0 EX_4abut[e]
# EX_4abut_e successfull
# Reaction ID: EX_4abutn_e
# Confidence scores: 0 EX_4abutn[e]
# EX_4abutn_e successfull
# Reaction ID: EX_4hdebrisoquine_e
# Confidence scores: 0 EX_4hdebrisoquine[e]
# EX_4hdebrisoquine_e successfull
# Reaction ID: EX_4hphac_e
# Confidence scores: 0 EX_4hphac[e]
# EX_4hphac_e successfull
# Reaction ID: EX_4hpro_LT_e
# Confidence scores: 0 EX_4hpro[e]
# EX_4hpro_LT_e successfull
# Reaction ID: EX_4mop_e
# Confidence scores: 0 EX_4mop[e]
# EX_4mop_e successfull
# Reaction ID: EX_4mptnl_e
# Confidence scores: 0 EX_4mptnl[e]
# EX_4mptnl_e successfull
# Reaction ID: EX_4mtolbutamide_e
# Confidence scores: 0 EX_4mtolbutamide[e]
# EX_4mtolbutamide_e successfull
# Reaction ID: EX_4nph_e
# Confidence scores: 0 EX_4nph[e]
# EX_4nph_e successfull
# Reaction ID: EX_4nphsf_e
# Confidence scores: 0 EX_4nphsf[e]
# EX_4nphsf_e successfull
# Reaction ID: EX_4pyrdx_e
# Confidence scores: 0 EX_4pyrdx[e]
# EX_4pyrdx_e successfull
# Reaction ID: EX_5HPET_e
# Confidence scores: 0 EX_5HPET[e]
# EX_5HPET_e successfull
# Reaction ID: EX_5adtststerone_e
# Confidence scores: 0 EX_5adtststerone[e]
# EX_5adtststerone_e successfull
# Reaction ID: EX_5adtststeroneglc_e
# Confidence scores: 0 EX_5adtststeroneglc[e]
# EX_5adtststeroneglc_e successfull
# Reaction ID: EX_5fthf_e
# Confidence scores: 0 EX_5fthf[e]
# EX_5fthf_e successfull
# Reaction ID: EX_5homeprazole_e
# Confidence scores: 0 EX_5homeprazole[e]
# EX_5homeprazole_e successfull
# Reaction ID: EX_5htrp_e
# Confidence scores: 0 EX_5htrp[e]
# EX_5htrp_e successfull
# Reaction ID: EX_5mta_e
# Confidence scores: 0 EX_5mta[e]
# EX_5mta_e successfull
# Reaction ID: EX_5mthf_e
# Confidence scores: 0 EX_5mthf[e]
# EX_5mthf_e successfull
# Reaction ID: EX_5oxpro_e
# Confidence scores: 0 EX_5oxpro[e]
# EX_5oxpro_e successfull
# Reaction ID: EX_6htststerone_e
# Confidence scores: 0 EX_6htststerone[e]
# EX_6htststerone_e successfull
# Reaction ID: EX_9_cis_retfa_e
# Confidence scores: 0 EX_9_cis_retfa[e]
# EX_9_cis_retfa_e successfull
# Reaction ID: EX_Asn_X_Ser_Thr_e
# rxn [EX_Asn_X_Ser_Thr_e] not found
# -------------------
# Reaction ID: EX_C02470_e
# Confidence scores: 0 EX_C02470[e]
# EX_C02470_e successfull
# Reaction ID: EX_C02528_e
# Confidence scores: 0 EX_C02528[e]
# EX_C02528_e successfull
# Reaction ID: EX_C04849_e
# Confidence scores: 0 EX_C04849[e]
# EX_C04849_e successfull
# Reaction ID: EX_12HPET_e
# Confidence scores: 0 EX_12HPET[e]
# EX_12HPET_e successfull
# Reaction ID: EX_CE0074_e
# Confidence scores: 0 EX_CE0074[e]
# EX_CE0074_e successfull
# Reaction ID: EX_CE1940_e
# Confidence scores: 0 EX_CE1940[e]
# EX_CE1940_e successfull
# Reaction ID: EX_CE1950_e
# Confidence scores: 0 EX_CE1950[e]
# EX_CE1950_e successfull
# Reaction ID: EX_CE2011_e
# EX_CE2011_e successfull
# Reaction ID: EX_CE2250_e
# Confidence scores: 0 EX_CE2250[e]
# EX_CE2250_e successfull
# Reaction ID: EX_CE2838_e
# Confidence scores: 0 EX_CE2838[e]
# EX_CE2838_e successfull
# Reaction ID: EX_CE2839_e
# Confidence scores: 0 EX_CE2839[e]
# EX_CE2839_e successfull
# Reaction ID: EX_CE4633_e
# Confidence scores: 0 EX_CE4633[e]
# EX_CE4633_e successfull
# Reaction ID: EX_CE4881_e
# Confidence scores: 0 EX_CE4881[e]
# EX_CE4881_e successfull
# Reaction ID: EX_CE5797_e
# Confidence scores: 0 EX_CE5797[e]
# EX_CE5797_e successfull
# Reaction ID: EX_CE5798_e
# Confidence scores: 0 EX_CE5798[e]
# EX_CE5798_e successfull
# Reaction ID: EX_HC00229_e
# EX_HC00229_e successfull
# Reaction ID: EX_HC00250_e
# Confidence scores: 0 EX_HC00250[e]
# EX_HC00250_e successfull
# Reaction ID: EX_HC00342_e
# Confidence scores: 0 EX_HC00342[e]
# EX_HC00342_e successfull
# Reaction ID: EX_HC00822_e
# Confidence scores: 0 EX_HC00822[e]
# EX_HC00822_e successfull
# Reaction ID: EX_HC00955_e
# Confidence scores: 0 EX_HC00955[e]
# EX_HC00955_e successfull
# Reaction ID: EX_HC01104_e
# Confidence scores: 0 EX_HC01104[e]
# EX_HC01104_e successfull
# Reaction ID: EX_HC01361_e
# Confidence scores: 0 EX_HC01361[e]
# EX_HC01361_e successfull
# Reaction ID: EX_HC01440_e
# Confidence scores: 0 EX_HC01440[e]
# EX_HC01440_e successfull
# Reaction ID: EX_HC01441_e
# Confidence scores: 0 EX_HC01441[e]
# EX_HC01441_e successfull
# Reaction ID: EX_HC01444_e
# Confidence scores: 0 EX_HC01444[e]
# EX_HC01444_e successfull
# Reaction ID: EX_HC01446_e
# Confidence scores: 0 EX_HC01446[e]
# EX_HC01446_e successfull
# Reaction ID: EX_HC01577_e
# Confidence scores: 0 EX_HC01577[e]
# EX_HC01577_e successfull
# Reaction ID: EX_HC01609_e
# Confidence scores: 0 EX_HC01609[e]
# EX_HC01609_e successfull
# Reaction ID: EX_HC01610_e
# rxn [EX_HC01610_e] not found
# -------------------
# Reaction ID: EX_HC01700_e
# Confidence scores: 0 EX_HC01700[e]
# EX_HC01700_e successfull
# Reaction ID: EX_HC01787_e
# EX_HC01787_e successfull
# Reaction ID: EX_HC02154_e
# EX_HC02154_e successfull
# Reaction ID: EX_HC02160_e
# Confidence scores: 0 EX_HC02160[e]
# EX_HC02160_e successfull
# Reaction ID: EX_HC02161_e
# Confidence scores: 0 EX_HC02161[e]
# EX_HC02161_e successfull
# Reaction ID: EX_HC02172_e
# EX_HC02172_e successfull
# Reaction ID: EX_ddca_e
# Confidence scores: 0 EX_ddca[e]
# EX_ddca_e successfull
# Reaction ID: EX_wharachd_e
# Confidence scores: 0 EX_wharachd[e]
# EX_wharachd_e successfull
# Reaction ID: EX_HC02180_e
# Confidence scores: 0 EX_HC02180[e]
# EX_HC02180_e successfull
# Reaction ID: EX_HC02187_e
# Confidence scores: 0 EX_HC02187[e]
# EX_HC02187_e successfull
# Reaction ID: EX_HC02191_e
# Confidence scores: 0 EX_HC02191[e]
# EX_HC02191_e successfull
# Reaction ID: EX_HC02192_e
# Confidence scores: 0 EX_HC02192[e]
# EX_HC02192_e successfull
# Reaction ID: EX_CE5560_e
# rxn [EX_CE5560_e] not found
# -------------------
# Reaction ID: EX_HC02194_e
# Confidence scores: 1 EX_HC02194[e]
# EX_HC02194_e successfull
# Reaction ID: EX_HC02195_e
# Confidence scores: 0 EX_HC02195[e]
# EX_HC02195_e successfull
# Reaction ID: EX_HC02196_e
# Confidence scores: 0 EX_HC02196[e]
# EX_HC02196_e successfull
# Reaction ID: EX_HC02197_e
# Confidence scores: 0 EX_HC02197[e]
# EX_HC02197_e successfull
# Reaction ID: EX_HC02198_e
# Confidence scores: 0 EX_HC02198[e]
# EX_HC02198_e successfull
# Reaction ID: EX_HC02199_e
# EX_HC02199_e successfull
# Reaction ID: EX_HC02200_e
# EX_HC02200_e successfull
# Reaction ID: EX_HC02201_e
# EX_HC02201_e successfull
# Reaction ID: EX_HC02202_e
# Confidence scores: 0 EX_HC02202[e]
# EX_HC02202_e successfull
# Reaction ID: EX_HC02203_e
# Confidence scores: 0 EX_HC02203[e]
# EX_HC02203_e successfull
# Reaction ID: EX_HC02204_e
# Confidence scores: 0 EX_HC02204[e]
# EX_HC02204_e successfull
# Reaction ID: EX_HC02205_e
