# %%
__author__ = "Nantia Leonidou"
__description__ = " Main script "
########################################
# copied from run_mcadre.py
########################################

import numpy as np
from test_Inputs.test_Inputs import *
import pandas as pd

# read model
model = io.read_sbml_model('../pre_processing/dataset/Recon3D.xml')
# genes
G = pd.read_csv('../pre_processing/dataset/1_GPL570_GSE3397/1_GPL570_GSE3397_entrez_ids.csv')
G = list(G['ENTREZ_GENE_ID'])
# ubiquity scores
U = pd.read_csv('../pre_processing/dataset/1_GPL570_GSE3397/1_GPL570_GSE3397_ubiquity.csv', header=None)
U = U.rename(columns={0: "Scores"})
U = list(U['Scores'])
#confidence_scores 
confidence_scores = pd.read_csv('../pre_processing/dataset/Recon3D_confidence_scores.csv')
confidence_scores = np.float64(list(confidence_scores['Confidence Score']))

# %%
from rank.rank_reactions import *
t0 = process_time()
GM, C, NC, P, Z, model_C = rank_reactions(model, G, U, confidence_scores, [], 2)
t_stop = process_time()
# compute elapsed time
pruneTime = t_stop - t0
# Out:
# /Users/leonidou/Documents/mCADRE_PYTHON_code/code/rank/calc_expr_evidence.py:34 RuntimeWarning: All-NaN axis encountered
# /Users/leonidou/Documents/mCADRE_PYTHON_code/code/rank/calc_expr_evidence.py:58 RuntimeWarning: All-NaN axis encountered
# Checking all reactions (FASTCC)...
# Model consists of 126 blocked (inactive) reactions
# Execution time of check_model_consistency:  34.66294099999999
# check_model_consistency done ...
# /Users/leonidou/Documents/mCADRE_PYTHON_code/code/rank/calc_conn_evidence.py:41 RuntimeWarning: invalid value encountered in true_divide
# rank_reactions done ...

# %%
len(GM.reactions)
# Out:
# 10474

# %%
len(GM.metabolites)
# Out:
# 5833

# %%
len(GM.genes)
# Out:
# 2248

# %%
len(C)
# Out:
# 3485

# %%
len(NC)
# Out:
# 6989

# %%
len(Z)
# Out:
# 1778

# %%
len(model_C)
# Out:
# 3495

# %%
from prune.prune_model import *
print('Generic model passed precursor metabolites test')

##############################################################
# If generic functionality test is passed, prune reactions
###############################################################
print('Pruning reactions...')
t0 = process_time()
PM, cRes = prune_model(GM, P, C, Z, 1/3, '../pre_processing/dataset/key_metabolites_RECON1.txt', 1, 2)
# Stop the stopwatch / counter
t_stop = process_time()
# compute elapsed time
pruneTime = t_stop - t0
# Out:
# Generic model passed precursor metabolites test
# Pruning reactions...
# Reaction no.  1
# Attempting to remove reaction:  DCT ...
# Initial PM reactions: 10474
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 62 blocked (inactive) reactions
# Execution time of check_model_consistency:  30.485123000000385
# check_model_consistency done ...
# Lengths all--> inactive_G: 63 , inactive_C: ['ADRNCRNt', 'HMR_0167', 'CLPNDCRNt', 'r1645', 'r1609', 'RE0453N', 'UDPGLCAter', 'CERT2rt', 'C180CRNt'], inactive_NC:['r0960', 'ELAIDt', 'IBUPGLUCtchep', 'EX_ha_pre1_e', 'EX_hyptaur_e', 'EX_phllqne_e', 'DTTPtn', 'FATP4t', 'EX_ahdt_e', 'PRISTCOAtx', 'PSt3', 'NRVNCt', 'DRIBt', 'EX_aact_e', 'DNADtn', 'EX_drib_e', 'DM_melanin_c', 'EX_pan4p_e', 'EX_M02053_e', 'r2444', 'EX_doco13ac_e', 'TYMte', 'O2tn', 'EX_M00265_e', 'SK_phyQ_c', 'PA_HSter', 'LGNCt', 'EX_ptth_e', 'HMR_0182', 'UMPK3n', 'EX_strdnc_e', 'AACTte', 'DM_CE1562_c', 'CYTK9n', 'HDCECRNtr', 'EX_ha_e', 'T4HCINNMtm', 'G5SADrm', 'EX_10fthf5glu_e', 'r0707', '13DMTtep', 'r1459', 'DCT', 'EX_s2l2n2m2masn_e', 'EX_cysam_e', 'TTDCAtr', 'F1Ate2', 'HMR_9179', 'RE3201C', 'TYRASE', 'EX_cspg_e_e', 'HMR_1701', 'EX_CE1935_e', 'SRTNt6_2_r']
# Zero-expression evidence for reaction...
# 10474
# 10474
# check_model_function done ....
# PM reactions (before): 10474
# Removed all inactive reactions
# PM reactions (after): 10411
# Num. removed: 63 (9 core, 54 non-core); Num. remaining: 6935
# Reaction no.  2
# Attempting to remove reaction:  APRGSTRNt1e ...
# Initial PM reactions: 10411
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 35 blocked (inactive) reactions
# Execution time of check_model_consistency:  30.607742000000144
# check_model_consistency done ...
# Lengths all--> inactive_G: 36 , inactive_C: ['NDPK7n', 'r1661', 'HMR_2666', 'DGK1', 'VACCCPT1', 'RNTR2', 'HMR_2661', 'HMR_1532', 'r1617', 'VACCCPT2', 'r1634'], inactive_NC:['APRGSTRNt1e', 'FRDPtc', 'EX_M00260_e', 'EX_5thf_e', 'HMR_1631', 'EX_ldl_hs_e', 'EX_docosac_e', 'EX_hexc_e', 'TMNDNCt', 'EX_udca3s_e', 'ARACHt', 'EX_tcdca3s_e', 'EX_lca3s_e', 'EX_CE1939_e', 'DSPVStev', 'RE3038C', 'CYTK14n', 'EX_clpnd_e', 'EX_gudca3s_e', 'RE3566C', 'MALTt1r', 'DOCOSACTDr', 'C226COAtx', 'EX_dcsptn1_e', 'r0987']
# Zero-expression evidence for reaction...
# 10411
# 10411
# check_model_function done ....
# Len P: 6935
# num_removed 63
# Len P AFTER 6934
# No reactions removed
# result 1.1
# Num. removed: 63 (9 core, 54 non-core); Num. remaining: 6934
# Reaction no.  3
# Attempting to remove reaction:  T4HCINNMte ...
# Initial PM reactions: 10411
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 52 blocked (inactive) reactions
# Execution time of check_model_consistency:  31.47151699999995
# check_model_consistency done ...
# Lengths all--> inactive_G: 53 , inactive_C: ['HMR_2861', 'DCK2n', 'ADK3m', 'HMR_1532'], inactive_NC:['EX_tca3s_e', 'EX_M01207_e', 'HMR_6786', 'T4HCINNMte', 'EX_ca3s_e', 'TRIPVSitr', 'PI4P4Pn', 'EX_T4hcinnm_e', 'EX_M00260_e', 'GCHOLAte', '4CMCOAS', 'EX_5thf_e', 'EX_idl_hs_e', 'HMR_6785', 'HMR_1631', 'EX_tdca3s_e', 'EX_strch2_e', 'EX_hexc_e', 'EX_hpdca_e', 'TMNDNCt', '5ADTSTSTERONEtr', 'PGLYCt', 'EX_gm1b_hs_e', 'EX_udca3s_e', 'EX_tcdca3s_e', 'EX_lca3s_e', 'EX_tripvs_e', 'CE2512te', 'EX_CE1939_e', 'EX_5cysgly34dhphe_e', 'EX_CE1940_e', 'EX_gudca3s_e', 'EX_CE5026_e', '56DHPVStev', 'EX_smv_e', 'RE0926E', 'EX_4hbz_e', 'EX_dcsptn1_e', 'HMR_2862', 'EX_2hatvacid_e', '4HBZte', 'EX_gcdca3s_e', 'SMVitr', 'EX_crvnc_e', 'EX_ga1_hs_e', 'ATVLACThc', 'PAIL4P_HStn', 'EX_2hatvlac_e', 'PI3PP']
# Zero-expression evidence for reaction...
# 10411
# 10411
# check_model_function done ....
# PM reactions (before): 10411
# Removed all inactive reactions
# PM reactions (after): 10358
# Num. removed: 116 (13 core, 103 non-core); Num. remaining: 6885
# Reaction no.  4
# Attempting to remove reaction:  HMR_1761 ...
# Initial PM reactions: 10358
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 73 blocked (inactive) reactions
# Execution time of check_model_consistency:  29.539614999999685
# check_model_consistency done ...
# Lengths all--> inactive_G: 74 , inactive_C: ['HMR_2666', 'PTDCACRNt', 'HMR_2635', 'r1616', 'HMR_0770', '4HOXPACDOX_NADP', 'HPROxm', 'ARGSL', 'DCSPTN1CRNt', 'CHOLtu', 'C204CRNt', 'HPDCACRNt'], inactive_NC:['H2O2tly', 'SERDGLNexR', 'r2332', 'DHEAtr', 'EX_tsul_e', 'CLPNDt', 'r2365', 'G6PDH1er', 'HMR_1751', 'r2362', 'HMR_1743', 'HMR_1747', 'SK_Tyr_ggn_c', 'DGSNt', 'HMR_1749', 'EX_HC00005_e', 'r2510', 'ALAALACNc', 'CHSTEROLt3', 'EX_arach_e', 'FRDPtcr', 'r2360', 'LNLCt', 'HMR_1761', 'HMR_1759', 'EX_pglyc_hs_e', '10FTHFtm', 'PE_HSter', 'EX_C14825_e', 'RE2349C', 'EX_normete__L_e', 'HMR_1756', 'EX_hexdiac_e', 'HMR_1745', 'CRVNCtr', 'UDPGLCter', 'EX_pe15_hs_e', 'LKYNRtr2', 'SK_btn_c', 'EX_lst4exp_e', 'EX_ldl_hs_e', 'r2342', '3OHGLUTACOAT3t', 'EX_HC02206_e', 'EX_M01197_e', 'HMR_1629', 'RE3017R', 'HMR_1741', 'EX_3ispvs_e', 'RE1447N_1', 'RE3038C', 'r2144', 'HMR_1753', 'PROGLyt', 'RE3076X', 'EX_am1acs_e', 'RPEc', 'RE3050R', 'r0987', 'EX_lnlncg_e', 'TMDOATPtsc', 'LST4EXPitr']
# Zero-expression evidence for reaction...
# 10358
# 10358
# check_model_function done ....
# PM reactions (before): 10358
# Removed all inactive reactions
# PM reactions (after): 10284
# Num. removed: 190 (25 core, 165 non-core); Num. remaining: 6823
# Reaction no.  5
# Attempting to remove reaction:  LEUKTRA4t ...
# Initial PM reactions: 10284
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 22 blocked (inactive) reactions
# Execution time of check_model_consistency:  30.40114100000028
# check_model_consistency done ...
# Lengths all--> inactive_G: 23 , inactive_C: ['r1583', 'r1669', 'HKYNRtr', 'DLNLCGCPT1'], inactive_NC:['LEUKTRA4t', 'EX_peste_hs_e', 'EX_ttdcea_e', 'VD3', 'RSVtev', 'EX_gt1b_hs_e', 'EX_hLkynr_e', 'EX_carn_e', 'PRISTtx', 'TSTSTERONEtr', 'EX_elaidcrn_e', 'EX_glygn5_e', 'EX_6dhf_e', 'EX_5dhf_e', 'EX_M02457_e', 'FVStep', 'EX_dodecanac_e', 'EX_gdca3s_e', 'ADRNt']
# Zero-expression evidence for reaction...
# 10284
# 10284
# check_model_function done ....
# PM reactions (before): 10284
# Removed all inactive reactions
# PM reactions (after): 10261
# Num. removed: 213 (29 core, 184 non-core); Num. remaining: 6804
# Reaction no.  6
# Attempting to remove reaction:  r2353 ...
# Initial PM reactions: 10261
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 24 blocked (inactive) reactions
# Execution time of check_model_consistency:  28.115444000000934
# check_model_consistency done ...
# Lengths all--> inactive_G: 25 , inactive_C: ['C60CPT1', 'CDIPTr', '3MOX4HOXPGALDOX_NADP'], inactive_NC:['r0819', 'XOL27OHtmc', 'r1051', 'EX_M03117_e', 'EX_caribup_s_e', 'HMR_1318', '3HIBUP_Sitr', 'HMR_1620', 'EX_odecrn_e', 'EX_M02108_e', 'EX_acrn_e', 'TXA2te', 'EX_txa2_e', 'EX_gq1b_hs_e', 'PE_HStm', 'SK_HC02198_c', 'EX_M03134_e', 'MALTSULtm', 'r2353', 'EX_7dhchsterol_e', 'CARIBUP_Sthv', 'XOL27OHtm']
# Zero-expression evidence for reaction...
# 10261
# 10261
# check_model_function done ....
# PM reactions (before): 10261
# Removed all inactive reactions
# PM reactions (after): 10236
# Num. removed: 238 (32 core, 206 non-core); Num. remaining: 6782
# Reaction no.  7
# Attempting to remove reaction:  LEUKTRE4t ...
# Initial PM reactions: 10236
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 19 blocked (inactive) reactions
# Execution time of check_model_consistency:  28.70700500000021
# check_model_consistency done ...
# Lengths all--> inactive_G: 20 , inactive_C: ['TTDCRNt', 'VACCCPT1', 'HMR_2661', 'VACCCPT2', 'STRDNCCRNt'], inactive_NC:['CYTK7n', 'APAT2rm', 'DACT', 'EX_prostgi2_e', 'CYTK5n', 'LSTNM7TDhc', 'EX_docosac_e', '34HPLte', 'r2507', 'EX_gm1_hs_e', 'EX_34hpl_e', 'LEUKTRE4t', 'RE2814R', 'SK_vitd3_c', 'BALAtmr']
# Zero-expression evidence for reaction...
# 10236
# 10236
# check_model_function done ....
# PM reactions (before): 10236
# Removed all inactive reactions
# PM reactions (after): 10216
# Num. removed: 258 (37 core, 221 non-core); Num. remaining: 6767
# Reaction no.  8
# Attempting to remove reaction:  HMR_1760 ...
# Initial PM reactions: 10216
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 23 blocked (inactive) reactions
# Execution time of check_model_consistency:  29.893498999999792
# check_model_consistency done ...
# Lengths all--> inactive_G: 24 , inactive_C: ['DCK1n'], inactive_NC:['EX_M00010_e', 'HMR_1740', 'HMR_1738', 'HMR_1752', 'CYTK14n', 'HMR_1742', 'HMR_1744', 'r2508', 'EX_tudca3s_e', 'MALTt1r', 'HMR_1754', 'CYTK12n', 'EX_adrnl_e', 'DOCOSACTDr', 'HMR_1758', 'HMR_1739', 'EX_sphmyln_hs_e', 'HMR_1750', 'HMR_1748', 'EX_M02451_e', 'EX_tdechola_e', 'HMR_1760', 'HMR_1746']
# Zero-expression evidence for reaction...
# 10216
# 10216
# check_model_function done ....
# PM reactions (before): 10216
# Removed all inactive reactions
# PM reactions (after): 10192
# Num. removed: 282 (38 core, 244 non-core); Num. remaining: 6744
# Reaction no.  9
# Attempting to remove reaction:  r2366 ...
# Initial PM reactions: 10192
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 14 blocked (inactive) reactions
# Execution time of check_model_consistency:  31.040281000001414
# check_model_consistency done ...
# Lengths all--> inactive_G: 15 , inactive_C: ['PTDCACRNCPT1', 'r2434', 'PTDCACRNCPT2', 'MANt1r', 'HMR_2624', 'r0636'], inactive_NC:['EX_CE2838_e', 'RE2426C', 'CE4843td', 'TMDtd', 'r2296', 'r2298', 'r2366', 'EX_itp_e', 'r2297']
# Zero-expression evidence for reaction...
# 10192
# 10192
# check_model_function done ....
# Len P: 6744
# num_removed 282
# Len P AFTER 6743
# No reactions removed
# result 1.1
# Num. removed: 282 (38 core, 244 non-core); Num. remaining: 6743
# Reaction no.  10
# Attempting to remove reaction:  r2357 ...
# Initial PM reactions: 10192
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 21 blocked (inactive) reactions
# Execution time of check_model_consistency:  29.298312000000806
# check_model_consistency done ...
# Lengths all--> inactive_G: 22 , inactive_C: ['HMR_2821', 'r1595', 'FAOXC12DCx', 'NDPK1n', 'MANt1r', 'CHSTEROLt1', 'r1617', 'r1629', 'FAOXC12DCTc', 'r1657'], inactive_NC:['FATP6t', 'EX_din_e', 'EX_M00019_e', 'CYTK11n', 'EX_thyox__L_e', 'r2357', 'DINt', 'UMPK7n', 'ARACHCOAtx', 'EX_vacc_e', 'SPHMYLNtl', 'HMR_2827']
# Zero-expression evidence for reaction...
# 10192
# 10192
# check_model_function done ....
# Len P: 6743
# num_removed 282
# Len P AFTER 6742
# No reactions removed
# result 1.1
# Num. removed: 282 (38 core, 244 non-core); Num. remaining: 6742
# Reaction no.  11
# Attempting to remove reaction:  r2356 ...
# Initial PM reactions: 10192
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  30.64122099999986
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: ['r1586', 'HMR_7758'], inactive_NC:['NFDNPYtep', 'EX_pe13_hs_e', 'EX_fmn_e', 'EX_man_e', 'EX_nfdnpy_e', 'r2356', '6AHGLZtev', 'EX_HC02197_e']
# Zero-expression evidence for reaction...
# 10192
# 10192
# check_model_function done ....
# PM reactions (before): 10192
# Removed all inactive reactions
# PM reactions (after): 10182
# Num. removed: 292 (40 core, 252 non-core); Num. remaining: 6734
# Reaction no.  12
# Attempting to remove reaction:  r2367 ...
# Initial PM reactions: 10182
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  30.413298999999824
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: [], inactive_NC:['RE3566C', 'EX_xol7aone_e', 'r2367', 'ARACHt', 'IPDPtx']
# Zero-expression evidence for reaction...
# 10182
# 10182
# check_model_function done ....
# PM reactions (before): 10182
# Removed all inactive reactions
# PM reactions (after): 10177
# Num. removed: 297 (40 core, 257 non-core); Num. remaining: 6729
# Reaction no.  13
# Attempting to remove reaction:  r2354 ...
# Initial PM reactions: 10177
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 15 blocked (inactive) reactions
# Execution time of check_model_consistency:  28.869386999998824
# check_model_consistency done ...
# Lengths all--> inactive_G: 16 , inactive_C: ['HMR_2821'], inactive_NC:['RE2426C', 'GALGLUSIDEtl', 'r0809', 'ASPDTDe', 'HMR_1317', 'r2514', 'r2354', 'HMR_2827', 'EX_ump_e', 'EX_nrvnc_e', 'BTNtn', 'TMDOATtev', 'MLTHFte2', 'SK_7klitchol_c', 'EX_M02449_e']
# Zero-expression evidence for reaction...
# 10177
# 10177
# check_model_function done ....
# PM reactions (before): 10177
# Removed all inactive reactions
# PM reactions (after): 10161
# Num. removed: 313 (41 core, 272 non-core); Num. remaining: 6714
# Reaction no.  14
# Attempting to remove reaction:  r2358 ...
# Initial PM reactions: 10161
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 8 blocked (inactive) reactions
# Execution time of check_model_consistency:  28.813199000000168
# check_model_consistency done ...
# Lengths all--> inactive_G: 9 , inactive_C: ['r1606', 'r0407', 'r1656'], inactive_NC:['r2358', 'LKYNRtr3', 'EX_15HPET_e', 'DURIt', 'SPHMYLNtl', 'HMR_9640']
# Zero-expression evidence for reaction...
# 10161
# 10161
# check_model_function done ....
# Len P: 6714
# num_removed 313
# Len P AFTER 6713
# No reactions removed
# result 1.1
# Num. removed: 313 (41 core, 272 non-core); Num. remaining: 6713
# Reaction no.  15
# Attempting to remove reaction:  r2346 ...
# Initial PM reactions: 10161
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 33 blocked (inactive) reactions
# Execution time of check_model_consistency:  27.216264000000592
# check_model_consistency done ...
# Lengths all--> inactive_G: 34 , inactive_C: ['C8DCc', 'SCP21x', 'HMR_2711', 'G6PDH2r', 'r1617', 'EICOSTETCRNt', 'r1664', 'r1651', 'r1593'], inactive_NC:['PROSTGI2tr', 'EX_retfa_e', 'TMDtd', 'OCDCEAt', 'ABTD', 'EX_gluside_hs_e', 'r2333', 'r2509', 'r0747', 'EX_udp_e', 'r2346', 'RE0830C', 'HMR_4790', 'HMR_9640', 'r0946', 'EX_adrn_e', '7DHCHSTEROLtr', 'EX_cyst__L_e', 'EX_gal_e', 'EX_thyox__L_e', '21HPRGNLONEt2', 'CYTK13', 'EX_retinol_e', 'PROSTGI2c', 'CYST_Ltr']
# Zero-expression evidence for reaction...
# 10161
# 10161
# check_model_function done ....
# Len P: 6713
# num_removed 313
# Len P AFTER 6712
# No reactions removed
# result 1.1
# Num. removed: 313 (41 core, 272 non-core); Num. remaining: 6712
# Reaction no.  16
# Attempting to remove reaction:  r2364 ...
# Initial PM reactions: 10161
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 24 blocked (inactive) reactions
# Execution time of check_model_consistency:  26.97641400000066
# check_model_consistency done ...
# Lengths all--> inactive_G: 25 , inactive_C: ['FAOXC12DCx', 'HMR_2711', 'ACETONEt2m', 'r1608', 'CE2705t', 'FAOXC12DCTc', 'r1658', 'GALUi'], inactive_NC:['EX_CE2705_e', 'EX_retfa_e', 'EX_thmmp_e', 'r2329', 'TMDtd', 'SK_CE1273_c', 'r2316', 'EX_dha_e', '21HPRGNLONEt2', 'EX_retinol_e', 'EX_dcyt_e', 'MHISTAte', 'HMR_9640', 'RE1845C', 'EX_CE1273_e', 'EX_gca3s_e', 'r2364']
# Zero-expression evidence for reaction...
# 10161
# 10161
# check_model_function done ....
# Len P: 6712
# num_removed 313
# Len P AFTER 6711
# No reactions removed
# result 1.1
# Num. removed: 313 (41 core, 272 non-core); Num. remaining: 6711
# Reaction no.  17
# Attempting to remove reaction:  LEUKTRF4t ...
# Initial PM reactions: 10161
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 12 blocked (inactive) reactions
# Execution time of check_model_consistency:  28.053420999998707
# check_model_consistency done ...
# Lengths all--> inactive_G: 13 , inactive_C: ['r1554', 'G6Pter', 'C4CRNCPT2'], inactive_NC:['EX_9_cis_retfa_e', 'EX_dha_e', 'LEUKTRF4t', 'RTOTALt', 'MAGt', 'EX_mag_hs_e', 'MHISTAte', 'HMR_9640', 'EX_malthx_e', 'EX_dlnlcg_e']
# Zero-expression evidence for reaction...
# 10161
# 10161
# check_model_function done ....
# PM reactions (before): 10161
# Removed all inactive reactions
# PM reactions (after): 10148
# Num. removed: 326 (44 core, 282 non-core); Num. remaining: 6701
# Reaction no.  18
# Attempting to remove reaction:  r2347 ...
# Initial PM reactions: 10148
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 21 blocked (inactive) reactions
# Execution time of check_model_consistency:  28.90646200000083
# check_model_consistency done ...
# Lengths all--> inactive_G: 22 , inactive_C: ['HSD17B1', 'r1614', 'r1659'], inactive_NC:['PCHOL_HSter', 'SK_CE1273_c', 'r2316', 'EX_M01235_e', 'FRDPtc', 'EX_kynate_e', 'ETHAt', 'FATP6t', 'SK_HC02197_c', 'EX_etha_e', 'HMR_2569', 'FATP9t', 'HMR_1095', 'r2347', 'EX_CE1273_e', 'EX_cyst__L_e', 'CYTK4n', 'RE3238C', 'CYST_Ltr']
# Zero-expression evidence for reaction...
# 10148
# 10148
# check_model_function done ....
# PM reactions (before): 10148
# Removed all inactive reactions
# PM reactions (after): 10126
# Num. removed: 348 (47 core, 301 non-core); Num. remaining: 6682
# Reaction no.  19
# Attempting to remove reaction:  r2359 ...
# Initial PM reactions: 10126
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 5 blocked (inactive) reactions
# Execution time of check_model_consistency:  27.704420999998547
# check_model_consistency done ...
# Lengths all--> inactive_G: 6 , inactive_C: ['r1617'], inactive_NC:['XOL7AONEtr', 'GLYC2P3Pc', 'ESTRADIOLtr', 'DIGALSIDEtg', 'r2359']
# Zero-expression evidence for reaction...
# 10126
# 10126
# check_model_function done ....
# PM reactions (before): 10126
# Removed all inactive reactions
# PM reactions (after): 10120
# Num. removed: 354 (48 core, 306 non-core); Num. remaining: 6677
# Reaction no.  20
# Attempting to remove reaction:  r2369 ...
# Initial PM reactions: 10120
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 17 blocked (inactive) reactions
# Execution time of check_model_consistency:  26.260513000001083
# check_model_consistency done ...
# Lengths all--> inactive_G: 18 , inactive_C: ['r1561', 'RE3346C', 'HMR_2684', 'TTDCPT1', 'HMR_2686', 'HMR_0176', 'r0686', 'HMR_2685'], inactive_NC:['r2324', 'EX_ps_hs_e', 'TMDtd', '5MTAte', 'PGISr', 'EX_5mta_e', 'r2369', 'EX_C04717_e', '7DHCHSTEROLtr', 'r2333']
# Zero-expression evidence for reaction...
# 10120
# 10120
# check_model_function done ....
# Len P: 6677
# num_removed 354
# Len P AFTER 6676
# No reactions removed
# result 1.1
# Num. removed: 354 (48 core, 306 non-core); Num. remaining: 6676
# Reaction no.  21
# Attempting to remove reaction:  3HSMVhep ...
# Initial PM reactions: 10120
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 30 blocked (inactive) reactions
# Execution time of check_model_consistency:  27.26774900000055
# check_model_consistency done ...
# Lengths all--> inactive_G: 31 , inactive_C: ['HMR_2684', 'HMR_2686', 'NDPK6n', 'ECOAH9m', 'r1666', 'HMR_2685'], inactive_NC:['EX_3hsmvacid_e', '3HSMVhep', 'EX_succ_e', 'SK_lnlncgcoa_c', 'PGISr', 'DUDPtn', 'EX_asp__L_e', 'EX_whhdca_e', 'UDPG4E', 'HMR_4790', 'SK_xol7aone_c', 'WHHDCAte', '3HSMVACIDteb', '3HSMVACIDhep', 'RE1918C', 'C226COAtx', 'EX_lys__L_e', 'EX_ps_hs_e', '3HSMVitr', 'HDD2COAtx', 'TAURtcx', 'DURIt', 'EX_fvs_e', 'r0747', 'PMTCRNtr']
# Zero-expression evidence for reaction...
# 10120
# 10120
# check_model_function done ....
# PM reactions (before): 10120
# Removed all inactive reactions
# PM reactions (after): 10089
# Num. removed: 385 (54 core, 331 non-core); Num. remaining: 6651
# Reaction no.  22
# Attempting to remove reaction:  HMR_1980 ...
# Initial PM reactions: 10089
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 14 blocked (inactive) reactions
# Execution time of check_model_consistency:  27.211175999998886
# check_model_consistency done ...
# Lengths all--> inactive_G: 15 , inactive_C: ['r1615', 'TTDCPT2', 'GALUi', 'CE2705t'], inactive_NC:['EX_CE2705_e', 'UTPtn', 'SK_retfa_c', 'TMDtd', 'HC00900t1', 'RE1233C', 'EX_gca3s_e', 'HMR_1980', 'HMR_1979', 'EX_C04717_e', 'PPItr']
# Zero-expression evidence for reaction...
# 10089
# 10089
# check_model_function done ....
# Len P: 6651
# num_removed 385
# Len P AFTER 6650
# No reactions removed
# result 1.1
# Num. removed: 385 (54 core, 331 non-core); Num. remaining: 6650
# Reaction no.  23
# Attempting to remove reaction:  HMR_1983 ...
# Initial PM reactions: 10089
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 12 blocked (inactive) reactions
# Execution time of check_model_consistency:  27.08032800000001
# check_model_consistency done ...
# Lengths all--> inactive_G: 13 , inactive_C: ['r1561', 'HMR_2711', 'r1594', 'PSSA2_hs', 'r1632'], inactive_NC:['AHCYStm', 'UTPtn', 'STCRNtr', 'TMDtd', 'HMR_1983', 'HMR_1982', 'TDCHOLAtx', 'AMETtm']
# Zero-expression evidence for reaction...
# 10089
# 10089
# check_model_function done ....
# Len P: 6650
# num_removed 385
# Len P AFTER 6649
# No reactions removed
# result 1.1
# Num. removed: 385 (54 core, 331 non-core); Num. remaining: 6649
# Reaction no.  24
# Attempting to remove reaction:  DCATDc ...
# Initial PM reactions: 10089
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 14 blocked (inactive) reactions
# Execution time of check_model_consistency:  28.919958000000406
# check_model_consistency done ...
# Lengths all--> inactive_G: 15 , inactive_C: ['r1597', 'FAOXOHMC10DC10c'], inactive_NC:['RE1518M', 'r1527', 'EX_retfa_e', 'UTPtn', 'FAOXMC10OHMC10r', 'OMHDEACIDTD', 'CHSTEROLtrc', 'EX_retinol_e', 'HMR_0180', 'DCATDr', 'ISOCHOLt', 'DCATDc', 'EX_gca3s_e']
# Zero-expression evidence for reaction...
# 10089
# 10089
# check_model_function done ....
# PM reactions (before): 10089
# Removed all inactive reactions
# PM reactions (after): 10074
# Num. removed: 400 (56 core, 344 non-core); Num. remaining: 6636
# Reaction no.  25
# Attempting to remove reaction:  GLYGLYPEPT1tc ...
# Initial PM reactions: 10074
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 10 blocked (inactive) reactions
# Execution time of check_model_consistency:  26.57605599999988
# check_model_consistency done ...
# Lengths all--> inactive_G: 11 , inactive_C: ['r1561', 'FAOXC12DCx', 'PSSA1_hs', 'r1646', 'FAOXC12DCTc'], inactive_NC:['PTVSTtep', 'EX_glygly_e', 'r2509', 'DCYTt', 'CHSTEROLt2', 'GLYGLYPEPT1tc']
# Zero-expression evidence for reaction...
# 10074
# 10074
# check_model_function done ....
# Len P: 6636
# num_removed 400
# Len P AFTER 6635
# No reactions removed
# result 1.1
# Num. removed: 400 (56 core, 344 non-core); Num. remaining: 6635
# Reaction no.  26
# Attempting to remove reaction:  HMR_9583 ...
# Initial PM reactions: 10074
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 32 blocked (inactive) reactions
# Execution time of check_model_consistency:  25.331161000000066
# check_model_consistency done ...
# Lengths all--> inactive_G: 33 , inactive_C: ['HISSNAT5tc', 'r1634', 'r1590'], inactive_NC:['r2357', 'EX_HC02207_e', 'ADPtx', 'HMR_1316', 'STCOAtx', 'EX_4mop_e', 'CITt4_4', 'EX_dhcholestanate_e', '1MNCAMt', 'CSNAT2m', 'SK_crvnc_c', 'r2509', 'HMR_9583', 'EX_glyb_e', 'LEUKTRD4t', '4MOPte', 'GGT6', 'GHMT2r', 'RE3567C', 'ESTRONEtr', 'EX_gd1b_hs_e', 'HMR_1315', 'r2358', 'HMR_9584', 'EX_oxyp_e', 'EX_HC02180_e', 'ARACHDCOAtx', 'EX_so3_e', 'RE2069C', 'HMR_0831']
# Zero-expression evidence for reaction...
# 10074
# 10074
# check_model_function done ....
# PM reactions (before): 10074
# Removed all inactive reactions
# PM reactions (after): 10041
# Num. removed: 433 (59 core, 374 non-core); Num. remaining: 6607
# Reaction no.  27
# Attempting to remove reaction:  CE4890te2 ...
# Initial PM reactions: 10041
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 12 blocked (inactive) reactions
# Execution time of check_model_consistency:  27.919286000000284
# check_model_consistency done ...
# Lengths all--> inactive_G: 13 , inactive_C: ['r1587', 'HMR_0176', 'r1658', 'CREATt4_2_r'], inactive_NC:['15KPROSTGF2c', 'DSPVStev', 'HMR_1306', 'EX_ttdcrn_e', 'EX_HC02217_e', 'EX_dca3s_e', 'CE4890te2', 'ODECOAtx', 'UAG4Ei']
# Zero-expression evidence for reaction...
# 10041
# 10041
# check_model_function done ....
# Len P: 6607
# num_removed 433
# Len P AFTER 6606
# No reactions removed
# result 1.1
# Num. removed: 433 (59 core, 374 non-core); Num. remaining: 6606
# Reaction no.  28
# Attempting to remove reaction:  DEBRISOQUINEt ...
# Initial PM reactions: 10041
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 13 blocked (inactive) reactions
# Execution time of check_model_consistency:  26.066241000000446
# check_model_consistency done ...
# Lengths all--> inactive_G: 14 , inactive_C: ['r2374', 'PSSA1_hs', 'G6PDH2r'], inactive_NC:['P4502D6', 'EX_4hdebrisoquine_e', 'EX_debrisoquine_e', 'DEBRISOQUINEt', 'DMNONCRNt', 'EX_gt1a_hs_e', '4HDEBRISOQUINEte', 'ALADGLNexR', 'EX_C04717_e', 'EX_M00003_e', 'GT1Ate']
# Zero-expression evidence for reaction...
# 10041
# 10041
# check_model_function done ....
# PM reactions (before): 10041
# Removed all inactive reactions
# PM reactions (after): 10027
# Num. removed: 447 (62 core, 385 non-core); Num. remaining: 6595
# Reaction no.  29
# Attempting to remove reaction:  AVITE1t ...
# Initial PM reactions: 10027
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 15 blocked (inactive) reactions
# Execution time of check_model_consistency:  26.64991199999895
# check_model_consistency done ...
# Lengths all--> inactive_G: 16 , inactive_C: ['RE3012C', 'r1606', 'HMR_1129', 'XYLR'], inactive_NC:['CE4843td', 'GALt2_2', 'r2319', 'ABT_Dt', 'VITEtl', 'RE1233C', 'CSNATp', 'AVITE1t', 'EX_dca3s_e', 'RE0915E', '3HPVStep', 'ALLOPtepvb']
# Zero-expression evidence for reaction...
# 10027
# 10027
# check_model_function done ....
# PM reactions (before): 10027
# Removed all inactive reactions
# PM reactions (after): 10011
# Num. removed: 463 (66 core, 397 non-core); Num. remaining: 6583
# Reaction no.  30
# Attempting to remove reaction:  AGRMte ...
# Initial PM reactions: 10011
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 16 blocked (inactive) reactions
# Execution time of check_model_consistency:  25.851260999999795
# check_model_consistency done ...
# Lengths all--> inactive_G: 17 , inactive_C: ['r1561', 'HMR_0176'], inactive_NC:['URIDK2m', 'EX_Lpipecol_e', 'AGRMte', 'HSD3B7', 'TMDtd', 'LPIPECOLtx', 'r2145', 'EX_agm_e', 'GLXtm', 'EX_M00008_e', 'EX_M00019_e', 'AGMt_m', 'RE2766C', 'LPIPECOLt', 'r2368']
# Zero-expression evidence for reaction...
# 10011
# 10011
# check_model_function done ....
# PM reactions (before): 10011
# Removed all inactive reactions
# PM reactions (after): 9994
# Num. removed: 480 (68 core, 412 non-core); Num. remaining: 6568
# Reaction no.  31
# Attempting to remove reaction:  CE6205te ...
# Initial PM reactions: 9994
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  26.72044199999982
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: ['GALT', 'EICOSTETCRNt', 'TMNDNCCRNt'], inactive_NC:['EX_din_e', 'EX_ttdcrn_e', 'CE6205te', 'RE2562C', 'EX_CE6205_e', 'EX_gudac_e', '5MTHFt2']
# Zero-expression evidence for reaction...
# 9994
# 9994
# check_model_function done ....
# Len P: 6568
# num_removed 480
# Len P AFTER 6567
# No reactions removed
# result 1.1
# Num. removed: 480 (68 core, 412 non-core); Num. remaining: 6567
# Reaction no.  32
# Attempting to remove reaction:  N8ASPMDte ...
# Initial PM reactions: 9994
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 12 blocked (inactive) reactions
# Execution time of check_model_consistency:  28.20267700000113
# check_model_consistency done ...
# Lengths all--> inactive_G: 13 , inactive_C: ['PUNP4', 'r1615'], inactive_NC:['ATPtx', 'EX_34hpp_e', '34HPPte', 'SK_HC02220_c', 'DSPVStev', 'PAIL45P_HStn', 'SPMDAT2', 'N8ASPMDte', 'EX_sphings_e', 'AMPtp', 'EX_n8aspmd_e']
# Zero-expression evidence for reaction...
# 9994
# 9994
# check_model_function done ....
# PM reactions (before): 9994
# Removed all inactive reactions
# PM reactions (after): 9981
# Num. removed: 493 (70 core, 423 non-core); Num. remaining: 6556
# Reaction no.  33
# Attempting to remove reaction:  C09642te ...
# Initial PM reactions: 9981
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 19 blocked (inactive) reactions
# Execution time of check_model_consistency:  25.703836999999112
# check_model_consistency done ...
# Lengths all--> inactive_G: 20 , inactive_C: ['GALT', 'HMR_2711', 'HACD1m', 'PUNP2', 'ECOAH1m', 'HMR_6755'], inactive_NC:['C09642te', 'HMR_1306', 'RE2526C', 'ECOAR', 'RE1923C', 'EX_lnlccrn_e', 'TCHOLAtx', 'TCHOLAte', 'EX_HC02217_e', 'EX_C09642_e', 'RE1519X', 'ODECOAtx', 'EX_pcrn_e', 'ECOAH4m']
# Zero-expression evidence for reaction...
# 9981
# 9981
# check_model_function done ....
# Len P: 6556
# num_removed 493
# Len P AFTER 6555
# No reactions removed
# result 1.1
# Num. removed: 493 (70 core, 423 non-core); Num. remaining: 6555
# Reaction no.  34
# Attempting to remove reaction:  CHATn ...
# Initial PM reactions: 9981
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 17 blocked (inactive) reactions
# Execution time of check_model_consistency:  27.64461499999925
# check_model_consistency done ...
# Lengths all--> inactive_G: 18 , inactive_C: ['FAOXC12DCTc', 'FAOXC12DCx', 'C6DCCACT', 'ADPCOACROT'], inactive_NC:['EX_Lkynr_e', 'TMNDNCCOAtx', 'DINt', 'CHATn', 'EX_nad_e', 'ACHtn', 'ACCOAtn', 'EX_dcyt_e', 'EX_xolest2_hs_e', 'r0946', 'CHOLtn', '15DMTtep', 'COAtn', 'RE1519X']
# Zero-expression evidence for reaction...
# 9981
# 9981
# check_model_function done ....
# PM reactions (before): 9981
# Removed all inactive reactions
# PM reactions (after): 9963
# Num. removed: 511 (74 core, 437 non-core); Num. remaining: 6541
# Reaction no.  35
# Attempting to remove reaction:  CSNt ...
# Initial PM reactions: 9963
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 11 blocked (inactive) reactions
# Execution time of check_model_consistency:  25.127431999999317
# check_model_consistency done ...
# Lengths all--> inactive_G: 12 , inactive_C: ['r1608'], inactive_NC:['6BHGLZGLCtev', 'RE0830C', 'CSND', 'EX_malttr_e', 'CSNt', 'EX_acetone_e', '6BHGLZitr', 'EX_gd3_hs_e', 'EX_csn_e', 'EX_6bhglz_e', 'FUMSO3tm']
# Zero-expression evidence for reaction...
# 9963
# 9963
# check_model_function done ....
# PM reactions (before): 9963
# Removed all inactive reactions
# PM reactions (after): 9951
# Num. removed: 523 (75 core, 448 non-core); Num. remaining: 6530
# Reaction no.  36
# Attempting to remove reaction:  r0934 ...
# Initial PM reactions: 9951
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  24.725389999999607
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: ['RE3010M'], inactive_NC:['SK_c226coa_c', 'ICDCHOLt', 'EX_cdp_e', 'SK_retfa_c', 'TCHOLAtx', 'r0817', 'r0934', 'r2355', 'r2333']
# Zero-expression evidence for reaction...
# 9951
# 9951
# check_model_function done ....
# PM reactions (before): 9951
# Removed all inactive reactions
# PM reactions (after): 9941
# Num. removed: 533 (76 core, 457 non-core); Num. remaining: 6521
# Reaction no.  37
# Attempting to remove reaction:  r2363 ...
# Initial PM reactions: 9941
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 21 blocked (inactive) reactions
# Execution time of check_model_consistency:  26.943234000000302
# check_model_consistency done ...
# Lengths all--> inactive_G: 22 , inactive_C: ['NDPK1m', 'r1574', 'r1654', 'r1613', 'ACETONEt2m', 'RNTR2', 'BETALDHy', 'C180CPT1', 'r0610', 'r1638', 'r0611'], inactive_NC:['r2363', 'RAI2', 'EX_ttdcrn_e', 'RE0958E', 'RAI1', 'PRGNLONEtr', 'r0835', 'HMR_3953', 'r2514e', 'EX_i_e', 'UAG4Ei']
# Zero-expression evidence for reaction...
# 9941
# 9941
# check_model_function done ....
# Len P: 6521
# num_removed 533
# Len P AFTER 6520
# No reactions removed
# result 1.1
# Num. removed: 533 (76 core, 457 non-core); Num. remaining: 6520
# Reaction no.  38
# Attempting to remove reaction:  HMR_3491 ...
# Initial PM reactions: 9941
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 5 blocked (inactive) reactions
# Execution time of check_model_consistency:  25.294486999999208
# check_model_consistency done ...
# Lengths all--> inactive_G: 6 , inactive_C: ['r1656'], inactive_NC:['RE3079X', 'HMR_3491', 'r2539', 'EX_ncam_e', '7DHCHSTEROLtr']
# Zero-expression evidence for reaction...
# 9941
# 9941
# check_model_function done ....
# PM reactions (before): 9941
# Removed all inactive reactions
# PM reactions (after): 9935
# Num. removed: 539 (77 core, 462 non-core); Num. remaining: 6515
# Reaction no.  39
# Attempting to remove reaction:  ADPRIBt ...
# Initial PM reactions: 9935
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 14 blocked (inactive) reactions
# Execution time of check_model_consistency:  26.005833999999595
# check_model_consistency done ...
# Lengths all--> inactive_G: 15 , inactive_C: ['RNTR2', 'BETALDHy', 'RE1530M', 'HMR_6755', 'r0686'], inactive_NC:['15KPROSTGF2c', 'HMR_4831', 'NADNe', 'EX_pnto__R_e', '21HPRGNLONEt2', 'CAt7r', 'It', 'EX_nadh_e', 'ADPRIBt', 'RDH2']
# Zero-expression evidence for reaction...
# 9935
# 9935
# check_model_function done ....
# Len P: 6515
# num_removed 539
# Len P AFTER 6514
# No reactions removed
# result 1.1
# Num. removed: 539 (77 core, 462 non-core); Num. remaining: 6514
# Reaction no.  40
# Attempting to remove reaction:  GLCRt1 ...
# Initial PM reactions: 9935
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 8 blocked (inactive) reactions
# Execution time of check_model_consistency:  24.94930899999963
# check_model_consistency done ...
# Lengths all--> inactive_G: 9 , inactive_C: ['GALT', 'GLACO', 'PNP'], inactive_NC:['DMHPTCRNt', 'EX_dgchol_e', 'GLCRt1', 'EX_glcr_e', 'EX_gd1c_hs_e', 'HOMOVALte']
# Zero-expression evidence for reaction...
# 9935
# 9935
# check_model_function done ....
# Len P: 6514
# num_removed 539
# Len P AFTER 6513
# No reactions removed
# result 1.1
# Num. removed: 539 (77 core, 462 non-core); Num. remaining: 6513
# Reaction no.  41
# Attempting to remove reaction:  r2361 ...
# Initial PM reactions: 9935
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 15 blocked (inactive) reactions
# Execution time of check_model_consistency:  24.345022000001336
# check_model_consistency done ...
# Lengths all--> inactive_G: 16 , inactive_C: ['ADNtm', 'PTDCACRNCPT1', 'SCP21x', 'PTDCACRNCPT2', 'NDPK7', 'C40CPT1', 'HMR_2624'], inactive_NC:['r0830', 'DADNt4', 'r2361', 'ADPACtd', 'SPHMYLNtl', 'XMPtr', 'EX_adpac_e', 'EX_xmp_e', 'EX_M01238_e']
# Zero-expression evidence for reaction...
# 9935
# 9935
# check_model_function done ....
# Len P: 6513
# num_removed 539
# Len P AFTER 6512
# No reactions removed
# result 1.1
# Num. removed: 539 (77 core, 462 non-core); Num. remaining: 6512
# Reaction no.  42
# Attempting to remove reaction:  RETt ...
# Initial PM reactions: 9935
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 18 blocked (inactive) reactions
# Execution time of check_model_consistency:  24.62116800000149
# check_model_consistency done ...
# Lengths all--> inactive_G: 19 , inactive_C: ['PTDCACRNCPT1', 'r1595', 'HMR_2711', 'PTDCACRNCPT2', 'HMR_2624', 'r2110'], inactive_NC:['HMR_9561', 'EX_retn_e', 'EX_tchola_e', '21HPRGNLONEt2', 'EX_lnlccrn_e', 'CHSTEROLt2', 'EX_M02837_e', 'RETt', 'RETINALt', 'RETFAt', 'HMR_3520', 'RETHe', 'r2311']
# Zero-expression evidence for reaction...
# 9935
# 9935
# check_model_function done ....
# Len P: 6512
# num_removed 539
# Len P AFTER 6511
# No reactions removed
# result 1.1
# Num. removed: 539 (77 core, 462 non-core); Num. remaining: 6511
# Reaction no.  43
# Attempting to remove reaction:  SPRMti ...
# Initial PM reactions: 9935
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 19 blocked (inactive) reactions
# Execution time of check_model_consistency:  25.18009400000301
# check_model_consistency done ...
# Lengths all--> inactive_G: 20 , inactive_C: ['PTDCACRNCPT1', 'r1595', 'ALAR', 'PTDCACRNCPT2', 'CITtam', 'RNTR2', 'RE1530M', 'r1612', 'C40CPT1', 'HMR_2624', 'CREATt4_2_r'], inactive_NC:['r2194', 'EX_CE7172_e', 'PTRCtex2', 'G3PCt', 'EX_hdcea_e', 'SPRMti', 'LYStm', 'EX_g3pc_e', 'EX_M01238_e']
# Zero-expression evidence for reaction...
# 9935
# 9935
# check_model_function done ....
# Len P: 6511
# num_removed 539
# Len P AFTER 6510
# No reactions removed
# result 1.1
# Num. removed: 539 (77 core, 462 non-core); Num. remaining: 6510
# Reaction no.  44
# Attempting to remove reaction:  HPETFABP1tc ...
# Initial PM reactions: 9935
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 11 blocked (inactive) reactions
# Execution time of check_model_consistency:  27.711982000000717
# check_model_consistency done ...
# Lengths all--> inactive_G: 12 , inactive_C: ['C161CPT2', 'r0686', 'r1665', 'TYRPHELAT2tc'], inactive_NC:['15KPROSTGF2c', 'MMAt2e', 'LEULEUt', 'DM_5HPET_r', 'HPETFABP1tc', 'HMR_3953', 'HOMOVALte', 'r0672']
# Zero-expression evidence for reaction...
# 9935
# 9935
# check_model_function done ....
# Len P: 6510
# num_removed 539
# Len P AFTER 6509
# No reactions removed
# result 1.1
# Num. removed: 539 (77 core, 462 non-core); Num. remaining: 6509
# Reaction no.  45
# Attempting to remove reaction:  OXYPthc ...
# Initial PM reactions: 9935
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 13 blocked (inactive) reactions
# Execution time of check_model_consistency:  27.640454000000318
# check_model_consistency done ...
# Lengths all--> inactive_G: 14 , inactive_C: ['PTDCACRNCPT1', 'r1661', 'HMR_2624', 'PTDCACRNCPT2'], inactive_NC:['RAI2', 'OXYPtepv', 'OXYPthc', '21HPRGNLONEt2', 'RAI1', 'SPHMYLNtl', 'FADH2tx', 'EX_CE7172_e', 'FADtx', 'CITRtm']
# Zero-expression evidence for reaction...
# 9935
# 9935
# check_model_function done ....
# Len P: 6509
# num_removed 539
# Len P AFTER 6508
# No reactions removed
# result 1.1
# Num. removed: 539 (77 core, 462 non-core); Num. remaining: 6508
# Reaction no.  46
# Attempting to remove reaction:  r2344 ...
# Initial PM reactions: 9935
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 6 blocked (inactive) reactions
# Execution time of check_model_consistency:  26.714363999999478
# check_model_consistency done ...
# Lengths all--> inactive_G: 7 , inactive_C: ['r1612', 'r1660'], inactive_NC:['AHCYStm', 'SPHMYLNtl', 'HMR_3953', 'r2344', 'AMETtm']
# Zero-expression evidence for reaction...
# 9935
# 9935
# check_model_function done ....
# Len P: 6508
# num_removed 539
# Len P AFTER 6507
# No reactions removed
# result 1.1
# Num. removed: 539 (77 core, 462 non-core); Num. remaining: 6507
# Reaction no.  47
# Attempting to remove reaction:  34DHOXMANDte ...
# Initial PM reactions: 9935
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 5 blocked (inactive) reactions
# Execution time of check_model_consistency:  25.28268400000161
# check_model_consistency done ...
# Lengths all--> inactive_G: 6 , inactive_C: ['r1671', 'r1632'], inactive_NC:['34DHOXMANDte', 'EX_34dhoxmand_e', 'AHCYStm', 'AMETtm']
# Zero-expression evidence for reaction...
# 9935
# 9935
# check_model_function done ....
# Len P: 6507
# num_removed 539
# Len P AFTER 6506
# No reactions removed
# result 1.1
# Num. removed: 539 (77 core, 462 non-core); Num. remaining: 6506
# Reaction no.  48
# Attempting to remove reaction:  LEUKTRB4t ...
# Initial PM reactions: 9935
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 11 blocked (inactive) reactions
# Execution time of check_model_consistency:  24.741816999998264
# check_model_consistency done ...
# Lengths all--> inactive_G: 12 , inactive_C: ['r1610', 'r1671', 'PNP', 'ASNPHELAT2tc'], inactive_NC:['LDH_D', 'r0381', 'THRGLNexR', 'AMETt', 'GLYPROt', 'LEUKTRB4t', 'RE2659R', 'HOMOVALte']
# Zero-expression evidence for reaction...
# 9935
# 9935
# check_model_function done ....
# Len P: 6506
# num_removed 539
# Len P AFTER 6505
# No reactions removed
# result 1.1
# Num. removed: 539 (77 core, 462 non-core); Num. remaining: 6505
# Reaction no.  49
# Attempting to remove reaction:  r2343 ...
# Initial PM reactions: 9935
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  26.638660000000527
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: ['RE1530M'], inactive_NC:['r2343', 'EX_pchol_hs_e']
# Zero-expression evidence for reaction...
# 9935
# 9935
# check_model_function done ....
# Len P: 6505
# num_removed 539
# Len P AFTER 6504
# No reactions removed
# result 1.1
# Num. removed: 539 (77 core, 462 non-core); Num. remaining: 6504
# Reaction no.  50
# Attempting to remove reaction:  34DHPHAte ...
# Initial PM reactions: 9935
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 15 blocked (inactive) reactions
# Execution time of check_model_consistency:  24.57302300000083
# check_model_consistency done ...
# Lengths all--> inactive_G: 16 , inactive_C: ['NAPRT', 'SCP21x', 'r1613', 'r1573'], inactive_NC:['EX_aicar_e', 'r0381', 'EX_34dhpha_e', 'AICARte', 'EX_pnto__R_e', '21HPRGNLONEt2', '3HIBUP_Rthv', 'EX_crm_hs_e', '34DHPHAte', 'EX_3hibup__R_e', 'EX_CE7172_e', 'EX_pear_hs_e']
# Zero-expression evidence for reaction...
# 9935
# 9935
# check_model_function done ....
# PM reactions (before): 9935
# Removed all inactive reactions
# PM reactions (after): 9919
# Num. removed: 555 (81 core, 474 non-core); Num. remaining: 6492
# Reaction no.  51
# Attempting to remove reaction:  LNLNCGt ...
# Initial PM reactions: 9919
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 6 blocked (inactive) reactions
# Execution time of check_model_consistency:  28.45313399999941
# check_model_consistency done ...
# Lengths all--> inactive_G: 7 , inactive_C: [], inactive_NC:['HMR_0016', 'AMETt2m', 'HMR_0015', 'EX_M02561_e', 'EX_M02560_e', 'r1520', 'LNLNCGt']
# Zero-expression evidence for reaction...
# 9919
# 9919
# check_model_function done ....
# PM reactions (before): 9919
# Removed all inactive reactions
# PM reactions (after): 9912
# Num. removed: 562 (81 core, 481 non-core); Num. remaining: 6485
# Reaction no.  52
# Attempting to remove reaction:  IBUP_Rshep ...
# Initial PM reactions: 9912
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 15 blocked (inactive) reactions
# Execution time of check_model_consistency:  23.4455850000013
# check_model_consistency done ...
# Lengths all--> inactive_G: 16 , inactive_C: ['34DHPLACOX_NADP', 'r2111', 'IBUP_SACOT2', 'CHSTEROLt1', 'IBUP_RASCL1hep'], inactive_NC:['PTVSTtep', 'IBUP_SCONJhep', 'EX_bilirub_e', 'IBUP_Rshep', 'EX_vacc_e', 'EX_tauribup__S_e', 'RE0453C', 'TAURIBUP_Sthv', 'SK_hdca_c', 'r2363', 'EX_M01238_e']
# Zero-expression evidence for reaction...
# 9912
# 9912
# check_model_function done ....
# Len P: 6485
# num_removed 562
# Len P AFTER 6484
# No reactions removed
# result 1.1
# Num. removed: 562 (81 core, 481 non-core); Num. remaining: 6484
# Reaction no.  53
# Attempting to remove reaction:  THYMt ...
# Initial PM reactions: 9912
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 17 blocked (inactive) reactions
# Execution time of check_model_consistency:  23.932718000000023
# check_model_consistency done ...
# Lengths all--> inactive_G: 18 , inactive_C: ['PTDCACRNCPT1', 'UGLT', 'PTDCACRNCPT2', 'HMR_2624', 'r1654'], inactive_NC:['C03990t', 'OCDCEAt', 'EX_ptdca_e', 'EX_thym_e', 'EX_vacc_e', 'EX_M01238_e', 'GLYCt', 'HDCAt', 'r0835', 'EX_3dhlchol_e', 'THYMt', 'r1468', '3AIB_Dtm']
# Zero-expression evidence for reaction...
# 9912
# 9912
# check_model_function done ....
# Len P: 6484
# num_removed 562
# Len P AFTER 6483
# No reactions removed
# result 1.1
# Num. removed: 562 (81 core, 481 non-core); Num. remaining: 6483
# Reaction no.  54
# Attempting to remove reaction:  PROSTGF2t ...
# Initial PM reactions: 9912
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 31 blocked (inactive) reactions
# Execution time of check_model_consistency:  22.462255000002187
# check_model_consistency done ...
# Lengths all--> inactive_G: 32 , inactive_C: ['ADNtm', 'PTDCACRNCPT1', 'TMNDNCCRNt', 'PTDCACRNCPT2', 'GULND', 'r2086', 'RNTR2', 'RE1530M', 'r2516', 'C40CPT1', 'HMR_2624', 'EICOSTETCRNt', 'PNP'], inactive_NC:['15KPROSTGF2c', 'PROSTGF2t', 'GLXtp', 'ADEt', 'PRGNLONEtr', 'HMR_3520', 'EX_itp_e', 'EX_M01238_e', 'RAI1', 'RE0453C', 'r0871', 'RAI2', 'EX_ptdca_e', 'RETI1', 'EX_pydx5p_e', 'EX_glu__L_e', 'EX_lnlccrn_e', 'RE0958E', 'ORNt4m']
# Zero-expression evidence for reaction...
# 9912
# 9912
# check_model_function done ....
# Len P: 6483
# num_removed 562
# Len P AFTER 6482
# No reactions removed
# result 1.1
# Num. removed: 562 (81 core, 481 non-core); Num. remaining: 6482
# Reaction no.  55
# Attempting to remove reaction:  r0984 ...
# Initial PM reactions: 9912
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 14 blocked (inactive) reactions
# Execution time of check_model_consistency:  22.473441999998613
# check_model_consistency done ...
# Lengths all--> inactive_G: 15 , inactive_C: ['r1253', 'RNTR4', 'HMR_2817', 'RE1530M', 'ILELAT1tc'], inactive_NC:['ATVACIDtdu', 'HMR_2819', 'EX_vacc_e', 'EX_M01238_e', 'SPHMYLNtl', 'q10h2tc', 'r0984', 'EX_ttdca_e', 'EX_lnlc_e', 'r0983']
# Zero-expression evidence for reaction...
# 9912
# 9912
# check_model_function done ....
# Len P: 6482
# num_removed 562
# Len P AFTER 6481
# No reactions removed
# result 1.1
# Num. removed: 562 (81 core, 481 non-core); Num. remaining: 6481
# Reaction no.  56
# Attempting to remove reaction:  MMAt2e ...
# Initial PM reactions: 9912
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 7 blocked (inactive) reactions
# Execution time of check_model_consistency:  22.63926700000229
# check_model_consistency done ...
# Lengths all--> inactive_G: 8 , inactive_C: ['C181CPT1', 'UGLT', 'RE1530M', 'PNP'], inactive_NC:['AKGtp', 'MMAt2e', 'r2363', '4HATVLACtep']
# Zero-expression evidence for reaction...
# 9912
# 9912
# check_model_function done ....
# Len P: 6481
# num_removed 562
# Len P AFTER 6480
# No reactions removed
# result 1.1
# Num. removed: 562 (81 core, 481 non-core); Num. remaining: 6480
# Reaction no.  57
# Attempting to remove reaction:  ACGAM2E ...
# Initial PM reactions: 9912
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 18 blocked (inactive) reactions
# Execution time of check_model_consistency:  24.468761000000086
# check_model_consistency done ...
# Lengths all--> inactive_G: 19 , inactive_C: ['FATP1t', '34DHPLACOX_NADP', 'LNLCCRNt'], inactive_NC:['SK_chol_c', 'EX_15HPET_e', 'ABTD', 'D3AIBTm', 'GLXtp', 'TTCCOAtx', '2HATVLACtep', 'EX_ttdca_e', 'r1468', 'EX_M01238_e', 'r1117', 'FOLOAT1tc', 'STCRNtr', 'ACGAM2E', 'LEUKTRB4t', '5MTHFt2']
# Zero-expression evidence for reaction...
# 9912
# 9912
# check_model_function done ....
# PM reactions (before): 9912
# Removed all inactive reactions
# PM reactions (after): 9893
# Num. removed: 581 (84 core, 497 non-core); Num. remaining: 6465
# Reaction no.  58
# Attempting to remove reaction:  r0786 ...
# Initial PM reactions: 9893
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 18 blocked (inactive) reactions
# Execution time of check_model_consistency:  22.661651000002166
# check_model_consistency done ...
# Lengths all--> inactive_G: 19 , inactive_C: ['GALT', 'r0525', 'C8DCc', 'C161CRN2t', 'r2092', 'r1664'], inactive_NC:['HMR_2014', 'S2L2N2M2Mt', 'DMHPTCRNt', 'EX_s2l2n2m2m_e', 'S2L2N2M2Mtl', 'SPHPL', 'EX_ppa_e', 'C226CRNt', 'r1457', 'r0786', 'HOMOVALte', 'HMR_3520', 'MMAt2e']
# Zero-expression evidence for reaction...
# 9893
# 9893
# check_model_function done ....
# Len P: 6465
# num_removed 581
# Len P AFTER 6464
# No reactions removed
# result 1.1
# Num. removed: 581 (84 core, 497 non-core); Num. remaining: 6464
# Reaction no.  59
# Attempting to remove reaction:  SPHPL ...
# Initial PM reactions: 9893
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 22 blocked (inactive) reactions
# Execution time of check_model_consistency:  22.646637000001647
# check_model_consistency done ...
# ...
# Checking all reactions (FASTCC)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  16.565168000000995
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['HMR_9582', 'HMR_9581']
# Zero-expression evidence for reaction...
# 8224
# 8224
# check_model_function done ....
# PM reactions (before): 8224
# Removed all inactive reactions
# PM reactions (after): 8222
# Num. removed: 2252 (297 core, 1955 non-core); Num. remaining: 4186
# Reaction no.  1366
# Attempting to remove reaction:  CHSTEROLt ...
# Initial PM reactions: 8222
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 5 blocked (inactive) reactions
# Execution time of check_model_consistency:  17.022412000020267
# check_model_consistency done ...
# Lengths all--> inactive_G: 6 , inactive_C: ['CARN180t_m', 'r2133', 'r1638', 'C180CPT2'], inactive_NC:['r2335', 'CHSTEROLt']
# Zero-expression evidence for reaction...
# 8222
# 8222
# check_model_function done ....
# Len P: 4186
# num_removed 2252
# Len P AFTER 4185
# No reactions removed
# result 1.1
# Num. removed: 2252 (297 core, 1955 non-core); Num. remaining: 4185
# Reaction no.  1367
# Attempting to remove reaction:  r0239 ...
# Initial PM reactions: 8222
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  16.829407000011997
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: ['LFORKYNHYD', 'r2125', 'r2104'], inactive_NC:['r0239']
# Zero-expression evidence for reaction...
# 8222
# 8222
# check_model_function done ....
# Len P: 4185
# num_removed 2252
# Len P AFTER 4184
# No reactions removed
# result 1.1
# Num. removed: 2252 (297 core, 1955 non-core); Num. remaining: 4184
# Reaction no.  1368
# Attempting to remove reaction:  RE1517M ...
# Initial PM reactions: 8222
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  17.578149999986636
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: ['RE0512M', 'RE1531M', 'RE1523M'], inactive_NC:['RE1517M', 'RE1516M']
# Zero-expression evidence for reaction...
# 8222
# 8222
# check_model_function done ....
# Len P: 4184
# num_removed 2252
# Len P AFTER 4183
# No reactions removed
# result 1.1
# Num. removed: 2252 (297 core, 1955 non-core); Num. remaining: 4183
# Reaction no.  1369
# Attempting to remove reaction:  UREAt5 ...
# Initial PM reactions: 8222
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  17.174892999988515
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: ['CERT2gt', 'UREAt'], inactive_NC:['UREAt5']
# Zero-expression evidence for reaction...
# 8222
# 8222
# check_model_function done ....
# Len P: 4183
# num_removed 2252
# Len P AFTER 4182
# No reactions removed
# result 1.1
# Num. removed: 2252 (297 core, 1955 non-core); Num. remaining: 4182
# Reaction no.  1370
# Attempting to remove reaction:  GALGT3 ...
# Initial PM reactions: 8222
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 8 blocked (inactive) reactions
# Execution time of check_model_consistency:  18.189505999995163
# check_model_consistency done ...
# Lengths all--> inactive_G: 9 , inactive_C: ['B3GALT43g', 'ST6GALNAC62', 'CARN180t_m', 'C180CPT2', 'NAIt', 'r1571'], inactive_NC:['ST3GAL23g', 'GALGT3', 'r2335']
# Zero-expression evidence for reaction...
# 8222
# 8222
# check_model_function done ....
# Len P: 4182
# num_removed 2252
# Len P AFTER 4181
# No reactions removed
# result 1.1
# Num. removed: 2252 (297 core, 1955 non-core); Num. remaining: 4181
# Reaction no.  1371
# Attempting to remove reaction:  CITt4_2 ...
# Initial PM reactions: 8222
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  17.44948199999635
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: [], inactive_NC:['3MHISt1', 'CITt4_2', 'PROSTGI2t']
# Zero-expression evidence for reaction...
# 8222
# 8222
# check_model_function done ....
# PM reactions (before): 8222
# Removed all inactive reactions
# PM reactions (after): 8219
# Num. removed: 2255 (297 core, 1958 non-core); Num. remaining: 4178
# Reaction no.  1372
# Attempting to remove reaction:  FACOAL40im ...
# Initial PM reactions: 8219
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 7 blocked (inactive) reactions
# Execution time of check_model_consistency:  17.072847000003094
# check_model_consistency done ...
# Lengths all--> inactive_G: 8 , inactive_C: ['r1559', 'BUTt2m', 'CARN180t_m', 'r1602', 'C180CPT2', 'r1571'], inactive_NC:['FACOAL40im', 'EX_but_e']
# Zero-expression evidence for reaction...
# 8219
# 8219
# check_model_function done ....
# Len P: 4178
# num_removed 2255
# Len P AFTER 4177
# No reactions removed
# result 1.1
# Num. removed: 2255 (297 core, 1958 non-core); Num. remaining: 4177
# Reaction no.  1373
# Attempting to remove reaction:  ACCOACrm ...
# Initial PM reactions: 8219
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 16 blocked (inactive) reactions
# Execution time of check_model_consistency:  16.290684000006877
# check_model_consistency done ...
# Lengths all--> inactive_G: 17 , inactive_C: ['r0433_1', 'r2125', 'C180CPT2', 'r0432_1', 'CARN180t_m', 'HMR_9804', 'r0596', 'NDPK5'], inactive_NC:['EX_3hpp_e', 'HMR_9803', 'ACCOACrm', 'r1005', 'MCDp', 'MCDm', '3HPPt', 'r1006', '3HPPtm']
# Zero-expression evidence for reaction...
# 8219
# 8219
# check_model_function done ....
# Len P: 4177
# num_removed 2255
# Len P AFTER 4176
# No reactions removed
# result 1.1
# Num. removed: 2255 (297 core, 1958 non-core); Num. remaining: 4176
# Reaction no.  1374
# Attempting to remove reaction:  CYOR_u10mi ...
# Initial PM reactions: 8219
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  16.462161000003107
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: ['r1641', 'r1566'], inactive_NC:['CYOR_u10mi']
# Zero-expression evidence for reaction...
# 8219
# 8219
# check_model_function done ....
# Len P: 4176
# num_removed 2255
# Len P AFTER 4175
# No reactions removed
# result 1.1
# Num. removed: 2255 (297 core, 1958 non-core); Num. remaining: 4175
# Reaction no.  1375
# Attempting to remove reaction:  MMCDm ...
# Initial PM reactions: 8219
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  17.107173000025796
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['MMCDm']
# Zero-expression evidence for reaction...
# 8219
# 8219
# check_model_function done ....
# PM reactions (before): 8219
# Removed all inactive reactions
# PM reactions (after): 8218
# Num. removed: 2256 (297 core, 1959 non-core); Num. remaining: 4174
# Reaction no.  1376
# Attempting to remove reaction:  OPAH ...
# Initial PM reactions: 8218
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  16.43184899998596
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: ['r0568', 'NAIt', 'r2091'], inactive_NC:['OPAH']
# Zero-expression evidence for reaction...
# 8218
# 8218
# check_model_function done ....
# Len P: 4174
# num_removed 2256
# Len P AFTER 4173
# No reactions removed
# result 1.1
# Num. removed: 2256 (297 core, 1959 non-core); Num. remaining: 4173
# Reaction no.  1377
# Attempting to remove reaction:  HMR_4816 ...
# Initial PM reactions: 8218
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  16.682717999996385
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: [], inactive_NC:['HMR_4816', 'HMR_7906', 'EX_HC01361_e']
# Zero-expression evidence for reaction...
# 8218
# 8218
# check_model_function done ....
# PM reactions (before): 8218
# Removed all inactive reactions
# PM reactions (after): 8215
# Num. removed: 2259 (297 core, 1962 non-core); Num. remaining: 4170
# Reaction no.  1378
# Attempting to remove reaction:  HISTAVESSEC_1 ...
# Initial PM reactions: 8215
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  16.7691310000082
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: ['r1643'], inactive_NC:['EX_q10h2_e', 'HISTAVESSEC_1', 'Q10H2e']
# Zero-expression evidence for reaction...
# 8215
# 8215
# check_model_function done ....
# PM reactions (before): 8215
# Removed all inactive reactions
# PM reactions (after): 8211
# Num. removed: 2263 (298 core, 1965 non-core); Num. remaining: 4167
# Reaction no.  1379
# Attempting to remove reaction:  HMR_1897 ...
# Initial PM reactions: 8211
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  17.18375600001309
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: ['GDHm', 'NAIt', 'r1552'], inactive_NC:['HMR_1897', 'GLYtm']
# Zero-expression evidence for reaction...
# 8211
# 8211
# check_model_function done ....
# Len P: 4167
# num_removed 2263
# Len P AFTER 4166
# No reactions removed
# result 1.0
# Num. removed: 2263 (298 core, 1965 non-core); Num. remaining: 4166
# Reaction no.  1380
# Attempting to remove reaction:  L_LACt4r ...
# Initial PM reactions: 8211
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  16.02541200001724
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['L_LACt4r']
# Zero-expression evidence for reaction...
# 8211
# 8211
# check_model_function done ....
# PM reactions (before): 8211
# Removed all inactive reactions
# PM reactions (after): 8210
# Num. removed: 2264 (298 core, 1966 non-core); Num. remaining: 4165
# Reaction no.  1381
# Attempting to remove reaction:  RBK ...
# Initial PM reactions: 8210
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  16.806431999983033
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: ['r1631'], inactive_NC:['RBK']
# Zero-expression evidence for reaction...
# 8210
# 8210
# check_model_function done ....
# Len P: 4165
# num_removed 2264
# Len P AFTER 4164
# No reactions removed
# result 1.1
# Num. removed: 2264 (298 core, 1966 non-core); Num. remaining: 4164
# Reaction no.  1382
# Attempting to remove reaction:  UDPGP ...
# Initial PM reactions: 8210
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 5 blocked (inactive) reactions
# Execution time of check_model_consistency:  16.830337999999756
# check_model_consistency done ...
# Lengths all--> inactive_G: 6 , inactive_C: ['PTDCACRNCPT1', 'r2113', 'HMR_2624', 'PTDCACRNCPT2'], inactive_NC:['UDPGP', 'EX_ptdca_e']
# Zero-expression evidence for reaction...
# 8210
# 8210
# check_model_function done ....
# Len P: 4164
# num_removed 2264
# Len P AFTER 4163
# No reactions removed
# result 1.1
# Num. removed: 2264 (298 core, 1966 non-core); Num. remaining: 4163
# Reaction no.  1383
# Attempting to remove reaction:  GLYVESSEC_1 ...
# Initial PM reactions: 8210
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  15.821449999988545
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['GLYVESSEC_1']
# Zero-expression evidence for reaction...
# 8210
# 8210
# check_model_function done ....
# PM reactions (before): 8210
# Removed all inactive reactions
# PM reactions (after): 8209
# Num. removed: 2265 (298 core, 1967 non-core); Num. remaining: 4162
# Reaction no.  1384
# Attempting to remove reaction:  CRNCARtp ...
# Initial PM reactions: 8209
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 7 blocked (inactive) reactions
# Execution time of check_model_consistency:  16.268121000000974
# check_model_consistency done ...
# Lengths all--> inactive_G: 8 , inactive_C: ['r0074', 'NAIt', 'CARN180t_m', 'C180CPT2', 'ORNTArm', 'NKCC2t', 'ACRNtp'], inactive_NC:['CRNCARtp']
# Zero-expression evidence for reaction...
# 8209
# 8209
# check_model_function done ....
# Len P: 4162
# num_removed 2265
# Len P AFTER 4161
# No reactions removed
# result 1.1
# Num. removed: 2265 (298 core, 1967 non-core); Num. remaining: 4161
# Reaction no.  1385
# Attempting to remove reaction:  NADH2_u10mi ...
# Initial PM reactions: 8209
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  17.328956000012113
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: ['VALPHELAT2tc'], inactive_NC:['NADH2_u10mi', 'ACt2r']
# Zero-expression evidence for reaction...
# 8209
# 8209
# check_model_function done ....
# Len P: 4161
# num_removed 2265
# Len P AFTER 4160
# No reactions removed
# result 1.1
# Num. removed: 2265 (298 core, 1967 non-core); Num. remaining: 4160
# Reaction no.  1386
# Attempting to remove reaction:  XYLTer ...
# Initial PM reactions: 8209
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 108 blocked (inactive) reactions
# Execution time of check_model_consistency:  19.394868000003044
# check_model_consistency done ...
# Lengths all--> inactive_G: 109 , inactive_C: ['GLCAT8g', 'GLCAT2g', 'GALNACT1g', 'NACHEX9ly', 'UDPXYLtg', 'GLCNACT5g', 'IDOURtly', 'GLCNACASE5ly', 'GALNACT5g', 'S6TASE8ly', 'GALT2g', 'GLCAT6g', 'S3T3g', 'S6T25g', 'GLCNACT2g', 'GLCAT9g', 'GLCNACASE2ly', 'GLCNACT1g', 'NACHEX2ly', 'GLCNACASE3ly', 'S6TASE2ly', 'HMR_4124', 'GALNACT2g', 'GALTg', 'GALNACT3g', 'S6TASE1ly', 'CARN180t_m', 'S3T2g', 'S6TASE9ly', 'GLCNACDASg', 'UDPGLDCg', 'GLCAT7g', 'GLCAE2g', 'GLCAT3g', 'GLCNACASE1ly', 'GLCNACT4g', 'S2TASE2ly', 'GLCNACT3g', 'S2T4g', 'C180CPT2', 'S2TASE1ly', 'S4T1g', 'NACHEX8ly', 'S6TASE3ly', 'GLCAASE7ly', 'GLCAASE4ly', 'GLCAT5g', 'GLCAASE1ly', 'NACHEX1ly', 'S4T3g', 'GALNACT4g', 'GLCNACASE4ly', 'S4T2g', 'GLCAT4g'], inactive_NC:['S4TASE2ly', 'S3TASE1ly', 'S6T22g', 'CSPG_Dt', 'CSPG_At', 'HSAT4ly', 'HS4ly', 'S2T1g', 'S3TASE3ly', 'S2T2g', 'XSERtg', 'S6T23g', 'CSAPASEly', 'NACHEXA8ly', 'IDOAASE1ly', 'IDOAASE3ly', 'S6T19g', 'EX_idour_e', 'S4T5g', 'S4TASE1ly', 'HSPASEly', 'S3T1g', 'HS2ly', 'LINKDEG1ly', 'S6T20g', 'LINKDEG2ly', 'CO2tg', 'ACtg', 'LINKDEG4ly', 'IDOAASE2ly', 'S3TASE2ly', 'S6T21g', 'S4T4g', 'S4TASE5ly', 'CSPG_Atly', 'HSPGtly', 'IDOURte', 'CSEPASEly', 'HSAT2ly', 'NACHEXA7ly', 'GLCATg', 'CSPG_Ct', 'HSAT1ly', 'UDPGLCAtg', 'HS1ly', 'XYLTer', 'HSPGt', 'S4TASE4ly', 'HMR_7198', 'S6T24g', 'HSAT3ly', 'HS3ly', 'UDPXYLter', 'CSPG_Et', 'CSPG_Etly']
# Zero-expression evidence for reaction...
# 8209
# 8209
# check_model_function done ....
# Len P: 4160
# num_removed 2265
# Len P AFTER 4159
# No reactions removed
# result 1.1
# Num. removed: 2265 (298 core, 1967 non-core); Num. remaining: 4159
# Reaction no.  1387
# Attempting to remove reaction:  P45011A1m ...
# Initial PM reactions: 8209
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  16.96376600000076
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: ['INSt', 'r1630'], inactive_NC:['SK_HC02191_c', 'P45011A1m']
# Zero-expression evidence for reaction...
# 8209
# 8209
# check_model_function done ....
# Len P: 4159
# num_removed 2265
# Len P AFTER 4158
# No reactions removed
# result 1.1
# Num. removed: 2265 (298 core, 1967 non-core); Num. remaining: 4158
# Reaction no.  1388
# Attempting to remove reaction:  P45027A1m ...
# Initial PM reactions: 8209
# check_model_function done ....

# %%
len(PM.reactions)

# %%
len(PM.metabolites)

# %%
len(PM.genes)

# %%
pruneTime

# %%
from cobra import *
# write out PM model
io.write_sbml_model(PM,"python_recon3D_BEC1_method2.xml")
