# %%
__author__ = "Nantia Leonidou"
__description__ = " Main script "
########################################
# copied from run_mcadre.py
########################################

from mcadre.mcadre import *
from test_Inputs.test_Inputs import *
import pandas as pd

# read model
model = io.read_sbml_model('../pre_processing/dataset/RECON1.xml')
# genes
G = pd.read_csv('../pre_processing/dataset/1_GPL570_GSE3397/1_GPL570_GSE3397_entrez_ids.csv')
G = list(G['ENTREZ_GENE_ID'])
# ubiquity scores
U = pd.read_csv('../pre_processing/dataset/1_GPL570_GSE3397/1_GPL570_GSE3397_ubiquity.csv', header=None)
U = U.rename(columns={0: "Scores"})
U = list(U['Scores'])
# confidence scores
confidence_scores = get_test_inputs('../testInputs.mat','../humanModel.mat')[3]

# %%
from rank.rank_reactions import *
GM, C, NC, P, Z, model_C = rank_reactions(model, G, U, confidence_scores, [], 2)
# Out:
# /Users/leonidou/Documents/mCADRE_PYTHON_code/code/rank/calc_expr_evidence.py:34 RuntimeWarning: All-NaN axis encountered
# /Users/leonidou/Documents/mCADRE_PYTHON_code/code/rank/calc_expr_evidence.py:58 RuntimeWarning: All-NaN axis encountered
# Checking all reactions (FASTCC)...
# Model consists of 1298 blocked (inactive) reactions
# Execution time of check_model_consistency:  18.370566999999994
# check_model_consistency done ...
# rank_reactions done ...

# %%
len(GM.reactions)
# Out:
# 2443

# %%
len(GM.metabolites)
# Out:
# 1586

# %%
len(GM.genes)
# Out:
# 1478

# %%
len(C)
# Out:
# 856

# %%
len(NC)
# Out:
# 1587

# %%
len(Z)
# Out:
# 471

# %%
len(model_C)
# Out:
# 1322

# %%
from prune.prune_model import *
print('Generic model passed precursor metabolites test')

##############################################################
# If generic functionality test is passed, prune reactions
###############################################################
print('Pruning reactions...')
t0 = process_time()
PM, cRes = prune_model(GM, P, C, Z, 1/3, '../pre_processing/dataset/key_metabolites_RECON1.txt', 1, 2)
# Stop the stopwatch / counter
t_stop = process_time()
# compute elapsed time
pruneTime = t_stop - t0
# Out:
# Generic model passed precursor metabolites test
# Pruning reactions...
# Reaction no.  1
# Attempting to remove reaction:  THMMPt4 ...
# Initial PM reactions: 2443
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 17 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.23020200000002
# check_model_consistency done ...
# Lengths all--> inactive_G: 18 , inactive_C: ['GALT', 'HSD17B1', 'ILETAm'], inactive_NC:['THMMPt4', 'EX_thmmp_e', 'TCHOLAte', 'UMPK3n', 'ILEtmi', 'ESTRADIOLtr', 'CYTK11', 'DCYTt', 'EX_dcyt_e', 'EX_25hvitd3_e', 'CLPNDCOAtx', 'CITRtm', 'CHLtm', 'ARACHCOAtx', 'LGNCCOAtx']
# Zero-expression evidence for reaction...
# 2443
# 2443
# check_model_function done ....
# PM reactions (before): 2443
# Removed all inactive reactions
# PM reactions (after): 2425
# Num. removed: 18 (3 core, 15 non-core); Num. remaining: 1572
# Reaction no.  2
# Attempting to remove reaction:  DCT ...
# Initial PM reactions: 2425
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 13 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.303672999999975
# check_model_consistency done ...
# Lengths all--> inactive_G: 14 , inactive_C: ['FACOAL226_copy1', 'COAtim'], inactive_NC:['GCHOLAte', 'DOPACHRMISO', 'DOPAQNISO1', 'MALSO3tm', 'TYRASE', 'EX_gmp_e', 'TYRDOPO3', 'EX_asn__L_e', 'EX_hista_e', 'DCT', 'EX_11_cis_retfa_e', 'DM_melanin_c']
# Zero-expression evidence for reaction...
# 2425
# 2425
# check_model_function done ....
# PM reactions (before): 2425
# Removed all inactive reactions
# PM reactions (after): 2411
# Num. removed: 32 (5 core, 27 non-core); Num. remaining: 1560
# Reaction no.  3
# Attempting to remove reaction:  ACOX22x ...
# Initial PM reactions: 2411
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 16 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.6848130000000197
# check_model_consistency done ...
# Lengths all--> inactive_G: 17 , inactive_C: ['MAN6PI', 'SUCOAS1m', 'SCP2x', 'UDPGLCAter'], inactive_NC:['ACOX22x', 'HSD17B42x', 'EX_dgchol_e', 'DGCHOLte', 'DGCHOLtx', 'EX_ha_e', 'ARACHt', 'BAAT3x', 'EX_inost_e', 'EX_ump_e', 'PCHOL_HSter', 'CYTK1n', 'AMACR2p']
# Zero-expression evidence for reaction...
# 2411
# 2411
# check_model_function done ....
# PM reactions (before): 2411
# Removed all inactive reactions
# PM reactions (after): 2394
# Num. removed: 49 (9 core, 40 non-core); Num. remaining: 1547
# Reaction no.  4
# Attempting to remove reaction:  AMACRp ...
# Initial PM reactions: 2394
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 33 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.9005900000000224
# check_model_consistency done ...
# Lengths all--> inactive_G: 34 , inactive_C: ['SCPx', 'ILEtec', 'FACOAL204_copy1', 'NDPK7n'], inactive_NC:['P45027A12m', 'BAAT2x', 'ACt2m', 'P4508B13r', 'TCHOLAtx', 'THCHOLSTOICtm', 'P45027A11m', 'XOLTRIOLtm', 'FADH2tx', 'XOLDIOLONEt', 'VLCSp', 'EX_tchola_e', 'AMACRp', 'P45027A13m', 'P4508B11r', 'HCO3Em', 'ACOX2x', 'AKR1C42', 'BAAT1x', 'G6PDH1er_copy2', 'EX_gchola_e', 'EX_dag_hs_e', 'EX_mag_hs_e', 'AKR1D2', 'GCHOLAtx', 'PROSTGE2t2', 'PE_HStm', 'FADtx', 'CITt4_4', 'HSD17B4x']
# Zero-expression evidence for reaction...
# 2394
# 2394
# check_model_function done ....
# PM reactions (before): 2394
# Removed all inactive reactions
# PM reactions (after): 2360
# Num. removed: 83 (13 core, 70 non-core); Num. remaining: 1517
# Reaction no.  5
# Attempting to remove reaction:  34DHPHEt ...
# Initial PM reactions: 2360
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 16 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.495880999999997
# check_model_consistency done ...
# Lengths all--> inactive_G: 17 , inactive_C: ['ALATA_L', 'DURIPP', 'ADK1m', 'UREAt'], inactive_NC:['34DHPHEt', 'HSD3A2r', 'DINt', 'GULNDer', 'EX_thf_e', 'TAURt4_2_r', 'EX_taur_e', 'EX_34dhphe_e', 'CYTK2n', 'INSTt4_2', 'Htx', 'PAIL4P_HStn', 'RAI4']
# Zero-expression evidence for reaction...
# 2360
# 2360
# check_model_function done ....
# PM reactions (before): 2360
# Removed all inactive reactions
# PM reactions (after): 2343
# Num. removed: 100 (17 core, 83 non-core); Num. remaining: 1504
# Reaction no.  6
# Attempting to remove reaction:  SRTNtu ...
# Initial PM reactions: 2343
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.6620890000000372
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['SRTNtu', 'CYTK12n']
# Zero-expression evidence for reaction...
# 2343
# 2343
# check_model_function done ....
# PM reactions (before): 2343
# Removed all inactive reactions
# PM reactions (after): 2341
# Num. removed: 102 (17 core, 85 non-core); Num. remaining: 1502
# Reaction no.  7
# Attempting to remove reaction:  DEBRISOQUINEt ...
# Initial PM reactions: 2341
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 13 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.2108539999999834
# check_model_consistency done ...
# Lengths all--> inactive_G: 14 , inactive_C: [], inactive_NC:['CHOLATEt', '4HDEBRISOQUINEte', 'EX_4hdebrisoquine_e', 'RADH', 'EX_adprib_e', 'GCHOLAt', 'P4502D6', 'CYTK9', 'DEBRISOQUINEt', 'EX_fru_e', 'TCHOLAt', 'EX_glygn5_e', 'FRUt1r', 'EX_debrisoquine_e']
# Zero-expression evidence for reaction...
# 2341
# 2341
# check_model_function done ....
# PM reactions (before): 2341
# Removed all inactive reactions
# PM reactions (after): 2327
# Num. removed: 116 (17 core, 99 non-core); Num. remaining: 1488
# Reaction no.  8
# Attempting to remove reaction:  CHATn ...
# Initial PM reactions: 2327
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.6321550000000116
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: ['FACOAL2252', 'TMDPP'], inactive_NC:['ACHtn', 'CHATn', 'ACCOAtn', 'CLPNDt', 'EX_clpnd_e', 'CHOLtn', 'COAtn', 'EX_retfa_e']
# Zero-expression evidence for reaction...
# 2327
# 2327
# check_model_function done ....
# PM reactions (before): 2327
# Removed all inactive reactions
# PM reactions (after): 2317
# Num. removed: 126 (19 core, 107 non-core); Num. remaining: 1480
# Reaction no.  9
# Attempting to remove reaction:  CSNt ...
# Initial PM reactions: 2317
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.7956219999999803
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: [], inactive_NC:['PAIL45P_HStn', 'CSND', 'CSNt', 'EX_csn_e']
# Zero-expression evidence for reaction...
# 2317
# 2317
# check_model_function done ....
# PM reactions (before): 2317
# Removed all inactive reactions
# PM reactions (after): 2313
# Num. removed: 130 (19 core, 111 non-core); Num. remaining: 1476
# Reaction no.  10
# Attempting to remove reaction:  5FTHFt2 ...
# Initial PM reactions: 2313
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 7 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.549277000000018
# check_model_consistency done ...
# Lengths all--> inactive_G: 8 , inactive_C: ['FACOAL2042', 'NDPK5n'], inactive_NC:['EX_5fthf_e', 'EX_eicostet_e', 'FTHFCL', '5FTHFt2', 'EX_9_cis_retfa_e', 'EICOSTETt']
# Zero-expression evidence for reaction...
# 2313
# 2313
# check_model_function done ....
# PM reactions (before): 2313
# Removed all inactive reactions
# PM reactions (after): 2305
# Num. removed: 138 (21 core, 117 non-core); Num. remaining: 1470
# Reaction no.  11
# Attempting to remove reaction:  ADPRIBt ...
# Initial PM reactions: 2305
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 11 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.5874519999999848
# check_model_consistency done ...
# Lengths all--> inactive_G: 12 , inactive_C: ['D_LACt2'], inactive_NC:['EX_cytd_e', 'EX_nad_e', 'ADPRIBt', 'EX_gluala_e', 'CYTK10', 'EX_glyb_e', 'EX_lac__D_e', 'NADNe', 'UMPK7n', 'GLYBt4_2_r', 'CYTK2_1']
# Zero-expression evidence for reaction...
# 2305
# 2305
# check_model_function done ....
# PM reactions (before): 2305
# Removed all inactive reactions
# PM reactions (after): 2293
# Num. removed: 150 (22 core, 128 non-core); Num. remaining: 1459
# Reaction no.  12
# Attempting to remove reaction:  PGDI ...
# Initial PM reactions: 2293
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 18 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.340321000000017
# check_model_consistency done ...
# Lengths all--> inactive_G: 19 , inactive_C: ['MTHFDm', 'RDH2a', 'NDPK4m', 'PGS'], inactive_NC:['MALTSULtm', 'HYXNt', 'RETI1', 'PROSTGD2t', 'FUMtm', '5MTHFt2', 'EX_ncam_e', 'EX_uri_e', 'EX_hxan_e', 'EX_gsn_e', 'EX_drib_e', 'DRIBt', 'EX_gal_e', 'PGDI', 'EX_prostgd2_e']
# Zero-expression evidence for reaction...
# 2293
# 2293
# check_model_function done ....
# PM reactions (before): 2293
# Removed all inactive reactions
# PM reactions (after): 2274
# Num. removed: 169 (26 core, 143 non-core); Num. remaining: 1444
# Reaction no.  13
# Attempting to remove reaction:  THMTPt ...
# Initial PM reactions: 2274
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 24 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.2663200000000074
# check_model_consistency done ...
# Lengths all--> inactive_G: 25 , inactive_C: ['5MTHFt', 'THYOXt2', 'THMt3', 'FBA', 'DCK2n', 'GGH_6THFe', 'GGH_5THFe', 'GGH_7THFe', 'FOLR2'], inactive_NC:['DOPAtu', 'EX_7thf_e', 'EX_fol_e', 'EX_5mthf_e', 'EX_thmtp_e', 'TRPt', 'ARACHDt2', 'EX_thm_e', 'FOLt2', 'NRPPHRtu', 'THFt2', 'CLOHtex2', 'EX_retinol_e', 'THMTPt', 'RDH4', 'RETI3']
# Zero-expression evidence for reaction...
# 2274
# 2274
# check_model_function done ....
# Len P: 1444
# num_removed 169
# Len P AFTER 1443
# No reactions removed
# result 1.1
# Num. removed: 169 (26 core, 143 non-core); Num. remaining: 1443
# Reaction no.  14
# Attempting to remove reaction:  AGTix ...
# Initial PM reactions: 2274
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 26 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.995228999999995
# check_model_consistency done ...
# Lengths all--> inactive_G: 27 , inactive_C: ['DHAAt1r', 'HPYRR2x', 'MANt1r', 'NKCCt', 'HPYRRy', 'DCMPDA'], inactive_NC:['THFtm', 'GLYCK2', 'EX_gdchola_e', 'H2Oter', 'DTTPtn', 'HPYRDC', 'GLYOp', 'AGTix', 'DOPAtu', 'GDCHOLAte', 'EX_glyc__S_e', 'GLYC_St', 'LGNCt', 'SPTix', 'HPYRtp', 'Htr', 'SERtp', 'PROt4_2_r', 'BAAT4x', 'GDCHOLAtx', 'TRPt']
# Zero-expression evidence for reaction...
# 2274
# 2274
# check_model_function done ....
# PM reactions (before): 2274
# Removed all inactive reactions
# PM reactions (after): 2247
# Num. removed: 196 (32 core, 164 non-core); Num. remaining: 1422
# Reaction no.  15
# Attempting to remove reaction:  PROSTGF2t ...
# Initial PM reactions: 2247
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.330975999999964
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: ['VALtec', 'CBR2', 'XYLUR'], inactive_NC:['EX_pro__L_e', 'PROSTGF2t', 'RETI2', 'H2O2tm', 'EX_prostgf2_e', 'EX_prostge2_e', 'PROtm']
# Zero-expression evidence for reaction...
# 2247
# 2247
# check_model_function done ....
# Len P: 1422
# num_removed 196
# Len P AFTER 1421
# No reactions removed
# result 1.1
# Num. removed: 196 (32 core, 164 non-core); Num. remaining: 1421
# Reaction no.  16
# Attempting to remove reaction:  ACGAM2E ...
# Initial PM reactions: 2247
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 16 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.7104139999999575
# check_model_consistency done ...
# Lengths all--> inactive_G: 17 , inactive_C: ['UAG2EMA', 'VALtec', 'ACNAMlt', 'GALASE1ly', 'AHEXASEly', 'SIAASEly', 'GASNASEly', 'FUCASEe'], inactive_NC:['ABTD', 'ACGAM2E', 'ARACHDt2', 'S2L2N2M2MASNtly', 'EX_s2l2fn2m2masn_e', 'ENGASEly', 'EX_so4_e', 'UMPK6n', 'GALtly']
# Zero-expression evidence for reaction...
# 2247
# 2247
# check_model_function done ....
# Len P: 1421
# num_removed 196
# Len P AFTER 1420
# No reactions removed
# result 1.1
# Num. removed: 196 (32 core, 164 non-core); Num. remaining: 1420
# Reaction no.  17
# Attempting to remove reaction:  THYMt ...
# Initial PM reactions: 2247
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.748888000000022
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: [], inactive_NC:['DHPM2', 'THYMt', 'NRPPHRtu', 'EX_sph1p_e', 'EX_3aib__D_e', 'D_3AIBt', 'BUP2', 'EX_thym_e', 'DURAD2', 'SPH1Pte']
# Zero-expression evidence for reaction...
# 2247
# 2247
# check_model_function done ....
# PM reactions (before): 2247
# Removed all inactive reactions
# PM reactions (after): 2237
# Num. removed: 206 (32 core, 174 non-core); Num. remaining: 1410
# Reaction no.  18
# Attempting to remove reaction:  HIStiDF ...
# Initial PM reactions: 2237
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.183334000000002
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: [], inactive_NC:['HIStiDF', 'GALt2_2', 'CRVNCtr', 'ARACHDt2', 'UMPK5']
# Zero-expression evidence for reaction...
# 2237
# 2237
# check_model_function done ....
# PM reactions (before): 2237
# Removed all inactive reactions
# PM reactions (after): 2232
# Num. removed: 211 (32 core, 179 non-core); Num. remaining: 1405
# Reaction no.  19
# Attempting to remove reaction:  LCAT1e ...
# Initial PM reactions: 2232
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 12 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.3108819999999923
# check_model_consistency done ...
# Lengths all--> inactive_G: 13 , inactive_C: ['LALDO', 'ALAR', 'LALDD'], inactive_NC:['EX_xolest2_hs_e', 'CPK1', 'SUCCt4_3', 'OCDCAt', 'LCAT1e', 'CHSTEROLt', 'ORNt3m', 'CYTK13', 'BILDGLCURte', 'GLYCt']
# Zero-expression evidence for reaction...
# 2232
# 2232
# check_model_function done ....
# PM reactions (before): 2232
# Removed all inactive reactions
# PM reactions (after): 2219
# Num. removed: 224 (35 core, 189 non-core); Num. remaining: 1395
# Reaction no.  20
# Attempting to remove reaction:  FOLt2 ...
# Initial PM reactions: 2219
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 7 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.715161999999964
# check_model_consistency done ...
# Lengths all--> inactive_G: 8 , inactive_C: ['CYTDt', 'FOLR2'], inactive_NC:['ABTD', 'EX_fol_e', 'FOLt2', 'CYTK8', 'RIBt', 'UMPK6n']
# Zero-expression evidence for reaction...
# 2219
# 2219
# check_model_function done ....
# PM reactions (before): 2219
# Removed all inactive reactions
# PM reactions (after): 2211
# Num. removed: 232 (37 core, 195 non-core); Num. remaining: 1389
# Reaction no.  21
# Attempting to remove reaction:  NNMT ...
# Initial PM reactions: 2211
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 13 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.439497000000017
# check_model_consistency done ...
# Lengths all--> inactive_G: 14 , inactive_C: ['NP1', 'NDPK7m'], inactive_NC:['NADPNe', 'EX_adprbp_e', 'NNDPR', 'NACt', 'EX_1mncam_e', 'NNMT', '1MNCAMti', 'EX_nac_e', 'NADS2', 'NCAMUP', 'QUILSYN', 'EX_nadp_e']
# Zero-expression evidence for reaction...
# 2211
# 2211
# check_model_function done ....
# PM reactions (before): 2211
# Removed all inactive reactions
# PM reactions (after): 2197
# Num. removed: 246 (39 core, 207 non-core); Num. remaining: 1377
# Reaction no.  22
# Attempting to remove reaction:  URAt ...
# Initial PM reactions: 2197
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 8 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.0324620000000095
# check_model_consistency done ...
# Lengths all--> inactive_G: 9 , inactive_C: ['DCK1n', 'PHEtec', 'FACOAL1831'], inactive_NC:['PPItr', 'EX_lnlncg_e', 'UMPK2', 'EX_ura_e', 'URAt', 'LNLNCGt']
# Zero-expression evidence for reaction...
# 2197
# 2197
# check_model_function done ....
# Len P: 1377
# num_removed 246
# Len P AFTER 1376
# No reactions removed
# result 1.1
# Num. removed: 246 (39 core, 207 non-core); Num. remaining: 1376
# Reaction no.  23
# Attempting to remove reaction:  GUAt ...
# Initial PM reactions: 2197
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 7 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.3762290000000235
# check_model_consistency done ...
# Lengths all--> inactive_G: 8 , inactive_C: ['DCK1n'], inactive_NC:['GUAt', 'ADKd', 'EX_gua_e', 'UMPK7', 'UMPK2', 'DCSPTN1COAtx', 'ADK3']
# Zero-expression evidence for reaction...
# 2197
# 2197
# check_model_function done ....
# PM reactions (before): 2197
# Removed all inactive reactions
# PM reactions (after): 2189
# Num. removed: 254 (40 core, 214 non-core); Num. remaining: 1369
# Reaction no.  24
# Attempting to remove reaction:  L_LACtcm ...
# Initial PM reactions: 2189
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 10 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.2689230000000293
# check_model_consistency done ...
# Lengths all--> inactive_G: 11 , inactive_C: ['PUNP4', 'NDPK8m', 'FACOAL184', 'FACOAL1831'], inactive_NC:['EX_lnlncg_e', 'TYRt', 'THRGLNexR', 'L_LACtcm', 'STRDNCt', 'LNLNCGt', 'EX_strdnc_e']
# Zero-expression evidence for reaction...
# 2189
# 2189
# check_model_function done ....
# Len P: 1369
# num_removed 254
# Len P AFTER 1368
# No reactions removed
# result 1.1
# Num. removed: 254 (40 core, 214 non-core); Num. remaining: 1368
# Reaction no.  25
# Attempting to remove reaction:  AMETt2m ...
# Initial PM reactions: 2189
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 25 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.694080999999983
# check_model_consistency done ...
# Lengths all--> inactive_G: 26 , inactive_C: ['NDPK3m', 'PETOHMm_hs', 'CYTDtm', 'CDSm'], inactive_NC:['AMETt2m', 'GLYBtm', 'PCHOLPm_hs', 'CHOLD2m', 'PCFLOPm', 'CDPDAGtm', 'PEFLIPm', 'PSDm_hs', 'EX_man_e', 'FALDtm', 'EX_pydx_e', 'GLCter', 'BETALDHxm', 'DMGtm', 'CYTK1m', 'DMGDHm', 'BHMT', 'PYDXtr', 'MANt4', 'UMPK5n', 'PSFLIPm', 'CYTDK2m']
# Zero-expression evidence for reaction...
# 2189
# 2189
# check_model_function done ....
# PM reactions (before): 2189
# Removed all inactive reactions
# PM reactions (after): 2163
# Num. removed: 280 (44 core, 236 non-core); Num. remaining: 1346
# Reaction no.  26
# Attempting to remove reaction:  TXASr ...
# Initial PM reactions: 2163
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 6 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.625103999999965
# check_model_consistency done ...
# Lengths all--> inactive_G: 7 , inactive_C: ['PGSr'], inactive_NC:['TXA2tr', 'TXASr', 'ARACHDtr', 'EX_txa2_e', 'EX_so4_e', 'TXA2te']
# Zero-expression evidence for reaction...
# 2163
# 2163
# check_model_function done ....
# PM reactions (before): 2163
# Removed all inactive reactions
# PM reactions (after): 2156
# Num. removed: 287 (45 core, 242 non-core); Num. remaining: 1340
# Reaction no.  27
# Attempting to remove reaction:  SERDGLYexR ...
# Initial PM reactions: 2156
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.6545540000000756
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: ['PUNP2'], inactive_NC:['SERDGLYexR', 'PPItr', 'CYTK14n', 'SERDGLNexR']
# Zero-expression evidence for reaction...
# 2156
# 2156
# check_model_function done ....
# PM reactions (before): 2156
# Removed all inactive reactions
# PM reactions (after): 2151
# Num. removed: 292 (46 core, 246 non-core); Num. remaining: 1336
# Reaction no.  28
# Attempting to remove reaction:  TYRt ...
# Initial PM reactions: 2151
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 5 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.4600169999999935
# check_model_consistency done ...
# Lengths all--> inactive_G: 6 , inactive_C: ['VALtec', 'NDPK7'], inactive_NC:['ESTRONESt', 'TYRt', 'UMPK2n', 'CYTK3']
# Zero-expression evidence for reaction...
# 2151
# 2151
# check_model_function done ....
# Len P: 1336
# num_removed 292
# Len P AFTER 1335
# No reactions removed
# result 1.1
# Num. removed: 292 (46 core, 246 non-core); Num. remaining: 1335
# Reaction no.  29
# Attempting to remove reaction:  CYTK6n ...
# Initial PM reactions: 2151
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 5 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.968119999999999
# check_model_consistency done ...
# Lengths all--> inactive_G: 6 , inactive_C: ['PUNP4'], inactive_NC:['EX_pro__L_e', 'ALAGLNexR', 'EX_lys__L_e', 'CYTK6n', 'PROtm']
# Zero-expression evidence for reaction...
# 2151
# 2151
# check_model_function done ....
# PM reactions (before): 2151
# Removed all inactive reactions
# PM reactions (after): 2145
# Num. removed: 298 (47 core, 251 non-core); Num. remaining: 1330
# Reaction no.  30
# Attempting to remove reaction:  It ...
# Initial PM reactions: 2145
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.302236999999991
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: ['FACOAL203', 'PDX5POi', 'GDHm'], inactive_NC:['EX_dlnlcg_e', 'SERGLYexR', 'FATP6t', 'PYDXNtr', 'EX_pydxn_e', 'It', 'DLNLCGt']
# Zero-expression evidence for reaction...
# 2145
# 2145
# check_model_function done ....
# Len P: 1330
# num_removed 298
# Len P AFTER 1329
# No reactions removed
# result 1.1
# Num. removed: 298 (47 core, 251 non-core); Num. remaining: 1329
# Reaction no.  31
# Attempting to remove reaction:  ADEt ...
# Initial PM reactions: 2145
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.3965580000000273
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: [], inactive_NC:['CYTK3n', 'EX_ade_e', 'ADRNt', 'ADEt', 'CYTK7n']
# Zero-expression evidence for reaction...
# 2145
# 2145
# check_model_function done ....
# PM reactions (before): 2145
# Removed all inactive reactions
# PM reactions (after): 2140
# Num. removed: 303 (47 core, 256 non-core); Num. remaining: 1324
# Reaction no.  32
# Attempting to remove reaction:  CYTK3 ...
# Initial PM reactions: 2140
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.0019399999999905
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: ['FUM', 'NDPK8m'], inactive_NC:['CYTK7', 'CYTK3']
# Zero-expression evidence for reaction...
# 2140
# 2140
# check_model_function done ....
# Len P: 1324
# num_removed 303
# Len P AFTER 1323
# No reactions removed
# result 1.1
# Num. removed: 303 (47 core, 256 non-core); Num. remaining: 1323
# Reaction no.  33
# Attempting to remove reaction:  CYTK9n ...
# Initial PM reactions: 2140
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 12 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.7465440000000854
# check_model_consistency done ...
# Lengths all--> inactive_G: 13 , inactive_C: ['RPI', 'DCK2n', 'ADNt', 'NDPK2n'], inactive_NC:['EX_lac__L_e', 'CYTK13n', 'THRGLNexR', 'DURItn', 'UMPKn', 'EX_dgsn_e', 'DCYTDn', 'DGSNt', 'CYTK9n']
# Zero-expression evidence for reaction...
# 2140
# 2140
# check_model_function done ....
# Len P: 1323
# num_removed 303
# Len P AFTER 1322
# No reactions removed
# result 1.1
# Num. removed: 303 (47 core, 256 non-core); Num. remaining: 1322
# Reaction no.  34
# Attempting to remove reaction:  CYTK8n ...
# Initial PM reactions: 2140
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.919538999999986
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: ['L_LACt2r'], inactive_NC:['CYTK8n', 'UMPK4n']
# Zero-expression evidence for reaction...
# 2140
# 2140
# check_model_function done ....
# Len P: 1322
# num_removed 303
# Len P AFTER 1321
# No reactions removed
# result 1.1
# Num. removed: 303 (47 core, 256 non-core); Num. remaining: 1321
# Reaction no.  35
# Attempting to remove reaction:  CYTK10n ...
# Initial PM reactions: 2140
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 11 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.9115639999999985
# check_model_consistency done ...
# Lengths all--> inactive_G: 12 , inactive_C: ['VALtec', 'FACOAL205', 'ADNt', 'PHEtec'], inactive_NC:['CYTK11n', 'H2O2tp', 'ESTRONESt', 'TMNDNCt', 'CYTK10n', 'XYLTt', 'EX_tmndnc_e', 'EX_xylt_e']
# Zero-expression evidence for reaction...
# 2140
# 2140
# check_model_function done ....
# Len P: 1321
# num_removed 303
# Len P AFTER 1320
# No reactions removed
# result 1.1
# Num. removed: 303 (47 core, 256 non-core); Num. remaining: 1320
# Reaction no.  36
# Attempting to remove reaction:  CYTK5n ...
# Initial PM reactions: 2140
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.242843999999991
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: ['LDH_Lm'], inactive_NC:['CYTK5n', 'UMPK4n']
# Zero-expression evidence for reaction...
# 2140
# 2140
# check_model_function done ....
# Len P: 1320
# num_removed 303
# Len P AFTER 1319
# No reactions removed
# result 1.1
# Num. removed: 303 (47 core, 256 non-core); Num. remaining: 1319
# Reaction no.  37
# Attempting to remove reaction:  ALADGLYexR ...
# Initial PM reactions: 2140
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.854286000000002
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: ['VALtec'], inactive_NC:['ALADGLYexR', 'UMPK4n']
# Zero-expression evidence for reaction...
# 2140
# 2140
# check_model_function done ....
# Len P: 1319
# num_removed 303
# Len P AFTER 1318
# No reactions removed
# result 1.1
# Num. removed: 303 (47 core, 256 non-core); Num. remaining: 1318
# Reaction no.  38
# Attempting to remove reaction:  HISDr ...
# Initial PM reactions: 2140
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.1904859999999644
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: [], inactive_NC:['GluForTx', 'URCN', 'IZPN', 'HISDr', 'FTCD']
# Zero-expression evidence for reaction...
# 2140
# 2140
# check_model_function done ....
# PM reactions (before): 2140
# Removed all inactive reactions
# PM reactions (after): 2135
# Num. removed: 308 (47 core, 261 non-core); Num. remaining: 1313
# Reaction no.  39
# Attempting to remove reaction:  GCC2bim ...
# Initial PM reactions: 2135
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.0634240000000545
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: ['PPM'], inactive_NC:['GCC2cm', 'TYRt', 'GCC2am', 'GCC2bim']
# Zero-expression evidence for reaction...
# 2135
# 2135
# check_model_function done ....
# PM reactions (before): 2135
# Removed all inactive reactions
# PM reactions (after): 2130
# Num. removed: 313 (48 core, 265 non-core); Num. remaining: 1310
# Reaction no.  40
# Attempting to remove reaction:  GCCbim ...
# Initial PM reactions: 2130
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.5529599999999846
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: ['THYOXt2'], inactive_NC:['GCCam', 'GCCcm', 'GCCbim']
# Zero-expression evidence for reaction...
# 2130
# 2130
# check_model_function done ....
# PM reactions (before): 2130
# Removed all inactive reactions
# PM reactions (after): 2126
# Num. removed: 317 (49 core, 268 non-core); Num. remaining: 1307
# Reaction no.  41
# Attempting to remove reaction:  BCDO ...
# Initial PM reactions: 2126
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.2789880000000267
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: ['PDX5POi', 'HSD11B1r'], inactive_NC:['CAROtr', 'BCDO', 'RETI2', 'PYDXNtr', 'HSD11B2r', 'EX_pydxn_e', 'EX_caro_e', 'UMPKn']
# Zero-expression evidence for reaction...
# 2126
# 2126
# check_model_function done ....
# PM reactions (before): 2126
# Removed all inactive reactions
# PM reactions (after): 2116
# Num. removed: 327 (51 core, 276 non-core); Num. remaining: 1299
# Reaction no.  42
# Attempting to remove reaction:  ALOX5 ...
# Initial PM reactions: 2116
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 12 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.636394999999993
# check_model_consistency done ...
# Lengths all--> inactive_G: 13 , inactive_C: ['LTC4Sr'], inactive_NC:['ALOX52', 'EX_leuktrC4_e', 'LTD4DP', 'LTC4CP', 'LEUKTRA4tr', 'GGT5r', 'ALOX5', 'LEUKTRC4t', 'GTHRDtr', 'GGT6', 'LEUKTRD4tr', 'GLUtr']
# Zero-expression evidence for reaction...
# 2116
# 2116
# check_model_function done ....
# PM reactions (before): 2116
# Removed all inactive reactions
# PM reactions (after): 2103
# Num. removed: 340 (52 core, 288 non-core); Num. remaining: 1287
# Reaction no.  43
# Attempting to remove reaction:  TRPO2 ...
# Initial PM reactions: 2103
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 8 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.288825999999972
# check_model_consistency done ...
# Lengths all--> inactive_G: 9 , inactive_C: ['HKYNH'], inactive_NC:['EX_ala__L_e', 'AMCOXO', 'TRPO2', 'FKYNH', '3HAO', 'KYN3OX', 'PCLAD', 'AM6SAD']
# Zero-expression evidence for reaction...
# 2103
# 2103
# check_model_function done ....
# PM reactions (before): 2103
# Removed all inactive reactions
# PM reactions (after): 2094
# Num. removed: 349 (53 core, 296 non-core); Num. remaining: 1279
# Reaction no.  44
# Attempting to remove reaction:  UMPK2n ...
# Initial PM reactions: 2094
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.8500980000000027
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: ['NDPK3n'], inactive_NC:['UMPK2n', 'UMPK4n']
# Zero-expression evidence for reaction...
# 2094
# 2094
# check_model_function done ....
# Len P: 1279
# num_removed 349
# Len P AFTER 1278
# No reactions removed
# result 1.1
# Num. removed: 349 (53 core, 296 non-core); Num. remaining: 1278
# Reaction no.  45
# Attempting to remove reaction:  THFt2 ...
# Initial PM reactions: 2094
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 7 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.5928159999999707
# check_model_consistency done ...
# Lengths all--> inactive_G: 8 , inactive_C: ['5MTHFt', 'GGH_6THFe', 'GGH_7THFe', 'GGH_5THFe'], inactive_NC:['EX_7thf_e', 'THFt2', 'EX_5mthf_e', 'PCt']
# Zero-expression evidence for reaction...
# 2094
# 2094
# check_model_function done ....
# Len P: 1278
# num_removed 349
# Len P AFTER 1277
# No reactions removed
# result 1.1
# Num. removed: 349 (53 core, 296 non-core); Num. remaining: 1277
# Reaction no.  46
# Attempting to remove reaction:  UMPK4n ...
# Initial PM reactions: 2094
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 6 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.430302999999981
# check_model_consistency done ...
# Lengths all--> inactive_G: 7 , inactive_C: ['NDPK3n'], inactive_NC:['HIStN1', 'UMPK4n', 'EX_dgsn_e', 'UMPK2n', 'CYTK5n', 'DGSNt']
# Zero-expression evidence for reaction...
# 2094
# 2094
# check_model_function done ....
# PM reactions (before): 2094
# Removed all inactive reactions
# PM reactions (after): 2087
# Num. removed: 356 (54 core, 302 non-core); Num. remaining: 1273
# Reaction no.  47
# Attempting to remove reaction:  TYRDOPO ...
# Initial PM reactions: 2087
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 5 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.0834239999999227
# check_model_consistency done ...
# Lengths all--> inactive_G: 6 , inactive_C: ['FBA', 'ALAtN1'], inactive_NC:['TYRDOPO', 'ABUTt2r', 'RPE', 'SO4t4_2']
# Zero-expression evidence for reaction...
# 2087
# 2087
# check_model_function done ....
# Len P: 1273
# num_removed 356
# Len P AFTER 1272
# No reactions removed
# result 1.1
# Num. removed: 356 (54 core, 302 non-core); Num. remaining: 1272
# Reaction no.  48
# Attempting to remove reaction:  SO4OXAtex2 ...
# Initial PM reactions: 2087
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 10 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.761470000000031
# check_model_consistency done ...
# Lengths all--> inactive_G: 11 , inactive_C: ['FACOAL203', 'PGMT'], inactive_NC:['MEOHt2', 'EX_meoh_e', 'EX_dlnlcg_e', 'DOPAt4_2_r', 'L_LACt4r', 'SO4OXAtex2', 'RADH3', 'DLNLCGt', 'EX_pi_e']
# Zero-expression evidence for reaction...
# 2087
# 2087
# check_model_function done ....
# Len P: 1272
# num_removed 356
# Len P AFTER 1271
# No reactions removed
# result 1.0
# Num. removed: 356 (54 core, 302 non-core); Num. remaining: 1271
# Reaction no.  49
# Attempting to remove reaction:  TYR3MO2 ...
# Initial PM reactions: 2087
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.8072839999999815
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: [], inactive_NC:['MEOHt2', 'EX_meoh_e', 'TYR3MO2']
# Zero-expression evidence for reaction...
# 2087
# 2087
# check_model_function done ....
# PM reactions (before): 2087
# Removed all inactive reactions
# PM reactions (after): 2084
# Num. removed: 359 (54 core, 305 non-core); Num. remaining: 1268
# Reaction no.  50
# Attempting to remove reaction:  THRGLYexR ...
# Initial PM reactions: 2084
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.1180440000000544
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: ['L_LACt2r'], inactive_NC:['EX_cys__L_e', 'EX_dopa_e', 'THRGLYexR']
# Zero-expression evidence for reaction...
# 2084
# 2084
# check_model_function done ....
# PM reactions (before): 2084
# Removed all inactive reactions
# PM reactions (after): 2080
# Num. removed: 363 (55 core, 308 non-core); Num. remaining: 1265
# Reaction no.  51
# Attempting to remove reaction:  BAAT5x ...
# Initial PM reactions: 2080
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 32 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.211636999999996
# check_model_consistency done ...
# Lengths all--> inactive_G: 33 , inactive_C: ['SCP3x'], inactive_NC:['PAN4PP', 'AKR1D', 'CYSAMO', 'NAtx', 'P4507A1r', 'H2Otly', 'LCYSTCBOXL', 'EX_gln__L_e', 'EX_tdchola_e', 'PCRNtm', '3SALACBOXL', 'TAURtcx', 'P45027A15m', 'XOL7AH2tm', 'AKR1C41', 'PNTEH', 'VLCS2p', 'CSNAT2m', 'P45027A14m', 'CRNCAR3tp', 'CSNAT3x', 'DHCHOLESTANATEtm', 'XOL7AONEtr', 'HYPTROX', 'HSD3B7', 'TDCHOLAtx', 'HSD3B7P', 'TDCHOLAte', 'AMPtp', 'P45027A16m', 'BAAT5x', 'EX_ach_e']
# Zero-expression evidence for reaction...
# 2080
# 2080
# check_model_function done ....
# PM reactions (before): 2080
# Removed all inactive reactions
# PM reactions (after): 2047
# Num. removed: 396 (56 core, 340 non-core); Num. remaining: 1233
# Reaction no.  52
# Attempting to remove reaction:  CYTK13n ...
# Initial PM reactions: 2047
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.9968240000000606
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: ['FACOAL203', 'LDH_Lm'], inactive_NC:['CYTK13n', 'DLNLCGt', 'EX_dlnlcg_e']
# Zero-expression evidence for reaction...
# 2047
# 2047
# check_model_function done ....
# Len P: 1233
# num_removed 396
# Len P AFTER 1232
# No reactions removed
# result 1.1
# Num. removed: 396 (56 core, 340 non-core); Num. remaining: 1232
# Reaction no.  53
# Attempting to remove reaction:  CYTK11n ...
# Initial PM reactions: 2047
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.10454500000003
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['CYTK10n', 'CYTK11n']
# Zero-expression evidence for reaction...
# 2047
# 2047
# check_model_function done ....
# PM reactions (before): 2047
# Removed all inactive reactions
# PM reactions (after): 2045
# Num. removed: 398 (56 core, 342 non-core); Num. remaining: 1231
# Reaction no.  54
# Attempting to remove reaction:  CYTK4n ...
# Initial PM reactions: 2045
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 5 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.549180999999976
# check_model_consistency done ...
# Lengths all--> inactive_G: 6 , inactive_C: ['FBA', 'NDPK1n'], inactive_NC:['EX_xylt_e', 'CYTK4n', 'XYLTt', 'CYTK3']
# Zero-expression evidence for reaction...
# 2045
# 2045
# check_model_function done ....
# Len P: 1231
# num_removed 398
# Len P AFTER 1230
# No reactions removed
# result 1.1
# Num. removed: 398 (56 core, 342 non-core); Num. remaining: 1230
# Reaction no.  55
# Attempting to remove reaction:  CYTK7 ...
# Initial PM reactions: 2045
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.9139840000000277
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['CYTK7']
# Zero-expression evidence for reaction...
# 2045
# 2045
# check_model_function done ....
# PM reactions (before): 2045
# Removed all inactive reactions
# PM reactions (after): 2044
# Num. removed: 399 (56 core, 343 non-core); Num. remaining: 1229
# Reaction no.  56
# Attempting to remove reaction:  34HPPOR ...
# Initial PM reactions: 2044
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.9398740000000316
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: ['MACACI', 'TYRTA', 'FUMAC'], inactive_NC:['34HPPOR', 'HGNTOR']
# Zero-expression evidence for reaction...
# 2044
# 2044
# check_model_function done ....
# Len P: 1229
# num_removed 399
# Len P AFTER 1228
# No reactions removed
# result 1.1
# Num. removed: 399 (56 core, 343 non-core); Num. remaining: 1228
# Reaction no.  57
# Attempting to remove reaction:  ALADGLNexR ...
# Initial PM reactions: 2044
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 5 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.919781999999941
# check_model_consistency done ...
# Lengths all--> inactive_G: 6 , inactive_C: ['FACOAL205', 'RPI'], inactive_NC:['C226COAtx', 'ALADGLNexR', 'TMNDNCt', 'EX_tmndnc_e']
# Zero-expression evidence for reaction...
# 2044
# 2044
# check_model_function done ....
# Len P: 1228
# num_removed 399
# Len P AFTER 1227
# No reactions removed
# result 1.1
# Num. removed: 399 (56 core, 343 non-core); Num. remaining: 1227
# Reaction no.  58
# Attempting to remove reaction:  THRD_L ...
# Initial PM reactions: 2044
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.331790000000069
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: ['NDPK5m'], inactive_NC:['CYTK13n', 'THRD_L', 'EX_thr__L_e', 'ALADGLYexR']
# Zero-expression evidence for reaction...
# 2044
# 2044
# check_model_function done ....
# PM reactions (before): 2044
# Removed all inactive reactions
# PM reactions (after): 2039
# Num. removed: 404 (57 core, 347 non-core); Num. remaining: 1225
# Reaction no.  59
# Attempting to remove reaction:  CSNATp ...
# Initial PM reactions: 2039
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 34 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.2260630000000674
# check_model_consistency done ...
# Lengths all--> inactive_G: 35 , inactive_C: ['HMGLx'], inactive_NC:['FAOXC2452253x', 'FAOXC180x', 'DESAT22_1p', 'TMNDNCCOAtx', 'TETPENT6COAtx', 'FAOXC2251836x', 'ARACHDCOAtx', 'FAOXC200180x', 'ODECOAtx', 'TETHEX3COAtx', 'DESAT22_2p', 'FAOXC240200x', 'TETPENT3COAtx', 'FAOXC16080x', 'TETTET6COAtx', 'CRNCARtp', 'FAOXC260240x', 'ACACtx', 'FAOXC183806x', 'FAOXC2051843x', 'FAOXC241181x', 'OCCOAtx', 'FAOXC2442246x', 'C226COAtx', 'NRVNCCOAtx', 'FAOXC18480x', 'CSNATp', 'FAOXC2452256x', 'FAOXC2242046x', 'ADRNCOAtx', 'FAOXC246226x', 'HEXCCOAtx', 'FAOXC226205x', 'FAOXC2252053x']
# Zero-expression evidence for reaction...
# 2039
# 2039
# check_model_function done ....
# PM reactions (before): 2039
# Removed all inactive reactions
# PM reactions (after): 2004
# Num. removed: 439 (58 core, 381 non-core); Num. remaining: 1191
# Reaction no.  60
# Attempting to remove reaction:  UMPK3 ...
# Initial PM reactions: 2004
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.163392999999928
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: ['FACOAL1831'], inactive_NC:['UMPK3', 'EX_ins_e', 'LNLNCGt', 'EX_lnlncg_e']
# Zero-expression evidence for reaction...
# 2004
# 2004
# check_model_function done ....
# PM reactions (before): 2004
# Removed all inactive reactions
# PM reactions (after): 1999
# Num. removed: 444 (59 core, 385 non-core); Num. remaining: 1187
# Reaction no.  61
# Attempting to remove reaction:  CYSTSERex ...
# Initial PM reactions: 1999
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.0725640000000567
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['CYSTSERex']
# Zero-expression evidence for reaction...
# 1999
# 1999
# check_model_function done ....
# PM reactions (before): 1999
# Removed all inactive reactions
# PM reactions (after): 1998
# Num. removed: 445 (59 core, 386 non-core); Num. remaining: 1186
# Reaction no.  62
# Attempting to remove reaction:  CYSGLYex_copy1 ...
# Initial PM reactions: 1998
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.806096000000025
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['CYSGLYex_copy1', 'CYSGLYex_copy2']
# Zero-expression evidence for reaction...
# 1998
# 1998
# check_model_function done ....
# PM reactions (before): 1998
# Removed all inactive reactions
# PM reactions (after): 1996
# Num. removed: 447 (59 core, 388 non-core); Num. remaining: 1184
# Reaction no.  63
# Attempting to remove reaction:  THRGLNexR ...
# Initial PM reactions: 1996
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.8877260000000433
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['THRGLNexR']
# Zero-expression evidence for reaction...
# 1996
# 1996
# check_model_function done ....
# PM reactions (before): 1996
# Removed all inactive reactions
# PM reactions (after): 1995
# Num. removed: 448 (59 core, 389 non-core); Num. remaining: 1183
# Reaction no.  64
# Attempting to remove reaction:  GLYCTO1p ...
# Initial PM reactions: 1995
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 11 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.049718999999982
# check_model_consistency done ...
# Lengths all--> inactive_G: 12 , inactive_C: ['FBA4', 'NDPK1', 'GLYCLTDy', 'GCALDD', 'GLXO1'], inactive_NC:['EX_oxa_e', 'OXAtp', 'GLYCLTtp', 'GLXO2p', 'GLYCTO1p', 'GLXtp', 'KHK2']
# Zero-expression evidence for reaction...
# 1995
# 1995
# check_model_function done ....
# Len P: 1183
# num_removed 448
# Len P AFTER 1182
# No reactions removed
# result 1.1
# Num. removed: 448 (59 core, 389 non-core); Num. remaining: 1182
# Reaction no.  65
# Attempting to remove reaction:  ACOAO7p ...
# Initial PM reactions: 1995
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 16 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.7161989999999605
# check_model_consistency done ...
# Lengths all--> inactive_G: 17 , inactive_C: ['C161CRN2t', 'FBA', 'ASPTAm', 'URIt', 'C161CPT22', 'FAOXC161802m', 'C161CPT12'], inactive_NC:['ARTFR61', 'ACOAO7p', 'RPE', 'EX_ura_e', 'RTOT6', 'HDD2COAtx', 'URAt', 'PMTCOAtx', 'RADH4', 'CYTK3']
# Zero-expression evidence for reaction...
# 1995
# 1995
# check_model_function done ....
# Len P: 1182
# num_removed 448
# Len P AFTER 1181
# No reactions removed
# result 1.1
# Num. removed: 448 (59 core, 389 non-core); Num. remaining: 1181
# Reaction no.  66
# Attempting to remove reaction:  ALAGLYexR ...
# Initial PM reactions: 1995
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.7505839999998898
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['ALAGLYexR']
# Zero-expression evidence for reaction...
# 1995
# 1995
# check_model_function done ....
# PM reactions (before): 1995
# Removed all inactive reactions
# PM reactions (after): 1994
# Num. removed: 449 (59 core, 390 non-core); Num. remaining: 1180
# Reaction no.  67
# Attempting to remove reaction:  SERGLYexR ...
# Initial PM reactions: 1994
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.2230789999998706
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: ['PYNP2r'], inactive_NC:['EX_adn_e', 'SERGLYexR']
# Zero-expression evidence for reaction...
# 1994
# 1994
# check_model_function done ....
# Len P: 1180
# num_removed 449
# Len P AFTER 1179
# No reactions removed
# result 1.1
# Num. removed: 449 (59 core, 390 non-core); Num. remaining: 1179
# Reaction no.  68
# Attempting to remove reaction:  SPODMe ...
# Initial PM reactions: 1994
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.756343999999899
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: ['ACACT1r_copy2', 'NDPK7', 'URIt'], inactive_NC:['SPODMe']
# Zero-expression evidence for reaction...
# 1994
# 1994
# check_model_function done ....
# Len P: 1179
# num_removed 449
# Len P AFTER 1178
# No reactions removed
# result 1.1
# Num. removed: 449 (59 core, 390 non-core); Num. remaining: 1178
# Reaction no.  69
# Attempting to remove reaction:  UMPK4 ...
# Initial PM reactions: 1994
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.8178230000000895
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: ['FACOAL205'], inactive_NC:['UMPK4', 'TMNDNCt', 'EX_tmndnc_e']
# Zero-expression evidence for reaction...
# 1994
# 1994
# check_model_function done ....
# ...
# No reactions removed
# Num. removed: 895 (101 core, 794 non-core); Num. remaining: 22
# Reaction no.  1000
# Attempting to remove reaction:  MI1PS ...
# Initial PM reactions: 1548
# check_model_function done ....
# Num. removed: 895 (101 core, 794 non-core); Num. remaining: 21
# Reaction no.  1001
# Attempting to remove reaction:  G6PPer ...
# Initial PM reactions: 1548
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.4028999999991356
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: ['G6Pter'], inactive_NC:['G6PPer']
# Reaction G6PPer is not in Z
# 1548
# 1548
# check_model_function done ....
# No reactions removed
# Num. removed: 895 (101 core, 794 non-core); Num. remaining: 20
# Reaction no.  1002
# Attempting to remove reaction:  3AIBTm ...
# Initial PM reactions: 1548
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 6 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.5068279999995866
# check_model_consistency done ...
# Lengths all--> inactive_G: 7 , inactive_C: ['FATP1t', 'FUMm'], inactive_NC:['3AIBTm', 'EX_3aib_e', '3AIBtm', '3AIBt', 'EX_hdca_e']
# Reaction 3AIBTm is not in Z
# 1548
# 1548
# check_model_function done ....
# No reactions removed
# Num. removed: 895 (101 core, 794 non-core); Num. remaining: 19
# Reaction no.  1003
# Attempting to remove reaction:  PPAer ...
# Initial PM reactions: 1548
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 135 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.9591090000012628
# check_model_consistency done ...
# Lengths all--> inactive_G: 136 , inactive_C: ['HSD17B8r', 'SBPP1er', 'EBP1r', 'LNSTLSr', 'RAI3', 'DHCRD2', 'G6Pter', 'SOAT11', 'C14STRr', 'IPDDIx', 'DPMVDx', 'GBA', 'CERT2rt', 'SOAT12', 'DHCR243r', 'UGT1A2r', 'UGCG', 'UGT1A6r', 'DHCR242r', 'SQLEr', 'PGMT', 'DMATTx', 'C4STMO2r', 'HMGCOAS', 'UGT1A1r', 'DHCR71r', 'ESTRADIOLGLCt2', 'DHCR241r', 'C4STMO1r', 'LSTO2r', 'SBPP3er', 'C3STDH1Pr', 'CERT1rt', 'SQLSr', 'EBP2r', 'LNS14DMr', 'UGT1A5r', 'GRTTx', 'C3STDH1r', 'UDPDOLPT_L', 'MEVK1x', 'C4STMO2Pr', '24_25VITD3Hm', 'PMEVKx', 'LSTO1r', 'UDPDOLPT_U', 'HMGCOARx', 'HSD17B7r', 'DHCR72r', 'UGT1A10r', 'UGT1A5r2'], inactive_NC:['ESTRONEGLCt', 'RETNtr2', 'BILIRUBtr', 'EX_xolest_hs_e', 'GLCMter', 'RETNGLCt2', 'NDP7er', 'SPHGNtr', 'SLCBK1', 'EX_estroneglc_e', 'DOLICHOL_Lter', 'DOLICHOL_Uter', 'NADtru', 'EX_bildglcur_e', 'BILGLCURt', 'ADPtx', 'VITD3Hm', 'EX_estradiolglc_e', 'P5CR', 'DOLK_U', 'DOLGPP_Uer', 'ESTRONEGLCtr', 'ATPtx', 'PROD2', 'G6PDH1er_copy1', 'VD3', 'EX_13_cis_retnglc_e', 'XOLTRI25tc', 'PVD3', 'RETNGLCt', 'FADH2tru', 'DOLK_L', '7DHCHSTEROLtr', 'PIter', 'C3STKR2r', 'NADPtxu', 'CHSTEROLt2', 'CH25H', 'ESTRADIOLGLCtr', 'DOLPH_Uer', 'O2ter', 'CHSTEROLt3', 'CO2ter', 'BILDGLCURtr', 'EX_retnglc_e', '24_25DHVITD3t', 'EX_estrones_e', 'DOLP_Lter', 'UDPGLCter', 'RETNGLCtr', 'NADPtru', 'CO2tp', 'G6PDH2er', 'SPH1Pter', 'DOLGLCP_Lter', 'BILGLCURtr', 'FRDPtr', 'HMGCOAtx', 'PPAer', 'EX_2425dhvitd3_e', '24_25DHVITD3tm', 'NADPHtru', 'BILDGLCURt', 'XOLESTte', 'DOLGPP_Ler', 'FADtru', 'NADHtru', 'DOLGLCP_Uter', 'ESTRONESt2', 'SPHK21c', 'P4507B11r', 'RETNGLCt2r', 'ESTRONEtr', 'EX_xoltri25_e', 'FORtr', 'PPItx', 'EX_bilglcur_e', 'PItx', 'XOLTRI25te', 'RETNtr', 'SPHINGStr', 'NADPHtxu', 'DOLPH_Ler', 'SPHS1Ptr', 'G6PPer']
# Reaction PPAer is not in Z
# 1548
# 1548
# check_model_function done ....
# No reactions removed
# Num. removed: 895 (101 core, 794 non-core); Num. remaining: 18
# Reaction no.  1004
# Attempting to remove reaction:  L_LACDcm ...
# Initial PM reactions: 1548
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.2456420000016806
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: ['FATP1t'], inactive_NC:['L_LACDcm', 'EX_hdca_e']
# Reaction L_LACDcm is not in Z
# 1548
# 1548
# check_model_function done ....
# No reactions removed
# Num. removed: 895 (101 core, 794 non-core); Num. remaining: 17
# Reaction no.  1005
# Attempting to remove reaction:  3HCO3_NAt ...
# Initial PM reactions: 1548
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.2248489999983576
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: ['KCC2t', 'CHOLtu'], inactive_NC:['3HCO3_NAt']
# Reaction 3HCO3_NAt is not in Z
# 1548
# 1548
# check_model_function done ....
# No reactions removed
# Num. removed: 895 (101 core, 794 non-core); Num. remaining: 16
# Reaction no.  1006
# Attempting to remove reaction:  PDE4 ...
# Initial PM reactions: 1548
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.318500999999742
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['PDE4']
# Reaction PDE4 is not in Z
# 1548
# 1548
# check_model_function done ....
# Removed non-core inactive reactions
# PM reactions (after): 1547
# Num. removed: 896 (101 core, 795 non-core); Num. remaining: 15
# Reaction no.  1007
# Attempting to remove reaction:  B_MANNASEly ...
# Initial PM reactions: 1547
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 25 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.6524120000012772
# check_model_consistency done ...
# Lengths all--> inactive_G: 26 , inactive_C: ['TRIODTHYt2', 'GASNASE2ly', 'CHOLtu', 'AHEXASE2ly', 'ACNAM9PL2', 'ACNAMlt', 'AHEXASEly', 'GALASE1ly', 'HEX4', 'A_MANASEly', 'SIAASEly', 'GASNASEly', 'FUCASEe'], inactive_NC:['N2M2NMASNtly', 'EX_n2m2nmasn_e', 'S2L2N2M2MASNtly', 'EX_s2l2fn2m2masn_e', 'DM_Asn_X_Ser_Thr_l', 'ENGASE2ly', 'DM_kdn_c', 'TRIODTHYt', 'ENGASEly', 'MANtly', 'B_MANNASEly', 'GALtly', 'KDNH']
# Reaction B_MANNASEly is not in Z
# 1547
# 1547
# check_model_function done ....
# No reactions removed
# Num. removed: 896 (101 core, 795 non-core); Num. remaining: 14
# Reaction no.  1008
# Attempting to remove reaction:  ARGtm ...
# Initial PM reactions: 1547
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.533212000000276
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: ['SUCD1m', 'ARGNm', 'ORNTArm'], inactive_NC:['ARGtm', 'UREAtm']
# Reaction ARGtm is not in Z
# 1547
# 1547
# check_model_function done ....
# No reactions removed
# Num. removed: 896 (101 core, 795 non-core); Num. remaining: 13
# Reaction no.  1009
# Attempting to remove reaction:  ORNt4m ...
# Initial PM reactions: 1547
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 6 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.200767000000269
# check_model_consistency done ...
# Lengths all--> inactive_G: 7 , inactive_C: ['ARGSL', 'SUCD1m', 'URIt', 'CBPSam', 'ARGSS'], inactive_NC:['OCBTm', 'ORNt4m']
# Reaction ORNt4m is not in Z
# 1547
# 1547
# check_model_function done ....
# No reactions removed
# Num. removed: 896 (101 core, 795 non-core); Num. remaining: 12
# Reaction no.  1010
# Attempting to remove reaction:  LRAT ...
# Initial PM reactions: 1547
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.5788359999987733
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: ['URIt', 'ADNt'], inactive_NC:['LRAT']
# Reaction LRAT is not in Z
# 1547
# 1547
# check_model_function done ....
# No reactions removed
# Num. removed: 896 (101 core, 795 non-core); Num. remaining: 11
# Reaction no.  1011
# Attempting to remove reaction:  GGLUCT ...
# Initial PM reactions: 1547
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 11 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.4544019999993907
# check_model_consistency done ...
# Lengths all--> inactive_G: 12 , inactive_C: ['AMPTASECGe', 'TRIODTHYt2', 'GLYt4', 'GTHS', 'GLUDym', 'CGLYt3_2', 'AMPTASECG'], inactive_NC:['OPAH', 'GTMLTe', 'TRIODTHYt', 'GGLUCT', 'GLUCYS']
# Reaction GGLUCT is not in Z
# 1547
# 1547
# check_model_function done ....
# No reactions removed
# Num. removed: 896 (101 core, 795 non-core); Num. remaining: 10
# Reaction no.  1012
# Attempting to remove reaction:  PIter ...
# Initial PM reactions: 1547
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 136 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.7823649999991176
# check_model_consistency done ...
# Lengths all--> inactive_G: 137 , inactive_C: ['HSD17B8r', 'SBPP1er', 'EBP1r', 'LNSTLSr', 'CITtam', 'RAI3', 'DHCRD2', 'G6Pter', 'SOAT11', 'C14STRr', 'IPDDIx', 'DPMVDx', 'GBA', 'CERT2rt', 'SOAT12', 'DHCR243r', 'UGT1A2r', 'UGCG', 'UGT1A6r', 'DHCR242r', 'SQLEr', 'DMATTx', 'C4STMO2r', 'HMGCOAS', 'UGT1A1r', 'DHCR71r', 'ESTRADIOLGLCt2', 'DHCR241r', 'C4STMO1r', 'LSTO2r', 'SBPP3er', 'CHOLtu', 'C3STDH1Pr', 'CERT1rt', 'SQLSr', 'EBP2r', 'LNS14DMr', 'UGT1A5r', 'GRTTx', 'C3STDH1r', 'UDPDOLPT_L', 'MEVK1x', 'C4STMO2Pr', '24_25VITD3Hm', 'PMEVKx', 'LSTO1r', 'UDPDOLPT_U', 'HMGCOARx', 'HSD17B7r', 'DHCR72r', 'UGT1A10r', 'UGT1A5r2'], inactive_NC:['ESTRONEGLCt', 'RETNtr2', 'BILIRUBtr', 'EX_xolest_hs_e', 'GLCMter', 'RETNGLCt2', 'NDP7er', 'SPHGNtr', 'SLCBK1', 'EX_estroneglc_e', 'DOLICHOL_Lter', 'DOLICHOL_Uter', 'NADtru', 'EX_bildglcur_e', 'BILGLCURt', 'ADPtx', 'VITD3Hm', 'EX_estradiolglc_e', 'P5CR', 'DOLK_U', 'DOLGPP_Uer', 'ESTRONEGLCtr', 'ATPtx', 'PROD2', 'G6PDH1er_copy1', 'VD3', 'EX_13_cis_retnglc_e', 'XOLTRI25tc', 'PVD3', 'RETNGLCt', 'FADH2tru', 'DOLK_L', '7DHCHSTEROLtr', 'PIter', 'C3STKR2r', 'NADPtxu', 'CHSTEROLt2', 'CH25H', 'ESTRADIOLGLCtr', 'DOLPH_Uer', 'O2ter', 'CHSTEROLt3', 'CO2ter', 'BILDGLCURtr', 'EX_retnglc_e', '24_25DHVITD3t', 'EX_estrones_e', 'DOLP_Lter', 'UDPGLCter', 'RETNGLCtr', 'NADPtru', 'CO2tp', 'G6PDH2er', 'SPH1Pter', 'DOLGLCP_Lter', 'BILGLCURtr', 'FRDPtr', 'HMGCOAtx', 'PPAer', 'EX_2425dhvitd3_e', '24_25DHVITD3tm', 'NADPHtru', 'BILDGLCURt', 'XOLESTte', 'DOLGPP_Ler', 'FADtru', 'NADHtru', 'DOLGLCP_Uter', 'ESTRONESt2', 'SPHK21c', 'P4507B11r', 'RETNGLCt2r', 'ESTRONEtr', 'EX_xoltri25_e', 'FORtr', 'PPItx', 'EX_bilglcur_e', 'PItx', 'XOLTRI25te', 'RETNtr', 'SPHINGStr', 'NADPHtxu', 'DOLPH_Ler', 'SPHS1Ptr', 'G6PPer']
# Reaction PIter is not in Z
# 1547
# 1547
# check_model_function done ....
# No reactions removed
# Num. removed: 896 (101 core, 795 non-core); Num. remaining: 9
# Reaction no.  1013
# Attempting to remove reaction:  PHETHPTOX2 ...
# Initial PM reactions: 1547
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.611961999999039
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: ['THBPT4ACAMDASE', 'DHPR'], inactive_NC:['PHETHPTOX2']
# Reaction PHETHPTOX2 is not in Z
# 1547
# 1547
# check_model_function done ....
# No reactions removed
# Num. removed: 896 (101 core, 795 non-core); Num. remaining: 8
# Reaction no.  1014
# Attempting to remove reaction:  PRO1xm ...
# Initial PM reactions: 1547
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.9154959999996208
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: ['FATP1t'], inactive_NC:['EX_hdca_e', 'PRO1xm']
# Reaction PRO1xm is not in Z
# 1547
# 1547
# check_model_function done ....
# No reactions removed
# Num. removed: 896 (101 core, 795 non-core); Num. remaining: 7
# Reaction no.  1015
# Attempting to remove reaction:  HYPOE ...
# Initial PM reactions: 1547
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.3305380000001605
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: ['AACOAT'], inactive_NC:['HYPOE']
# Reaction HYPOE is not in Z
# 1547
# 1547
# check_model_function done ....
# No reactions removed
# Num. removed: 896 (101 core, 795 non-core); Num. remaining: 6
# Reaction no.  1016
# Attempting to remove reaction:  PDXPP ...
# Initial PM reactions: 1547
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.4185949999991863
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: ['FATP1t'], inactive_NC:['PYDXNK', 'PDXPP', 'EX_hdca_e', 'EX_pi_e']
# Reaction PDXPP is not in Z
# 1547
# 1547
# check_model_function done ....
# No reactions removed
# Num. removed: 896 (101 core, 795 non-core); Num. remaining: 5
# Reaction no.  1017
# Attempting to remove reaction:  PYDXPP ...
# Initial PM reactions: 1547
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 7 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.5096619999985705
# check_model_consistency done ...
# Lengths all--> inactive_G: 8 , inactive_C: ['PYAM5PO', 'URIt', 'PYDXDH'], inactive_NC:['EX_4pyrdx_e', 'PYDXPP', 'EX_pydam_e', '4PYRDX', 'PYDAMtr']
# Reaction PYDXPP is not in Z
# 1547
# 1547
# check_model_function done ....
# No reactions removed
# Num. removed: 896 (101 core, 795 non-core); Num. remaining: 4
# Reaction no.  1018
# Attempting to remove reaction:  PROD2m ...
# Initial PM reactions: 1547
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.8921449999998003
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['PROD2m']
# Reaction PROD2m is not in Z
# 1547
# 1547
# check_model_function done ....
# Removed non-core inactive reactions
# PM reactions (after): 1546
# Num. removed: 897 (101 core, 796 non-core); Num. remaining: 3
# Reaction no.  1019
# Attempting to remove reaction:  NRPPHRSULT ...
# Initial PM reactions: 1546
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.2811710000005405
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: [], inactive_NC:['NRPPHRSFt', 'EX_nrpphrsf_e', 'NRPPHRSULT', 'EX_pi_e']
# Reaction NRPPHRSULT is not in Z
# 1546
# 1546
# check_model_function done ....
# No reactions removed
# Num. removed: 897 (101 core, 796 non-core); Num. remaining: 2
# Reaction no.  1020
# Attempting to remove reaction:  PPCOACm ...
# Initial PM reactions: 1546
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 30 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.328427999998894
# check_model_consistency done ...
# Lengths all--> inactive_G: 31 , inactive_C: ['FACOAL170', 'HACD9m', 'FACOAL150', 'ECOAH9m', 'HPDCACRNCPT1', 'ACOAD10m', 'HPDCACRNCPT2', 'URIt', 'MMEm', 'PTDCACRNCPT2', 'FAOXC170m', 'ILEt4', 'GLUDym', 'PTDCACRNCPT1', 'KCC2t', 'OIVD3m', 'HPDCACRNt', 'LEUtec', 'FAOXC150m', 'PTDCACRNt'], inactive_NC:['EX_ptdca_e', 'HPDCAt', 'ACACT10m', '3MOPt2im', 'ILETA', 'NH4t3r', 'PPCOACm', 'EX_hpdca_e', 'PTDCAt', 'EX_ile__L_e', 'MMSAD1m']
# Reaction PPCOACm is not in Z
# 1546
# 1546
# check_model_function done ....
# No reactions removed
# Num. removed: 897 (101 core, 796 non-core); Num. remaining: 1
# Reaction no.  1021
# Attempting to remove reaction:  PIt2m ...
# Initial PM reactions: 1546
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  1.4941089999992982
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['PIt2m']
# Reaction PIt2m is not in Z
# 1546
# 1546
# check_model_function done ....
# Removed non-core inactive reactions
# PM reactions (after): 1545
# Num. removed: 898 (101 core, 797 non-core); Num. remaining: 0
# prune_model done ....

# %%
len(PM.reactions)
# Out:
# 1545

# %%
len(PM.metabolites)
# Out:
# 1150

# %%
len(PM.genes)
# Out:
# 1174

# %%
pruneTime
# Out:
# 9151.536602

# %%
# cores and non-cores removed

# %%
from cobra import *
# write out PM model
io.write_sbml_model(PM,"python_recon1_BEC1_method2.xml")
