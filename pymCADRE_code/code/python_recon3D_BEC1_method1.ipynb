# %%
__author__ = "Nantia Leonidou"
__description__ = " Main script "
########################################
# copied from run_mcadre.py
########################################

import numpy as np
from test_Inputs.test_Inputs import *
import pandas as pd

# read model
model = io.read_sbml_model('../pre_processing/dataset/Recon3D.xml')
# genes
G = pd.read_csv('../pre_processing/dataset/1_GPL570_GSE3397/1_GPL570_GSE3397_entrez_ids.csv')
G = list(G['ENTREZ_GENE_ID'])
# ubiquity scores
U = pd.read_csv('../pre_processing/dataset/1_GPL570_GSE3397/1_GPL570_GSE3397_ubiquity.csv', header=None)
U = U.rename(columns={0: "Scores"})
U = list(U['Scores'])
#confidence_scores 
confidence_scores = pd.read_csv('../pre_processing/dataset/Recon3D_confidence_scores.csv')
confidence_scores = np.float64(list(confidence_scores['Confidence Score']))

# %%
from rank.rank_reactions import *
GM, C, NC, P, Z, model_C = rank_reactions(model, G, U, confidence_scores, [], 1)
# Out:
# /Users/leonidou/Documents/mCADRE_PYTHON_code/code/rank/calc_expr_evidence.py:34 RuntimeWarning: All-NaN axis encountered
# /Users/leonidou/Documents/mCADRE_PYTHON_code/code/rank/calc_expr_evidence.py:58 RuntimeWarning: All-NaN axis encountered
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  93.913408
# check_model_consistency done ...
# /Users/leonidou/Documents/mCADRE_PYTHON_code/code/rank/calc_conn_evidence.py:41 RuntimeWarning: invalid value encountered in true_divide
# rank_reactions done ...

# %%
len(GM.reactions)
# Out:
# 10600

# %%
len(GM.metabolites)
# Out:
# 5835

# %%
len(GM.genes)
# Out:
# 2248

# %%
len(C)
# Out:
# 3495

# %%
len(NC)
# Out:
# 7105

# %%
len(Z)
# Out:
# 1784

# %%
len(model_C)
# Out:
# 3495

# %%
from prune.prune_model import *
print('Generic model passed precursor metabolites test')

##############################################################
# If generic functionality test is passed, prune reactions
###############################################################
print('Pruning reactions...')
t0 = process_time()
PM, cRes = prune_model(GM, P, C, Z, 1/3, '../pre_processing/dataset/key_metabolites_RECON1.txt', 1, 1)
# Stop the stopwatch / counter
t_stop = process_time()
# compute elapsed time
pruneTime = t_stop - t0
# Out:
# Generic model passed precursor metabolites test
# Pruning reactions...
# Reaction no.  1
# Attempting to remove reaction:  DCT ...
# Initial PM reactions: 10600
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  90.50990900000033
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: [], inactive_NC:['RE3201C', 'DM_CE1562_c', 'DM_melanin_c', 'TYRASE', 'DCT']
# Zero-expression evidence for reaction...
# 10600
# 10600
# check_model_function done ....
# PM reactions (before): 10600
# Removed all inactive reactions
# PM reactions (after): 10595
# Num. removed: 5 (0 core, 5 non-core); Num. remaining: 7100
# Reaction no.  2
# Attempting to remove reaction:  APRGSTRNt1e ...
# Initial PM reactions: 10595
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  90.03918200000044
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['APRGSTRNt1e']
# Zero-expression evidence for reaction...
# 10595
# 10595
# check_model_function done ....
# PM reactions (before): 10595
# Removed all inactive reactions
# PM reactions (after): 10594
# Num. removed: 6 (0 core, 6 non-core); Num. remaining: 7099
# Reaction no.  3
# Attempting to remove reaction:  T4HCINNMte ...
# Initial PM reactions: 10594
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  90.53729700000076
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['EX_T4hcinnm_e', 'T4HCINNMte']
# Zero-expression evidence for reaction...
# 10594
# 10594
# check_model_function done ....
# PM reactions (before): 10594
# Removed all inactive reactions
# PM reactions (after): 10592
# Num. removed: 8 (0 core, 8 non-core); Num. remaining: 7097
# Reaction no.  4
# Attempting to remove reaction:  HMR_1761 ...
# Initial PM reactions: 10592
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  91.96662500000093
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: [], inactive_NC:['HMR_1761', 'HMR_1751', 'HMR_1749', 'HMR_1741', 'HMR_1759', 'HMR_1756', 'HMR_1743', 'HMR_1753', 'HMR_1747', 'HMR_1745']
# Zero-expression evidence for reaction...
# 10592
# 10592
# check_model_function done ....
# PM reactions (before): 10592
# Removed all inactive reactions
# PM reactions (after): 10582
# Num. removed: 18 (0 core, 18 non-core); Num. remaining: 7087
# Reaction no.  5
# Attempting to remove reaction:  LEUKTRA4t ...
# Initial PM reactions: 10582
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  91.3750259999997
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['LEUKTRA4t']
# Zero-expression evidence for reaction...
# 10582
# 10582
# check_model_function done ....
# PM reactions (before): 10582
# Removed all inactive reactions
# PM reactions (after): 10581
# Num. removed: 19 (0 core, 19 non-core); Num. remaining: 7086
# Reaction no.  6
# Attempting to remove reaction:  r2353 ...
# Initial PM reactions: 10581
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  90.21972300000016
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2353']
# Zero-expression evidence for reaction...
# 10581
# 10581
# check_model_function done ....
# PM reactions (before): 10581
# Removed all inactive reactions
# PM reactions (after): 10580
# Num. removed: 20 (0 core, 20 non-core); Num. remaining: 7085
# Reaction no.  7
# Attempting to remove reaction:  LEUKTRE4t ...
# Initial PM reactions: 10580
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  89.35834999999861
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['LEUKTRE4t']
# Zero-expression evidence for reaction...
# 10580
# 10580
# check_model_function done ....
# PM reactions (before): 10580
# Removed all inactive reactions
# PM reactions (after): 10579
# Num. removed: 21 (0 core, 21 non-core); Num. remaining: 7084
# Reaction no.  8
# Attempting to remove reaction:  HMR_1760 ...
# Initial PM reactions: 10579
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 11 blocked (inactive) reactions
# Execution time of check_model_consistency:  91.75258399999984
# check_model_consistency done ...
# Lengths all--> inactive_G: 12 , inactive_C: [], inactive_NC:['HMR_1739', 'HMR_1746', 'HMR_1758', 'HMR_1744', 'HMR_1752', 'HMR_1742', 'HMR_1760', 'HMR_1750', 'HMR_1748', 'HMR_1738', 'HMR_1754', 'HMR_1740']
# Zero-expression evidence for reaction...
# 10579
# 10579
# check_model_function done ....
# PM reactions (before): 10579
# Removed all inactive reactions
# PM reactions (after): 10567
# Num. removed: 33 (0 core, 33 non-core); Num. remaining: 7072
# Reaction no.  9
# Attempting to remove reaction:  r2360 ...
# Initial PM reactions: 10567
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  90.26630099999966
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2360']
# Zero-expression evidence for reaction...
# 10567
# 10567
# check_model_function done ....
# PM reactions (before): 10567
# Removed all inactive reactions
# PM reactions (after): 10566
# Num. removed: 34 (0 core, 34 non-core); Num. remaining: 7071
# Reaction no.  10
# Attempting to remove reaction:  r2362 ...
# Initial PM reactions: 10566
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  90.1414590000004
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2362']
# Zero-expression evidence for reaction...
# 10566
# 10566
# check_model_function done ....
# PM reactions (before): 10566
# Removed all inactive reactions
# PM reactions (after): 10565
# Num. removed: 35 (0 core, 35 non-core); Num. remaining: 7070
# Reaction no.  11
# Attempting to remove reaction:  r2366 ...
# Initial PM reactions: 10565
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  90.17993999999999
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2366']
# Zero-expression evidence for reaction...
# 10565
# 10565
# check_model_function done ....
# PM reactions (before): 10565
# Removed all inactive reactions
# PM reactions (after): 10564
# Num. removed: 36 (0 core, 36 non-core); Num. remaining: 7069
# Reaction no.  12
# Attempting to remove reaction:  r2365 ...
# Initial PM reactions: 10564
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  89.81481499999973
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2365']
# Zero-expression evidence for reaction...
# 10564
# 10564
# check_model_function done ....
# PM reactions (before): 10564
# Removed all inactive reactions
# PM reactions (after): 10563
# Num. removed: 37 (0 core, 37 non-core); Num. remaining: 7068
# Reaction no.  13
# Attempting to remove reaction:  r2356 ...
# Initial PM reactions: 10563
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  91.15459399999963
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2356']
# Zero-expression evidence for reaction...
# 10563
# 10563
# check_model_function done ....
# PM reactions (before): 10563
# Removed all inactive reactions
# PM reactions (after): 10562
# Num. removed: 38 (0 core, 38 non-core); Num. remaining: 7067
# Reaction no.  14
# Attempting to remove reaction:  r2367 ...
# Initial PM reactions: 10562
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  90.53745399999934
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2367']
# Zero-expression evidence for reaction...
# 10562
# 10562
# check_model_function done ....
# PM reactions (before): 10562
# Removed all inactive reactions
# PM reactions (after): 10561
# Num. removed: 39 (0 core, 39 non-core); Num. remaining: 7066
# Reaction no.  15
# Attempting to remove reaction:  r2354 ...
# Initial PM reactions: 10561
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  89.20040999999947
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2354']
# Zero-expression evidence for reaction...
# 10561
# 10561
# check_model_function done ....
# PM reactions (before): 10561
# Removed all inactive reactions
# PM reactions (after): 10560
# Num. removed: 40 (0 core, 40 non-core); Num. remaining: 7065
# Reaction no.  16
# Attempting to remove reaction:  r2357 ...
# Initial PM reactions: 10560
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  89.33482499999991
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2357']
# Zero-expression evidence for reaction...
# 10560
# 10560
# check_model_function done ....
# PM reactions (before): 10560
# Removed all inactive reactions
# PM reactions (after): 10559
# Num. removed: 41 (0 core, 41 non-core); Num. remaining: 7064
# Reaction no.  17
# Attempting to remove reaction:  r2358 ...
# Initial PM reactions: 10559
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  90.77072899999985
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2358']
# Zero-expression evidence for reaction...
# 10559
# 10559
# check_model_function done ....
# PM reactions (before): 10559
# Removed all inactive reactions
# PM reactions (after): 10558
# Num. removed: 42 (0 core, 42 non-core); Num. remaining: 7063
# Reaction no.  18
# Attempting to remove reaction:  r2346 ...
# Initial PM reactions: 10558
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  90.11140899999918
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2346']
# Zero-expression evidence for reaction...
# 10558
# 10558
# check_model_function done ....
# PM reactions (before): 10558
# Removed all inactive reactions
# PM reactions (after): 10557
# Num. removed: 43 (0 core, 43 non-core); Num. remaining: 7062
# Reaction no.  19
# Attempting to remove reaction:  r2364 ...
# Initial PM reactions: 10557
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  89.46929399999863
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2364']
# Zero-expression evidence for reaction...
# 10557
# 10557
# check_model_function done ....
# PM reactions (before): 10557
# Removed all inactive reactions
# PM reactions (after): 10556
# Num. removed: 44 (0 core, 44 non-core); Num. remaining: 7061
# Reaction no.  20
# Attempting to remove reaction:  LEUKTRF4t ...
# Initial PM reactions: 10556
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  90.70487200000025
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['LEUKTRF4t']
# Zero-expression evidence for reaction...
# 10556
# 10556
# check_model_function done ....
# PM reactions (before): 10556
# Removed all inactive reactions
# PM reactions (after): 10555
# Num. removed: 45 (0 core, 45 non-core); Num. remaining: 7060
# Reaction no.  21
# Attempting to remove reaction:  r2347 ...
# Initial PM reactions: 10555
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  89.56229499999972
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2347']
# Zero-expression evidence for reaction...
# 10555
# 10555
# check_model_function done ....
# PM reactions (before): 10555
# Removed all inactive reactions
# PM reactions (after): 10554
# Num. removed: 46 (0 core, 46 non-core); Num. remaining: 7059
# Reaction no.  22
# Attempting to remove reaction:  r2359 ...
# Initial PM reactions: 10554
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  90.00677699999869
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2359']
# Zero-expression evidence for reaction...
# 10554
# 10554
# check_model_function done ....
# PM reactions (before): 10554
# Removed all inactive reactions
# PM reactions (after): 10553
# Num. removed: 47 (0 core, 47 non-core); Num. remaining: 7058
# Reaction no.  23
# Attempting to remove reaction:  r2369 ...
# Initial PM reactions: 10553
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  93.16274499999963
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2369']
# Zero-expression evidence for reaction...
# 10553
# 10553
# check_model_function done ....
# PM reactions (before): 10553
# Removed all inactive reactions
# PM reactions (after): 10552
# Num. removed: 48 (0 core, 48 non-core); Num. remaining: 7057
# Reaction no.  24
# Attempting to remove reaction:  3HSMVhep ...
# Initial PM reactions: 10552
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  90.30805099999998
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: [], inactive_NC:['3HSMVhep', '3HSMVACIDteb', 'EX_3hsmvacid_e', '3HSMVACIDhep', '3HSMVitr']
# Zero-expression evidence for reaction...
# 10552
# 10552
# check_model_function done ....
# PM reactions (before): 10552
# Removed all inactive reactions
# PM reactions (after): 10547
# Num. removed: 53 (0 core, 53 non-core); Num. remaining: 7052
# Reaction no.  25
# Attempting to remove reaction:  HMR_1980 ...
# Initial PM reactions: 10547
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  90.18160200000057
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['HMR_1980', 'HMR_1979']
# Zero-expression evidence for reaction...
# 10547
# 10547
# check_model_function done ....
# PM reactions (before): 10547
# Removed all inactive reactions
# PM reactions (after): 10545
# Num. removed: 55 (0 core, 55 non-core); Num. remaining: 7050
# Reaction no.  26
# Attempting to remove reaction:  HMR_1983 ...
# Initial PM reactions: 10545
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  88.89013899999918
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['HMR_1983', 'HMR_1982']
# Zero-expression evidence for reaction...
# 10545
# 10545
# check_model_function done ....
# PM reactions (before): 10545
# Removed all inactive reactions
# PM reactions (after): 10543
# Num. removed: 57 (0 core, 57 non-core); Num. remaining: 7048
# Reaction no.  27
# Attempting to remove reaction:  DCATDc ...
# Initial PM reactions: 10543
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 6 blocked (inactive) reactions
# Execution time of check_model_consistency:  89.37557599999855
# check_model_consistency done ...
# Lengths all--> inactive_G: 7 , inactive_C: ['FAOXOHMC10DC10c'], inactive_NC:['r1527', 'OMHDEACIDTD', 'HMR_0180', 'DCATDc', 'FAOXMC10OHMC10r', 'DCATDr']
# Zero-expression evidence for reaction...
# 10543
# 10543
# check_model_function done ....
# PM reactions (before): 10543
# Removed all inactive reactions
# PM reactions (after): 10536
# Num. removed: 64 (1 core, 63 non-core); Num. remaining: 7042
# Reaction no.  28
# Attempting to remove reaction:  GLYGLYPEPT1tc ...
# Initial PM reactions: 10536
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  90.58013399999982
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['GLYGLYPEPT1tc', 'EX_glygly_e']
# Zero-expression evidence for reaction...
# 10536
# 10536
# check_model_function done ....
# PM reactions (before): 10536
# Removed all inactive reactions
# PM reactions (after): 10534
# Num. removed: 66 (1 core, 65 non-core); Num. remaining: 7040
# Reaction no.  29
# Attempting to remove reaction:  HMR_9583 ...
# Initial PM reactions: 10534
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  89.38554099999965
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['HMR_9583', 'HMR_9584']
# Zero-expression evidence for reaction...
# 10534
# 10534
# check_model_function done ....
# PM reactions (before): 10534
# Removed all inactive reactions
# PM reactions (after): 10532
# Num. removed: 68 (1 core, 67 non-core); Num. remaining: 7038
# Reaction no.  30
# Attempting to remove reaction:  CE4890te2 ...
# Initial PM reactions: 10532
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  89.52312800000072
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['CE4890te2']
# Zero-expression evidence for reaction...
# 10532
# 10532
# check_model_function done ....
# PM reactions (before): 10532
# Removed all inactive reactions
# PM reactions (after): 10531
# Num. removed: 69 (1 core, 68 non-core); Num. remaining: 7037
# Reaction no.  31
# Attempting to remove reaction:  DEBRISOQUINEt ...
# Initial PM reactions: 10531
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  88.25682700000107
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: [], inactive_NC:['EX_4hdebrisoquine_e', '4HDEBRISOQUINEte', 'EX_debrisoquine_e', 'DEBRISOQUINEt', 'P4502D6']
# Zero-expression evidence for reaction...
# 10531
# 10531
# check_model_function done ....
# PM reactions (before): 10531
# Removed all inactive reactions
# PM reactions (after): 10526
# Num. removed: 74 (1 core, 73 non-core); Num. remaining: 7032
# Reaction no.  32
# Attempting to remove reaction:  AVITE1t ...
# Initial PM reactions: 10526
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  90.32079800000065
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['AVITE1t']
# Zero-expression evidence for reaction...
# 10526
# 10526
# check_model_function done ....
# PM reactions (before): 10526
# Removed all inactive reactions
# PM reactions (after): 10525
# Num. removed: 75 (1 core, 74 non-core); Num. remaining: 7031
# Reaction no.  33
# Attempting to remove reaction:  AGRMte ...
# Initial PM reactions: 10525
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  90.72356000000218
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: [], inactive_NC:['AGMt_m', 'AGRMte', 'EX_agm_e']
# Zero-expression evidence for reaction...
# 10525
# 10525
# check_model_function done ....
# PM reactions (before): 10525
# Removed all inactive reactions
# PM reactions (after): 10522
# Num. removed: 78 (1 core, 77 non-core); Num. remaining: 7028
# Reaction no.  34
# Attempting to remove reaction:  CE6205te ...
# Initial PM reactions: 10522
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  88.63787500000035
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: [], inactive_NC:['EX_CE6205_e', 'RE2562C', 'CE6205te']
# Zero-expression evidence for reaction...
# 10522
# 10522
# check_model_function done ....
# PM reactions (before): 10522
# Removed all inactive reactions
# PM reactions (after): 10519
# Num. removed: 81 (1 core, 80 non-core); Num. remaining: 7025
# Reaction no.  35
# Attempting to remove reaction:  N8ASPMDte ...
# Initial PM reactions: 10519
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  90.10563999999795
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: [], inactive_NC:['EX_n8aspmd_e', 'N8ASPMDte', 'SPMDAT2']
# Zero-expression evidence for reaction...
# 10519
# 10519
# check_model_function done ....
# PM reactions (before): 10519
# Removed all inactive reactions
# PM reactions (after): 10516
# Num. removed: 84 (1 core, 83 non-core); Num. remaining: 7022
# Reaction no.  36
# Attempting to remove reaction:  C09642te ...
# Initial PM reactions: 10516
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  89.16457799999989
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['EX_C09642_e', 'C09642te']
# Zero-expression evidence for reaction...
# 10516
# 10516
# check_model_function done ....
# PM reactions (before): 10516
# Removed all inactive reactions
# PM reactions (after): 10514
# Num. removed: 86 (1 core, 85 non-core); Num. remaining: 7020
# Reaction no.  37
# Attempting to remove reaction:  CHATn ...
# Initial PM reactions: 10514
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  90.91099300000133
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: [], inactive_NC:['CHOLtn', 'ACHtn', 'ACCOAtn', 'CHATn', 'COAtn']
# Zero-expression evidence for reaction...
# 10514
# 10514
# check_model_function done ....
# PM reactions (before): 10514
# Removed all inactive reactions
# PM reactions (after): 10509
# Num. removed: 91 (1 core, 90 non-core); Num. remaining: 7015
# Reaction no.  38
# Attempting to remove reaction:  CSNt ...
# Initial PM reactions: 10509
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  89.30686499999865
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: [], inactive_NC:['EX_csn_e', 'CSNt', 'CSND']
# Zero-expression evidence for reaction...
# 10509
# 10509
# check_model_function done ....
# PM reactions (before): 10509
# Removed all inactive reactions
# PM reactions (after): 10506
# Num. removed: 94 (1 core, 93 non-core); Num. remaining: 7012
# Reaction no.  39
# Attempting to remove reaction:  r0934 ...
# Initial PM reactions: 10506
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  89.08758200000011
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r0934']
# Zero-expression evidence for reaction...
# 10506
# 10506
# check_model_function done ....
# PM reactions (before): 10506
# Removed all inactive reactions
# PM reactions (after): 10505
# Num. removed: 95 (1 core, 94 non-core); Num. remaining: 7011
# Reaction no.  40
# Attempting to remove reaction:  HMR_3491 ...
# Initial PM reactions: 10505
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  89.53035300000192
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['HMR_3491']
# Zero-expression evidence for reaction...
# 10505
# 10505
# check_model_function done ....
# PM reactions (before): 10505
# Removed all inactive reactions
# PM reactions (after): 10504
# Num. removed: 96 (1 core, 95 non-core); Num. remaining: 7010
# Reaction no.  41
# Attempting to remove reaction:  r2363 ...
# Initial PM reactions: 10504
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  93.34964200000104
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2363']
# Zero-expression evidence for reaction...
# 10504
# 10504
# check_model_function done ....
# PM reactions (before): 10504
# Removed all inactive reactions
# PM reactions (after): 10503
# Num. removed: 97 (1 core, 96 non-core); Num. remaining: 7009
# Reaction no.  42
# Attempting to remove reaction:  ADPRIBt ...
# Initial PM reactions: 10503
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  93.12217299999975
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['ADPRIBt']
# Zero-expression evidence for reaction...
# 10503
# 10503
# check_model_function done ....
# PM reactions (before): 10503
# Removed all inactive reactions
# PM reactions (after): 10502
# Num. removed: 98 (1 core, 97 non-core); Num. remaining: 7008
# Reaction no.  43
# Attempting to remove reaction:  GLCRt1 ...
# Initial PM reactions: 10502
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  92.08073700000023
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: ['GLACO'], inactive_NC:['GLCRt1', 'EX_glcr_e']
# Zero-expression evidence for reaction...
# 10502
# 10502
# check_model_function done ....
# Len P: 7008
# num_removed 98
# Len P AFTER 7007
# No reactions removed
# result 1.1
# Num. removed: 98 (1 core, 97 non-core); Num. remaining: 7007
# Reaction no.  44
# Attempting to remove reaction:  r2361 ...
# Initial PM reactions: 10502
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  92.01047499999913
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2361']
# Zero-expression evidence for reaction...
# 10502
# 10502
# check_model_function done ....
# PM reactions (before): 10502
# Removed all inactive reactions
# PM reactions (after): 10501
# Num. removed: 99 (1 core, 98 non-core); Num. remaining: 7006
# Reaction no.  45
# Attempting to remove reaction:  RETt ...
# Initial PM reactions: 10501
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  91.77216700000281
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['RETt']
# Zero-expression evidence for reaction...
# 10501
# 10501
# check_model_function done ....
# PM reactions (before): 10501
# Removed all inactive reactions
# PM reactions (after): 10500
# Num. removed: 100 (1 core, 99 non-core); Num. remaining: 7005
# Reaction no.  46
# Attempting to remove reaction:  SPRMti ...
# Initial PM reactions: 10500
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  89.05505099999937
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['SPRMti']
# Zero-expression evidence for reaction...
# 10500
# 10500
# check_model_function done ....
# PM reactions (before): 10500
# Removed all inactive reactions
# PM reactions (after): 10499
# Num. removed: 101 (1 core, 100 non-core); Num. remaining: 7004
# Reaction no.  47
# Attempting to remove reaction:  HPETFABP1tc ...
# Initial PM reactions: 10499
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  88.49403700000039
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['DM_5HPET_r', 'HPETFABP1tc']
# Zero-expression evidence for reaction...
# 10499
# 10499
# check_model_function done ....
# PM reactions (before): 10499
# Removed all inactive reactions
# PM reactions (after): 10497
# Num. removed: 103 (1 core, 102 non-core); Num. remaining: 7002
# Reaction no.  48
# Attempting to remove reaction:  ALLOPtepvb ...
# Initial PM reactions: 10497
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  89.27325799999744
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['ALLOPtepvb']
# Zero-expression evidence for reaction...
# 10497
# 10497
# check_model_function done ....
# PM reactions (before): 10497
# Removed all inactive reactions
# PM reactions (after): 10496
# Num. removed: 104 (1 core, 103 non-core); Num. remaining: 7001
# Reaction no.  49
# Attempting to remove reaction:  OXYPthc ...
# Initial PM reactions: 10496
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  88.70045400000163
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['OXYPthc']
# Zero-expression evidence for reaction...
# 10496
# 10496
# check_model_function done ....
# PM reactions (before): 10496
# Removed all inactive reactions
# PM reactions (after): 10495
# Num. removed: 105 (1 core, 104 non-core); Num. remaining: 7000
# Reaction no.  50
# Attempting to remove reaction:  r2355 ...
# Initial PM reactions: 10495
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  89.84902199999851
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2355']
# Zero-expression evidence for reaction...
# 10495
# 10495
# check_model_function done ....
# PM reactions (before): 10495
# Removed all inactive reactions
# PM reactions (after): 10494
# Num. removed: 106 (1 core, 105 non-core); Num. remaining: 6999
# Reaction no.  51
# Attempting to remove reaction:  r2344 ...
# Initial PM reactions: 10494
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  89.24038799999835
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2344']
# Zero-expression evidence for reaction...
# 10494
# 10494
# check_model_function done ....
# PM reactions (before): 10494
# Removed all inactive reactions
# PM reactions (after): 10493
# Num. removed: 107 (1 core, 106 non-core); Num. remaining: 6998
# Reaction no.  52
# Attempting to remove reaction:  34DHOXMANDte ...
# Initial PM reactions: 10493
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  89.12872100000095
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['34DHOXMANDte', 'EX_34dhoxmand_e']
# Zero-expression evidence for reaction...
# 10493
# 10493
# check_model_function done ....
# PM reactions (before): 10493
# Removed all inactive reactions
# PM reactions (after): 10491
# Num. removed: 109 (1 core, 108 non-core); Num. remaining: 6996
# Reaction no.  53
# Attempting to remove reaction:  LEUKTRB4t ...
# Initial PM reactions: 10491
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  93.55788799999937
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['LEUKTRB4t']
# Zero-expression evidence for reaction...
# 10491
# 10491
# check_model_function done ....
# PM reactions (before): 10491
# Removed all inactive reactions
# PM reactions (after): 10490
# Num. removed: 110 (1 core, 109 non-core); Num. remaining: 6995
# Reaction no.  54
# Attempting to remove reaction:  r2343 ...
# Initial PM reactions: 10490
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  88.88905499999964
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2343']
# Zero-expression evidence for reaction...
# 10490
# 10490
# check_model_function done ....
# PM reactions (before): 10490
# Removed all inactive reactions
# PM reactions (after): 10489
# Num. removed: 111 (1 core, 110 non-core); Num. remaining: 6994
# Reaction no.  55
# Attempting to remove reaction:  34DHPHAte ...
# Initial PM reactions: 10489
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  88.20539999999892
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['34DHPHAte', 'EX_34dhpha_e']
# Zero-expression evidence for reaction...
# 10489
# 10489
# check_model_function done ....
# PM reactions (before): 10489
# Removed all inactive reactions
# PM reactions (after): 10487
# Num. removed: 113 (1 core, 112 non-core); Num. remaining: 6992
# Reaction no.  56
# Attempting to remove reaction:  LNLNCGt ...
# Initial PM reactions: 10487
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  89.00168599999961
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['LNLNCGt']
# Zero-expression evidence for reaction...
# 10487
# 10487
# check_model_function done ....
# PM reactions (before): 10487
# Removed all inactive reactions
# PM reactions (after): 10486
# Num. removed: 114 (1 core, 113 non-core); Num. remaining: 6991
# Reaction no.  57
# Attempting to remove reaction:  LNLNCAt ...
# Initial PM reactions: 10486
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  89.78117500000008
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['LNLNCAt']
# Zero-expression evidence for reaction...
# 10486
# 10486
# check_model_function done ....
# PM reactions (before): 10486
# Removed all inactive reactions
# PM reactions (after): 10485
# Num. removed: 115 (1 core, 114 non-core); Num. remaining: 6990
# Reaction no.  58
# Attempting to remove reaction:  TTDCAtr ...
# Initial PM reactions: 10485
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  93.23175899999842
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['TTDCAtr']
# Zero-expression evidence for reaction...
# 10485
# 10485
# check_model_function done ....
# PM reactions (before): 10485
# Removed all inactive reactions
# PM reactions (after): 10484
# Num. removed: 116 (1 core, 115 non-core); Num. remaining: 6989
# Reaction no.  59
# Attempting to remove reaction:  IBUP_Rshep ...
# Initial PM reactions: 10484
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 5 blocked (inactive) reactions
# Execution time of check_model_consistency:  88.35824700000012
# check_model_consistency done ...
# Lengths all--> inactive_G: 6 , inactive_C: ['IBUP_RASCL1hep', 'IBUP_SACOT2'], inactive_NC:['IBUP_SCONJhep', 'TAURIBUP_Sthv', 'IBUP_Rshep', 'EX_tauribup__S_e']
# Zero-expression evidence for reaction...
# 10484
# 10484
# check_model_function done ....
# Len P: 6989
# num_removed 116
# Len P AFTER 6988
# No reactions removed
# result 1.1
# Num. removed: 116 (1 core, 115 non-core); Num. remaining: 6988
# Reaction no.  60
# Attempting to remove reaction:  r2444 ...
# Initial PM reactions: 10484
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  90.85836700000073
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2444']
# Zero-expression evidence for reaction...
# 10484
# 10484
# check_model_function done ....
# PM reactions (before): 10484
# Removed all inactive reactions
# PM reactions (after): 10483
# Num. removed: 117 (1 core, 116 non-core); Num. remaining: 6987
# Reaction no.  61
# Attempting to remove reaction:  THYMt ...
# Initial PM reactions: 10483
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  88.46667399999933
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['THYMt', 'EX_thym_e']
# Zero-expression evidence for reaction...
# 10483
# 10483
# check_model_function done ....
# PM reactions (before): 10483
# Removed all inactive reactions
# PM reactions (after): 10481
# Num. removed: 119 (1 core, 118 non-core); Num. remaining: 6985
# Reaction no.  62
# Attempting to remove reaction:  PROSTGF2t ...
# Initial PM reactions: 10481
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  90.4046930000004
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['PROSTGF2t']
# Zero-expression evidence for reaction...
# 10481
# 10481
# check_model_function done ....
# PM reactions (before): 10481
# Removed all inactive reactions
# PM reactions (after): 10480
# Num. removed: 120 (1 core, 119 non-core); Num. remaining: 6984
# Reaction no.  63
# Attempting to remove reaction:  r0984 ...
# Initial PM reactions: 10480
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  88.69526899999983
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['r0984', 'r0983']
# Zero-expression evidence for reaction...
# 10480
# 10480
# check_model_function done ....
# PM reactions (before): 10480
# Removed all inactive reactions
# PM reactions (after): 10478
# Num. removed: 122 (1 core, 121 non-core); Num. remaining: 6982
# Reaction no.  64
# Attempting to remove reaction:  MMAt2e ...
# Initial PM reactions: 10478
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  90.42368899999929
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['MMAt2e']
# Zero-expression evidence for reaction...
# 10478
# 10478
# check_model_function done ....
# PM reactions (before): 10478
# Removed all inactive reactions
# PM reactions (after): 10477
# Num. removed: 123 (1 core, 122 non-core); Num. remaining: 6981
# Reaction no.  65
# Attempting to remove reaction:  LGNCt ...
# Initial PM reactions: 10477
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  90.9297719999995
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['LGNCt']
# Zero-expression evidence for reaction...
# 10477
# 10477
# check_model_function done ....
# PM reactions (before): 10477
# Removed all inactive reactions
# PM reactions (after): 10476
# Num. removed: 124 (1 core, 123 non-core); Num. remaining: 6980
# Reaction no.  66
# Attempting to remove reaction:  ACGAM2E ...
# Initial PM reactions: 10476
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  90.1590529999994
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['ACGAM2E']
# Zero-expression evidence for reaction...
# 10476
# 10476
# check_model_function done ....
# PM reactions (before): 10476
# Removed all inactive reactions
# PM reactions (after): 10475
# Num. removed: 125 (1 core, 124 non-core); Num. remaining: 6979
# Reaction no.  67
# Attempting to remove reaction:  r0786 ...
# Initial PM reactions: 10475
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  90.10055799999827
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: [], inactive_NC:['r1457', 'r0786', 'SPHPL']
# Zero-expression evidence for reaction...
# 10475
# 10475
# check_model_function done ....
# PM reactions (before): 10475
# Removed all inactive reactions
# PM reactions (after): 10472
# Num. removed: 128 (1 core, 127 non-core); Num. remaining: 6976
# Reaction no.  68
# Attempting to remove reaction:  HDCEAt ...
# Initial PM reactions: 10472
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  88.80086999999912
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['HDCEAt']
# Zero-expression evidence for reaction...
# 10472
# 10472
# check_model_function done ....
# PM reactions (before): 10472
# Removed all inactive reactions
# PM reactions (after): 10471
# Num. removed: 129 (1 core, 128 non-core); Num. remaining: 6975
# Reaction no.  69
# Attempting to remove reaction:  ELAIDt ...
# Initial PM reactions: 10471
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  88.62314400000105
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['ELAIDt']
# Zero-expression evidence for reaction...
# 10471
# 10471
# check_model_function done ....
# PM reactions (before): 10471
# Removed all inactive reactions
# PM reactions (after): 10470
# Num. removed: 130 (1 core, 129 non-core); Num. remaining: 6974
# Reaction no.  70
# Attempting to remove reaction:  r2341 ...
# Initial PM reactions: 10470
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  88.85153999999966
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2341']
# Zero-expression evidence for reaction...
# 10470
# 10470
# check_model_function done ....
# PM reactions (before): 10470
# Removed all inactive reactions
# PM reactions (after): 10469
# Num. removed: 131 (1 core, 130 non-core); Num. remaining: 6973
# Reaction no.  71
# Attempting to remove reaction:  r2342 ...
# Initial PM reactions: 10469
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  94.11963100000139
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2342']
# Zero-expression evidence for reaction...
# 10469
# 10469
# check_model_function done ....
# PM reactions (before): 10469
# Removed all inactive reactions
# PM reactions (after): 10468
# Num. removed: 132 (1 core, 131 non-core); Num. remaining: 6972
# Reaction no.  72
# Attempting to remove reaction:  HMR_1620 ...
# Initial PM reactions: 10468
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  89.23907099999997
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['HMR_1620']
# Zero-expression evidence for reaction...
# 10468
# 10468
# check_model_function done ....
# PM reactions (before): 10468
# Removed all inactive reactions
# PM reactions (after): 10467
# Num. removed: 133 (1 core, 132 non-core); Num. remaining: 6971
# Reaction no.  73
# Attempting to remove reaction:  OCDCAt ...
# Initial PM reactions: 10467
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  89.6236659999995
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['OCDCAt']
# Zero-expression evidence for reaction...
# 10467
# 10467
# check_model_function done ....
# PM reactions (before): 10467
# Removed all inactive reactions
# PM reactions (after): 10466
# Num. removed: 134 (1 core, 133 non-core); Num. remaining: 6970
# Reaction no.  74
# Attempting to remove reaction:  DGSNt ...
# Initial PM reactions: 10466
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  89.10797900000034
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['DGSNt']
# Zero-expression evidence for reaction...
# 10466
# 10466
# check_model_function done ....
# PM reactions (before): 10466
# Removed all inactive reactions
# PM reactions (after): 10465
# Num. removed: 135 (1 core, 134 non-core); Num. remaining: 6969
# Reaction no.  75
# Attempting to remove reaction:  DURIt ...
# Initial PM reactions: 10465
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  90.47557099999904
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['DURIt']
# Zero-expression evidence for reaction...
# 10465
# 10465
# check_model_function done ....
# PM reactions (before): 10465
# Removed all inactive reactions
# PM reactions (after): 10464
# Num. removed: 136 (1 core, 135 non-core); Num. remaining: 6968
# Reaction no.  76
# Attempting to remove reaction:  LNLCt ...
# Initial PM reactions: 10464
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  89.46239399999831
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['LNLCt']
# Zero-expression evidence for reaction...
# 10464
# 10464
# check_model_function done ....
# PM reactions (before): 10464
# Removed all inactive reactions
# PM reactions (after): 10463
# Num. removed: 137 (1 core, 136 non-core); Num. remaining: 6967
# Reaction no.  77
# Attempting to remove reaction:  GUAt ...
# Initial PM reactions: 10463
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  90.60535700000037
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['GUAt', 'EX_gua_e']
# Zero-expression evidence for reaction...
# 10463
# 10463
# check_model_function done ....
# PM reactions (before): 10463
# Removed all inactive reactions
# PM reactions (after): 10461
# Num. removed: 139 (1 core, 138 non-core); Num. remaining: 6965
# Reaction no.  78
# Attempting to remove reaction:  r2338 ...
# Initial PM reactions: 10461
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  89.37730799999918
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2338']
# Zero-expression evidence for reaction...
# 10461
# 10461
# ...
# Removed all inactive reactions
# PM reactions (after): 10266
# Num. removed: 334 (2 core, 332 non-core); Num. remaining: 6760
# Reaction no.  251
# Attempting to remove reaction:  r2240 ...
# Initial PM reactions: 10266
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  94.55993900000612
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2240']
# Zero-expression evidence for reaction...
# 10266
# 10266
# check_model_function done ....
# PM reactions (before): 10266
# Removed all inactive reactions
# PM reactions (after): 10265
# Num. removed: 335 (2 core, 333 non-core); Num. remaining: 6759
# Reaction no.  252
# Attempting to remove reaction:  r2241 ...
# Initial PM reactions: 10265
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  95.57249099999899
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2241']
# Zero-expression evidence for reaction...
# 10265
# 10265
# check_model_function done ....
# PM reactions (before): 10265
# Removed all inactive reactions
# PM reactions (after): 10264
# Num. removed: 336 (2 core, 334 non-core); Num. remaining: 6758
# Reaction no.  253
# Attempting to remove reaction:  r2251 ...
# Initial PM reactions: 10264
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  94.77768599999399
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2251']
# Zero-expression evidence for reaction...
# 10264
# 10264
# check_model_function done ....
# PM reactions (before): 10264
# Removed all inactive reactions
# PM reactions (after): 10263
# Num. removed: 337 (2 core, 335 non-core); Num. remaining: 6757
# Reaction no.  254
# Attempting to remove reaction:  r2252 ...
# Initial PM reactions: 10263
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  93.36284599999635
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2252']
# Zero-expression evidence for reaction...
# 10263
# 10263
# check_model_function done ....
# PM reactions (before): 10263
# Removed all inactive reactions
# PM reactions (after): 10262
# Num. removed: 338 (2 core, 336 non-core); Num. remaining: 6756
# Reaction no.  255
# Attempting to remove reaction:  r2253 ...
# Initial PM reactions: 10262
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  94.54594199999701
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2253']
# Zero-expression evidence for reaction...
# 10262
# 10262
# check_model_function done ....
# PM reactions (before): 10262
# Removed all inactive reactions
# PM reactions (after): 10261
# Num. removed: 339 (2 core, 337 non-core); Num. remaining: 6755
# Reaction no.  256
# Attempting to remove reaction:  r2259 ...
# Initial PM reactions: 10261
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  94.89766999999847
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2259']
# Zero-expression evidence for reaction...
# 10261
# 10261
# check_model_function done ....
# PM reactions (before): 10261
# Removed all inactive reactions
# PM reactions (after): 10260
# Num. removed: 340 (2 core, 338 non-core); Num. remaining: 6754
# Reaction no.  257
# Attempting to remove reaction:  r2267 ...
# Initial PM reactions: 10260
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  95.35112899999513
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2267']
# Zero-expression evidence for reaction...
# 10260
# 10260
# check_model_function done ....
# PM reactions (before): 10260
# Removed all inactive reactions
# PM reactions (after): 10259
# Num. removed: 341 (2 core, 339 non-core); Num. remaining: 6753
# Reaction no.  258
# Attempting to remove reaction:  r2269 ...
# Initial PM reactions: 10259
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  94.94651000000886
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2269']
# Zero-expression evidence for reaction...
# 10259
# 10259
# check_model_function done ....
# PM reactions (before): 10259
# Removed all inactive reactions
# PM reactions (after): 10258
# Num. removed: 342 (2 core, 340 non-core); Num. remaining: 6752
# Reaction no.  259
# Attempting to remove reaction:  r2270 ...
# Initial PM reactions: 10258
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  93.93681800000195
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2270']
# Zero-expression evidence for reaction...
# 10258
# 10258
# check_model_function done ....
# PM reactions (before): 10258
# Removed all inactive reactions
# PM reactions (after): 10257
# Num. removed: 343 (2 core, 341 non-core); Num. remaining: 6751
# Reaction no.  260
# Attempting to remove reaction:  r2271 ...
# Initial PM reactions: 10257
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  96.98664099999587
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2271']
# Zero-expression evidence for reaction...
# 10257
# 10257
# check_model_function done ....
# PM reactions (before): 10257
# Removed all inactive reactions
# PM reactions (after): 10256
# Num. removed: 344 (2 core, 342 non-core); Num. remaining: 6750
# Reaction no.  261
# Attempting to remove reaction:  r2272 ...
# Initial PM reactions: 10256
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  95.09340800000064
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2272']
# Zero-expression evidence for reaction...
# 10256
# 10256
# check_model_function done ....
# PM reactions (before): 10256
# Removed all inactive reactions
# PM reactions (after): 10255
# Num. removed: 345 (2 core, 343 non-core); Num. remaining: 6749
# Reaction no.  262
# Attempting to remove reaction:  r2274 ...
# Initial PM reactions: 10255
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  96.70176799999899
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2274']
# Zero-expression evidence for reaction...
# 10255
# 10255
# check_model_function done ....
# PM reactions (before): 10255
# Removed all inactive reactions
# PM reactions (after): 10254
# Num. removed: 346 (2 core, 344 non-core); Num. remaining: 6748
# Reaction no.  263
# Attempting to remove reaction:  r2287 ...
# Initial PM reactions: 10254
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  94.15144100000907
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2287']
# Zero-expression evidence for reaction...
# 10254
# 10254
# check_model_function done ....
# PM reactions (before): 10254
# Removed all inactive reactions
# PM reactions (after): 10253
# Num. removed: 347 (2 core, 345 non-core); Num. remaining: 6747
# Reaction no.  264
# Attempting to remove reaction:  r2288 ...
# Initial PM reactions: 10253
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  95.88788200001
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2288']
# Zero-expression evidence for reaction...
# 10253
# 10253
# check_model_function done ....
# PM reactions (before): 10253
# Removed all inactive reactions
# PM reactions (after): 10252
# Num. removed: 348 (2 core, 346 non-core); Num. remaining: 6746
# Reaction no.  265
# Attempting to remove reaction:  r2248 ...
# Initial PM reactions: 10252
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  95.19804299999669
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2248']
# Zero-expression evidence for reaction...
# 10252
# 10252
# check_model_function done ....
# PM reactions (before): 10252
# Removed all inactive reactions
# PM reactions (after): 10251
# Num. removed: 349 (2 core, 347 non-core); Num. remaining: 6745
# Reaction no.  266
# Attempting to remove reaction:  r2249 ...
# Initial PM reactions: 10251
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  95.09436299999652
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2249']
# Zero-expression evidence for reaction...
# 10251
# 10251
# check_model_function done ....
# PM reactions (before): 10251
# Removed all inactive reactions
# PM reactions (after): 10250
# Num. removed: 350 (2 core, 348 non-core); Num. remaining: 6744
# Reaction no.  267
# Attempting to remove reaction:  r2250 ...
# Initial PM reactions: 10250
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  96.11452000000281
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2250']
# Zero-expression evidence for reaction...
# 10250
# 10250
# check_model_function done ....
# PM reactions (before): 10250
# Removed all inactive reactions
# PM reactions (after): 10249
# Num. removed: 351 (2 core, 349 non-core); Num. remaining: 6743
# Reaction no.  268
# Attempting to remove reaction:  r2242 ...
# Initial PM reactions: 10249
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  96.16358000000764
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2242']
# Zero-expression evidence for reaction...
# 10249
# 10249
# check_model_function done ....
# PM reactions (before): 10249
# Removed all inactive reactions
# PM reactions (after): 10248
# Num. removed: 352 (2 core, 350 non-core); Num. remaining: 6742
# Reaction no.  269
# Attempting to remove reaction:  r2244 ...
# Initial PM reactions: 10248
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  94.73385699999926
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2244']
# Zero-expression evidence for reaction...
# 10248
# 10248
# check_model_function done ....
# PM reactions (before): 10248
# Removed all inactive reactions
# PM reactions (after): 10247
# Num. removed: 353 (2 core, 351 non-core); Num. remaining: 6741
# Reaction no.  270
# Attempting to remove reaction:  r2243 ...
# Initial PM reactions: 10247
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  95.51937599999656
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2243']
# Zero-expression evidence for reaction...
# 10247
# 10247
# check_model_function done ....
# PM reactions (before): 10247
# Removed all inactive reactions
# PM reactions (after): 10246
# Num. removed: 354 (2 core, 352 non-core); Num. remaining: 6740
# Reaction no.  271
# Attempting to remove reaction:  r2307 ...
# Initial PM reactions: 10246
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  95.57277699999395
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2307']
# Zero-expression evidence for reaction...
# 10246
# 10246
# check_model_function done ....
# PM reactions (before): 10246
# Removed all inactive reactions
# PM reactions (after): 10245
# Num. removed: 355 (2 core, 353 non-core); Num. remaining: 6739
# Reaction no.  272
# Attempting to remove reaction:  r2305 ...
# Initial PM reactions: 10245
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  97.0337370000052
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2305']
# Zero-expression evidence for reaction...
# 10245
# 10245
# check_model_function done ....
# PM reactions (before): 10245
# Removed all inactive reactions
# PM reactions (after): 10244
# Num. removed: 356 (2 core, 354 non-core); Num. remaining: 6738
# Reaction no.  273
# Attempting to remove reaction:  r2306 ...
# Initial PM reactions: 10244
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  96.48294300000998
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2306']
# Zero-expression evidence for reaction...
# 10244
# 10244
# check_model_function done ....
# PM reactions (before): 10244
# Removed all inactive reactions
# PM reactions (after): 10243
# Num. removed: 357 (2 core, 355 non-core); Num. remaining: 6737
# Reaction no.  274
# Attempting to remove reaction:  r2256 ...
# Initial PM reactions: 10243
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  96.40937500000291
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2256']
# Zero-expression evidence for reaction...
# 10243
# 10243
# check_model_function done ....
# PM reactions (before): 10243
# Removed all inactive reactions
# PM reactions (after): 10242
# Num. removed: 358 (2 core, 356 non-core); Num. remaining: 6736
# Reaction no.  275
# Attempting to remove reaction:  r2254 ...
# Initial PM reactions: 10242
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  95.68451499998628
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2254']
# Zero-expression evidence for reaction...
# 10242
# 10242
# check_model_function done ....
# PM reactions (before): 10242
# Removed all inactive reactions
# PM reactions (after): 10241
# Num. removed: 359 (2 core, 357 non-core); Num. remaining: 6735
# Reaction no.  276
# Attempting to remove reaction:  r2255 ...
# Initial PM reactions: 10241
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  96.99904599999718
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['r2255']
# Zero-expression evidence for reaction...
# 10241
# 10241
# check_model_function done ....
# PM reactions (before): 10241
# Removed all inactive reactions
# PM reactions (after): 10240
# Num. removed: 360 (2 core, 358 non-core); Num. remaining: 6734
# Reaction no.  277
# Attempting to remove reaction:  PVSOATPtu ...
# Initial PM reactions: 10240
# check_model_function done ....
# Checking all reactions (fastFVA)...

# %%
len(PM.reactions)

# %%
len(PM.metabolites)

# %%
len(PM.genes)

# %%
pruneTime

# %%
# cores and non-cores removed

# %%
from cobra import *
# write out PM model
io.write_sbml_model(PM,"python_recon3D_BEC1_method1.xml")
