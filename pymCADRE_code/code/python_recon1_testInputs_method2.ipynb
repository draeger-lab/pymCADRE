# %%
__author__ = "Nantia Leonidou"
__description__ = " Main script "

from test_Inputs.test_Inputs import *
import pandas as pd

# read model
#model = io.read_sbml_model('../pre_processing/dataset/RECON1.xml')
model = io.mat.load_matlab_model('../humanModel.mat')
C_H_genes = get_test_inputs('../testInputs.mat','../humanModel.mat')[2]
G = get_test_inputs('../testInputs.mat','../humanModel.mat')[0]
U = get_test_inputs('../testInputs.mat','../humanModel.mat')[1]
confidence_scores = get_test_inputs('../testInputs.mat','../humanModel.mat')[3]

# %%
from rank.rank_reactions import *
GM, C, NC, P, Z, model_C = rank_reactions(model, G, U, confidence_scores, C_H_genes, 2)
# Out:
# /Users/leonidou/Documents/mCADRE_PYTHON_code/code/rank/calc_expr_evidence.py:34 RuntimeWarning: All-NaN axis encountered
# /Users/leonidou/Documents/mCADRE_PYTHON_code/code/rank/calc_expr_evidence.py:58 RuntimeWarning: All-NaN axis encountered
# Checking all reactions (FASTCC)...
# Model consists of 1305 blocked (inactive) reactions
# Execution time of check_model_consistency:  19.008674
# check_model_consistency done ...
# rank_reactions done ...

# %%
len(GM.reactions)
# Out:
# 2437

# %%
len(GM.metabolites)
# Out:
# 1587

# %%
len(GM.genes)
# Out:
# 1477

# %%
len(C)
# Out:
# 1093

# %%
len(NC)
# Out:
# 1344

# %%
len(Z)
# Out:
# 68

# %%
len(model_C)
# Out:
# 1714

# %%
from prune.prune_model import *
print('Generic model passed precursor metabolites test')

##############################################################
# If generic functionality test is passed, prune reactions
###############################################################
print('Pruning reactions...')
t0 = process_time()
PM, cRes = prune_model(GM, P, C, Z, 1/3, '../metabolites_humanModel.txt', 1, 2)
# Stop the stopwatch / counter
t_stop = process_time()
# compute elapsed time
pruneTime = t_stop - t0
# Out:
# Generic model passed precursor metabolites test
# Pruning reactions...
# Reaction no.  1
# Attempting to remove reaction:  CHATn ...
# Initial PM reactions: 2437
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 6 blocked (inactive) reactions
# Execution time of check_model_consistency:  4.4855110000000025
# check_model_consistency done ...
# Lengths all--> inactive_G: 7 , inactive_C: [], inactive_NC:['PCHOL_HSter', 'CHOLtn', 'CHATn', 'ACHtn', 'EX_ha(e)', 'COAtn', 'ACCOAtn']
# Zero-expression evidence for reaction...
# 2437
# 2437
# check_model_function done ....
# PM reactions (before): 2437
# Removed all inactive reactions
# PM reactions (after): 2430
# Num. removed: 7 (0 core, 7 non-core); Num. remaining: 1337
# Reaction no.  2
# Attempting to remove reaction:  DEBRISOQUINEt ...
# Initial PM reactions: 2430
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 20 blocked (inactive) reactions
# Execution time of check_model_consistency:  4.249274000000014
# check_model_consistency done ...
# Lengths all--> inactive_G: 21 , inactive_C: ['MALTSULtm', 'DHAAt1r', 'UDPGLCAter', 'FACOAL1831', 'UMPK3n', 'P4502D6'], inactive_NC:['EX_dag_hs(e)', 'SRTNtu', 'DOPAtu', 'PE_HStm', 'EX_adprib(e)', 'EX_lnlncg(e)', '4HDEBRISOQUINEte', 'LGNCCOAtx', 'EX_hdca(e)', 'DEBRISOQUINEt', 'EX_debrisoquine(e)', 'TRPt', 'EX_ha_pre1(e)', 'LNLNCGt', 'EX_4hdebrisoquine(e)']
# Zero-expression evidence for reaction...
# 2430
# 2430
# check_model_function done ....
# Len P: 1337
# num_removed 7
# Len P AFTER 1336
# No reactions removed
# result 1.1
# Num. removed: 7 (0 core, 7 non-core); Num. remaining: 1336
# Reaction no.  3
# Attempting to remove reaction:  SRTNtu ...
# Initial PM reactions: 2430
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 23 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.737683000000004
# check_model_consistency done ...
# Lengths all--> inactive_G: 24 , inactive_C: ['MALTSULtm', 'ALAR', 'FATP8t', 'HSD17B1', 'UMPK6n', 'FATP1t', 'FACOAL204'], inactive_NC:['EX_strch2(e)', 'EX_dag_hs(e)', 'SRTNtu', 'EX_drib(e)', 'ESTRADIOLtr', 'EX_hista(e)', 'HSD3A2r', 'LGNCCOAtx', 'ARACHCOAtx', 'EX_11_cis_retfa(e)', 'STCOAtx', 'DRIBt', 'PAIL45P_HStn', 'TCHOLAt', 'TRPt', 'EX_ha_pre1(e)', 'CHOLATEt']
# Zero-expression evidence for reaction...
# 2430
# 2430
# check_model_function done ....
# Len P: 1336
# num_removed 7
# Len P AFTER 1335
# No reactions removed
# result 1.1
# Num. removed: 7 (0 core, 7 non-core); Num. remaining: 1335
# Reaction no.  4
# Attempting to remove reaction:  PROSTGF2t ...
# Initial PM reactions: 2430
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 7 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.688233000000025
# check_model_consistency done ...
# Lengths all--> inactive_G: 8 , inactive_C: ['HSD17B1', 'CBR2', 'DCK2n'], inactive_NC:['PAIL4P_HStn', 'EX_prostge2(e)', 'ESTRADIOLtr', 'PROSTGF2t', 'EX_prostgf2(e)']
# Zero-expression evidence for reaction...
# 2430
# 2430
# check_model_function done ....
# Len P: 1335
# num_removed 7
# Len P AFTER 1334
# No reactions removed
# result 1.1
# Num. removed: 7 (0 core, 7 non-core); Num. remaining: 1334
# Reaction no.  5
# Attempting to remove reaction:  SPTix ...
# Initial PM reactions: 2430
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 29 blocked (inactive) reactions
# Execution time of check_model_consistency:  4.1618780000000015
# check_model_consistency done ...
# Lengths all--> inactive_G: 30 , inactive_C: ['H2CO3Dm', 'THYOXt2', 'UMPK6n', 'HPYRR2x', 'GALT', 'MANt1r', 'ADK1m', 'HPYRRy'], inactive_NC:['SERtp', '34DHPHEt', 'ARACHCOAtx', 'LGNCCOAtx', 'TRPt', 'EX_ha_pre1(e)', 'EX_strch2(e)', 'EX_hista(e)', 'HPYRDC', 'GLYCK2', 'ADRNt', 'EX_dag_hs(e)', 'EX_glyc_S(e)', 'SPTix', 'EX_mag_hs(e)', 'STCOAtx', 'H2CO3D2m', 'HPYRtp', 'EX_34dhphe(e)', 'EX_ncam(e)', 'AGTix', 'GLYC_St']
# Zero-expression evidence for reaction...
# 2430
# 2430
# check_model_function done ....
# Len P: 1334
# num_removed 7
# Len P AFTER 1333
# No reactions removed
# result 1.1
# Num. removed: 7 (0 core, 7 non-core); Num. remaining: 1333
# Reaction no.  6
# Attempting to remove reaction:  It ...
# Initial PM reactions: 2430
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 12 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.5372279999999705
# check_model_consistency done ...
# Lengths all--> inactive_G: 13 , inactive_C: ['G6PDH2rer'], inactive_NC:['EX_strch2(e)', 'EX_dag_hs(e)', 'It', 'EX_drib(e)', 'THMMPt4', 'EX_hista(e)', 'EX_thmmp(e)', 'EX_mag_hs(e)', 'EX_11_cis_retfa(e)', 'DRIBt', 'EX_9_cis_retfa(e)', 'EX_ha_pre1(e)']
# Zero-expression evidence for reaction...
# 2430
# 2430
# check_model_function done ....
# PM reactions (before): 2430
# Removed all inactive reactions
# PM reactions (after): 2417
# Num. removed: 20 (1 core, 19 non-core); Num. remaining: 1321
# Reaction no.  7
# Attempting to remove reaction:  UGT1A9r ...
# Initial PM reactions: 2417
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 7 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.9086770000000115
# check_model_consistency done ...
# Lengths all--> inactive_G: 8 , inactive_C: ['5ADTSTSTERONEGLCte'], inactive_NC:['5ADTSTSTERONEtr', 'UGT1A9r', 'ARACHCOAtx', '5ADTSTSTERONEGLCtr', 'EX_5adtststeroneglc(e)', 'STCOAtx', 'PAIL45P_HStn']
# Zero-expression evidence for reaction...
# 2417
# 2417
# check_model_function done ....
# PM reactions (before): 2417
# Removed all inactive reactions
# PM reactions (after): 2409
# Num. removed: 28 (2 core, 26 non-core); Num. remaining: 1314
# Reaction no.  8
# Attempting to remove reaction:  AGTix ...
# Initial PM reactions: 2409
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 20 blocked (inactive) reactions
# Execution time of check_model_consistency:  4.053066999999999
# check_model_consistency done ...
# Lengths all--> inactive_G: 21 , inactive_C: ['MALTSULtm', 'NDPK2n', 'HSD17B1', 'CYTK9n', 'HPYRR2x', 'HPYRRy'], inactive_NC:['SERtp', 'HPYRtp', 'EX_glyc_S(e)', 'PAIL4P_HStn', 'ACt2m', 'EX_man(e)', 'ESTRADIOLtr', 'AGTix', 'GLYCt', 'GLYC_St', 'LGNCCOAtx', 'HPYRDC', 'SPTix', 'GLYCK2', 'HDCAtr']
# Zero-expression evidence for reaction...
# 2409
# 2409
# check_model_function done ....
# Len P: 1314
# num_removed 28
# Len P AFTER 1313
# No reactions removed
# result 1.1
# Num. removed: 28 (2 core, 26 non-core); Num. remaining: 1313
# Reaction no.  9
# Attempting to remove reaction:  TYRDOPO ...
# Initial PM reactions: 2409
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 7 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.7920119999999997
# check_model_consistency done ...
# Lengths all--> inactive_G: 8 , inactive_C: ['DCK2n', 'GALT'], inactive_NC:['EX_34dhphe(e)', 'EX_gluala(e)', '34DHPHEt', 'TYRDOPO', 'EX_hdca(e)', 'EX_so4(e)']
# Zero-expression evidence for reaction...
# 2409
# 2409
# check_model_function done ....
# PM reactions (before): 2409
# Removed all inactive reactions
# PM reactions (after): 2401
# Num. removed: 36 (4 core, 32 non-core); Num. remaining: 1307
# Reaction no.  10
# Attempting to remove reaction:  TYR3MO2 ...
# Initial PM reactions: 2401
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 11 blocked (inactive) reactions
# Execution time of check_model_consistency:  4.225683000000004
# check_model_consistency done ...
# Lengths all--> inactive_G: 12 , inactive_C: ['MALSO3tm', '3HLYTCL', 'FACOAL204'], inactive_NC:['DOPAQNISO1', 'TYRDOPO3', 'DCT', 'TYRASE', 'DOPACHRMISO', 'DM_melanin_c', 'LGNCCOAtx', 'RIBt', 'TYR3MO2']
# Zero-expression evidence for reaction...
# 2401
# 2401
# check_model_function done ....
# PM reactions (before): 2401
# Removed all inactive reactions
# PM reactions (after): 2389
# Num. removed: 48 (7 core, 41 non-core); Num. remaining: 1298
# Reaction no.  11
# Attempting to remove reaction:  34HPPOR ...
# Initial PM reactions: 2389
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 11 blocked (inactive) reactions
# Execution time of check_model_consistency:  4.050268000000017
# check_model_consistency done ...
# Lengths all--> inactive_G: 12 , inactive_C: ['TYRTA', 'HSD17B1', 'MACACI', 'GUAt', 'FUMAC'], inactive_NC:['ESTRADIOLtr', 'CHOLATEt', '34HPPOR', 'HGNTOR', 'EX_gua(e)', 'TCHOLAt', 'EX_fru(e)']
# Zero-expression evidence for reaction...
# 2389
# 2389
# check_model_function done ....
# Len P: 1298
# num_removed 48
# Len P AFTER 1297
# No reactions removed
# result 1.1
# Num. removed: 48 (7 core, 41 non-core); Num. remaining: 1297
# Reaction no.  12
# Attempting to remove reaction:  CYTDn ...
# Initial PM reactions: 2389
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 16 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.314378999999974
# check_model_consistency done ...
# Lengths all--> inactive_G: 17 , inactive_C: ['PYRt2m', 'H2CO3Dm', 'SUCOAS1m', 'PSSA1_hs'], inactive_NC:['CYTDtn', 'RADH4', 'GULNDer', 'EX_adprib(e)', 'CYTDn', 'DCYTt', 'Uritn', 'EX_xylt(e)', 'HIStN1', 'H2CO3D2m', 'XYLTt', 'EX_dcyt(e)', 'RETI2']
# Zero-expression evidence for reaction...
# 2389
# 2389
# check_model_function done ....
# PM reactions (before): 2389
# Removed all inactive reactions
# PM reactions (after): 2372
# Num. removed: 65 (11 core, 54 non-core); Num. remaining: 1284
# Reaction no.  13
# Attempting to remove reaction:  DCYTDn ...
# Initial PM reactions: 2372
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 8 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.6834709999999973
# check_model_consistency done ...
# Lengths all--> inactive_G: 9 , inactive_C: ['ESTRONESt', 'DCK1n'], inactive_NC:['DURItn', 'EX_asn_L(e)', 'HSD3A2r', 'DCYTDn', 'EX_cit(e)', 'EX_amp(e)', 'NH4tn']
# Zero-expression evidence for reaction...
# 2372
# 2372
# check_model_function done ....
# PM reactions (before): 2372
# Removed all inactive reactions
# PM reactions (after): 2363
# Num. removed: 74 (13 core, 61 non-core); Num. remaining: 1277
# Reaction no.  14
# Attempting to remove reaction:  URCN ...
# Initial PM reactions: 2363
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 10 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.813553000000013
# check_model_consistency done ...
# Lengths all--> inactive_G: 11 , inactive_C: ['FUMTSULtm', 'PGM'], inactive_NC:['EX_din(e)', 'UREAt', 'DOPAtu', 'IZPN', 'GLCter', 'GluForTx', 'FTCD', 'URCN', 'HISD']
# Zero-expression evidence for reaction...
# 2363
# 2363
# check_model_function done ....
# PM reactions (before): 2363
# Removed all inactive reactions
# PM reactions (after): 2352
# Num. removed: 85 (15 core, 70 non-core); Num. remaining: 1268
# Reaction no.  15
# Attempting to remove reaction:  GLYCTO1p ...
# Initial PM reactions: 2352
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 8 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.277582000000052
# check_model_consistency done ...
# Lengths all--> inactive_G: 9 , inactive_C: ['GLYCLTDy', 'ADK1m', 'GCALDD', 'FBA4'], inactive_NC:['GLYCTO1p', 'HPYRDC', 'KHK2', 'CHOLATEt', 'GLYCLTtp']
# Zero-expression evidence for reaction...
# 2352
# 2352
# check_model_function done ....
# Len P: 1268
# num_removed 85
# Len P AFTER 1267
# No reactions removed
# result 1.1
# Num. removed: 85 (15 core, 70 non-core); Num. remaining: 1267
# Reaction no.  16
# Attempting to remove reaction:  PRDX ...
# Initial PM reactions: 2352
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  4.0539569999999685
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: ['UDPGLCAter', 'ADK1m'], inactive_NC:['DURIt', 'SPHS1Pte', 'CHOLATEt', 'EX_duri(e)', 'GLYBt4(2)r', 'PRDX', 'EX_glyb(e)', 'EX_sphs1p(e)']
# Zero-expression evidence for reaction...
# 2352
# 2352
# check_model_function done ....
# PM reactions (before): 2352
# Removed all inactive reactions
# PM reactions (after): 2342
# Num. removed: 95 (17 core, 78 non-core); Num. remaining: 1259
# Reaction no.  17
# Attempting to remove reaction:  CHTNASEe ...
# Initial PM reactions: 2342
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.2727760000000217
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: ['UMPK5n', 'RDH2'], inactive_NC:['CHTNASEe', 'EX_acgam(e)', 'EX_chtn(e)']
# Zero-expression evidence for reaction...
# 2342
# 2342
# check_model_function done ....
# Len P: 1259
# num_removed 95
# Len P AFTER 1258
# No reactions removed
# result 1.1
# Num. removed: 95 (17 core, 78 non-core); Num. remaining: 1258
# Reaction no.  18
# Attempting to remove reaction:  GLXO2p ...
# Initial PM reactions: 2342
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 11 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.4779689999999164
# check_model_consistency done ...
# Lengths all--> inactive_G: 12 , inactive_C: ['DCMPDA', 'DHAAt1r', 'HSD17B1', 'UMPK7', 'CYTDt'], inactive_NC:['LGNCt', 'SPC_HSt', 'ESTRADIOLtr', 'OXAtp', 'EX_spc_hs(e)', 'NRVNCt', 'GLXO2p']
# Zero-expression evidence for reaction...
# 2342
# 2342
# check_model_function done ....
# Len P: 1258
# num_removed 95
# Len P AFTER 1257
# No reactions removed
# result 1.1
# Num. removed: 95 (17 core, 78 non-core); Num. remaining: 1257
# Reaction no.  19
# Attempting to remove reaction:  HSD11B2r ...
# Initial PM reactions: 2342
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 10 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.4127620000000434
# check_model_consistency done ...
# Lengths all--> inactive_G: 11 , inactive_C: ['DHAAt1r', 'HSD11B1r', 'UMPK2n', 'ASPTAm', 'RDH3'], inactive_NC:['EX_sph1p(e)', 'SPC_HSt', 'EX_spc_hs(e)', 'SPH1Pte', 'TCHOLAt', 'HSD11B2r']
# Zero-expression evidence for reaction...
# 2342
# 2342
# check_model_function done ....
# Len P: 1257
# num_removed 95
# Len P AFTER 1256
# No reactions removed
# result 1.1
# Num. removed: 95 (17 core, 78 non-core); Num. remaining: 1256
# Reaction no.  20
# Attempting to remove reaction:  PROt4(2)r ...
# Initial PM reactions: 2342
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 11 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.6235249999999724
# check_model_consistency done ...
# Lengths all--> inactive_G: 12 , inactive_C: ['HSD17B1', 'VALtec', 'RDH3'], inactive_NC:['PAIL4P_HStn', 'ACt2m', 'PE_HStm', 'ESTRADIOLtr', 'PROt4(2)r', 'EX_gal(e)', 'TCHOLAt', 'TRPt', 'EX_ala_D(e)']
# Zero-expression evidence for reaction...
# 2342
# 2342
# check_model_function done ....
# PM reactions (before): 2342
# Removed all inactive reactions
# PM reactions (after): 2330
# Num. removed: 107 (20 core, 87 non-core); Num. remaining: 1247
# Reaction no.  21
# Attempting to remove reaction:  TREHe ...
# Initial PM reactions: 2330
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 7 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.3233699999999544
# check_model_consistency done ...
# Lengths all--> inactive_G: 8 , inactive_C: ['BILDGLCURte', 'CYTK2n'], inactive_NC:['EX_crvnc(e)', 'PPItr', 'EX_man(e)', 'THFtm', 'TREHe', 'EX_tre(e)']
# Zero-expression evidence for reaction...
# 2330
# 2330
# check_model_function done ....
# PM reactions (before): 2330
# Removed all inactive reactions
# PM reactions (after): 2322
# Num. removed: 115 (22 core, 93 non-core); Num. remaining: 1241
# Reaction no.  22
# Attempting to remove reaction:  LPS3e ...
# Initial PM reactions: 2322
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.561421999999993
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: ['PUNP5', 'CYTK5n', 'LPSe'], inactive_NC:['EX_Rtotal3(e)', 'LPS2e', 'EX_tag_hs(e)', 'LPS3e', 'EX_Rtotal(e)', 'EX_dhdascb(e)', 'EX_ascb_L(e)']
# Zero-expression evidence for reaction...
# 2322
# 2322
# check_model_function done ....
# Len P: 1241
# num_removed 115
# Len P AFTER 1240
# No reactions removed
# result 1.1
# Num. removed: 115 (22 core, 93 non-core); Num. remaining: 1240
# Reaction no.  23
# Attempting to remove reaction:  LPS2e ...
# Initial PM reactions: 2322
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 19 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.180543000000057
# check_model_consistency done ...
# Lengths all--> inactive_G: 20 , inactive_C: ['DHAAt1r', 'THYOXt2', 'FATP6t', 'LPSe', 'CYTK1n'], inactive_NC:['FATP4t', 'EX_Rtotal3(e)', 'LPS2e', 'EX_tag_hs(e)', 'SPC_HSt', 'LGNCt', 'LPS3e', 'EX_spc_hs(e)', 'TYRt', 'OCDCAtr', 'NRVNCt', 'EX_Rtotal(e)', 'EX_cys_L(e)', 'FATP5t', 'EX_cytd(e)']
# Zero-expression evidence for reaction...
# 2322
# 2322
# check_model_function done ....
# PM reactions (before): 2322
# Removed all inactive reactions
# PM reactions (after): 2302
# Num. removed: 135 (27 core, 108 non-core); Num. remaining: 1226
# Reaction no.  24
# Attempting to remove reaction:  LPS4e ...
# Initial PM reactions: 2302
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 7 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.1360469999999623
# check_model_consistency done ...
# Lengths all--> inactive_G: 8 , inactive_C: ['UMPKn', 'ADNt', 'NDPK4n'], inactive_NC:['EX_1glyc_hs(e)', '5MTHFt2', 'LPS4e', 'EX_pglyc_hs(e)', 'DTDPtn']
# Zero-expression evidence for reaction...
# 2302
# 2302
# check_model_function done ....
# Len P: 1226
# num_removed 135
# Len P AFTER 1225
# No reactions removed
# result 1.1
# Num. removed: 135 (27 core, 108 non-core); Num. remaining: 1225
# Reaction no.  25
# Attempting to remove reaction:  CHAT ...
# Initial PM reactions: 2302
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.656169000000091
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: ['UMPK2'], inactive_NC:['OCDCEAtr', 'ACHVESSEC', 'CHAT']
# Zero-expression evidence for reaction...
# 2302
# 2302
# check_model_function done ....
# PM reactions (before): 2302
# Removed all inactive reactions
# PM reactions (after): 2298
# Num. removed: 139 (28 core, 111 non-core); Num. remaining: 1222
# Reaction no.  26
# Attempting to remove reaction:  ESTRONESt2 ...
# Initial PM reactions: 2298
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 19 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.3413120000000163
# check_model_consistency done ...
# Lengths all--> inactive_G: 20 , inactive_C: ['ADKd', 'ESTRADIOLGLCt2', 'P4501B1r', 'NDPK2n', 'CYTK9n', 'ESTRONEGLCt', 'HSD17B7r'], inactive_NC:['EX_estroneglc(e)', 'ESTRONESt2', 'HSD17B8r', 'ESTRONEtr', 'UGT1A1r', 'EX_estradiolglc(e)', 'UGT1A6r', 'EX_estrones(e)', 'EX_hestratriol(e)', 'HESTRATRIOLte', 'ESTRONEGLCtr', 'ESTRADIOLGLCtr', 'HESTRATRIOLtr']
# Zero-expression evidence for reaction...
# 2298
# 2298
# check_model_function done ....
# Len P: 1222
# num_removed 139
# Len P AFTER 1221
# No reactions removed
# result 1.1
# Num. removed: 139 (28 core, 111 non-core); Num. remaining: 1221
# Reaction no.  27
# Attempting to remove reaction:  ETHP ...
# Initial PM reactions: 2298
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.2317189999999982
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: ['FACOAL2251'], inactive_NC:['ETHP', 'L_LACt4r', 'EX_dcsptn1(e)', 'DCSPTN1t']
# Zero-expression evidence for reaction...
# 2298
# 2298
# check_model_function done ....
# PM reactions (before): 2298
# Removed all inactive reactions
# PM reactions (after): 2293
# Num. removed: 144 (29 core, 115 non-core); Num. remaining: 1217
# Reaction no.  28
# Attempting to remove reaction:  SRTNt6(2)r ...
# Initial PM reactions: 2293
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.471041000000014
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['RPE', 'SRTNt6(2)r']
# Zero-expression evidence for reaction...
# 2293
# 2293
# check_model_function done ....
# PM reactions (before): 2293
# Removed all inactive reactions
# PM reactions (after): 2291
# Num. removed: 146 (29 core, 117 non-core); Num. remaining: 1215
# Reaction no.  29
# Attempting to remove reaction:  HSD3B2r ...
# Initial PM reactions: 2291
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.1380080000000135
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: ['PUNP5', 'UMPKn', 'LEUtec'], inactive_NC:['HSD3B2r']
# Zero-expression evidence for reaction...
# 2291
# 2291
# check_model_function done ....
# Len P: 1215
# num_removed 146
# Len P AFTER 1214
# No reactions removed
# result 1.1
# Num. removed: 146 (29 core, 117 non-core); Num. remaining: 1214
# Reaction no.  30
# Attempting to remove reaction:  HSD3B3r ...
# Initial PM reactions: 2291
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 7 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.1217849999999316
# check_model_consistency done ...
# Lengths all--> inactive_G: 8 , inactive_C: ['NDPK7', 'LALDO', 'CYTK9n', 'LALDD', 'TAURt4(2)r', 'NDPK8m'], inactive_NC:['HSD3B3r', 'EX_taur(e)']
# Zero-expression evidence for reaction...
# 2291
# 2291
# check_model_function done ....
# Len P: 1214
# num_removed 146
# Len P AFTER 1213
# No reactions removed
# result 1.1
# Num. removed: 146 (29 core, 117 non-core); Num. remaining: 1213
# Reaction no.  31
# Attempting to remove reaction:  5ADTSTSTERONESULT ...
# Initial PM reactions: 2291
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 7 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.542504000000008
# check_model_consistency done ...
# Lengths all--> inactive_G: 8 , inactive_C: ['CYTK3n', 'CYTDt'], inactive_NC:['5ADTSTSTERONESULT', 'EX_5adtststerone(e)', '5ADTSTSTERONESte', 'G5SADrm', 'EX_5adtststerones(e)', '5ADTSTSTERONEte']
# Zero-expression evidence for reaction...
# 2291
# 2291
# check_model_function done ....
# PM reactions (before): 2291
# Removed all inactive reactions
# PM reactions (after): 2283
# Num. removed: 154 (31 core, 123 non-core); Num. remaining: 1207
# Reaction no.  32
# Attempting to remove reaction:  PRO1x ...
# Initial PM reactions: 2283
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.1235090000000127
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: ['GALt1r'], inactive_NC:['SPH1Pte', 'PRO1x', 'ALADGLNexR', 'EX_sph1p(e)']
# Zero-expression evidence for reaction...
# 2283
# 2283
# check_model_function done ....
# PM reactions (before): 2283
# Removed all inactive reactions
# PM reactions (after): 2278
# Num. removed: 159 (32 core, 127 non-core); Num. remaining: 1203
# Reaction no.  33
# Attempting to remove reaction:  IDHPOXOX2b ...
# Initial PM reactions: 2278
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 14 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.2183009999999967
# check_model_consistency done ...
# Lengths all--> inactive_G: 15 , inactive_C: ['TRIODTHYSULT', 'RDH1', 'NDPK2n'], inactive_NC:['TRIODTHYSUFt', 'EX_malt(e)', 'IDHPOXOX3', 'EX_thyox_L(e)', 'IDHPOXOXb', 'EX_i(e)', 'IDHPOXOX4', 'THYOXt', 'H2Oter', 'THYPX', 'IDHPOXOX2b', 'EX_triodthysuf(e)']
# Zero-expression evidence for reaction...
# 2278
# 2278
# check_model_function done ....
# PM reactions (before): 2278
# Removed all inactive reactions
# PM reactions (after): 2263
# Num. removed: 174 (35 core, 139 non-core); Num. remaining: 1191
# Reaction no.  34
# Attempting to remove reaction:  P4502C18 ...
# Initial PM reactions: 2263
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 7 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.4124930000000404
# check_model_consistency done ...
# Lengths all--> inactive_G: 8 , inactive_C: ['UMPK2n', 'RDH2a'], inactive_NC:['DMANTIPYRINEte', 'EX_antipyrene(e)', 'ANTIPYRENEte', 'EX_dmantipyrine(e)', 'EX_5mthf(e)', 'P4502C18']
# Zero-expression evidence for reaction...
# 2263
# 2263
# check_model_function done ....
# PM reactions (before): 2263
# Removed all inactive reactions
# PM reactions (after): 2255
# Num. removed: 182 (37 core, 145 non-core); Num. remaining: 1185
# Reaction no.  35
# Attempting to remove reaction:  CHLP ...
# Initial PM reactions: 2255
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.8124629999999797
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['CHLP']
# Zero-expression evidence for reaction...
# 2255
# 2255
# check_model_function done ....
# PM reactions (before): 2255
# Removed all inactive reactions
# PM reactions (after): 2254
# Num. removed: 183 (37 core, 146 non-core); Num. remaining: 1184
# Reaction no.  36
# Attempting to remove reaction:  CHOLt4 ...
# Initial PM reactions: 2254
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.06574999999998
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: ['CYTK14n'], inactive_NC:['CHOLt4']
# Zero-expression evidence for reaction...
# 2254
# 2254
# check_model_function done ....
# Len P: 1184
# num_removed 183
# Len P AFTER 1183
# No reactions removed
# result 1.1
# Num. removed: 183 (37 core, 146 non-core); Num. remaining: 1183
# Reaction no.  37
# Attempting to remove reaction:  GAMYe ...
# Initial PM reactions: 2254
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 7 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.525523000000021
# check_model_consistency done ...
# Lengths all--> inactive_G: 8 , inactive_C: ['AMY2e', 'ORNt3m', 'MALtm', 'O16G1e'], inactive_NC:['GAMYe', 'EX_glygn2(e)', 'H2Otly', 'EX_Tyr_ggn(e)']
# Zero-expression evidence for reaction...
# 2254
# 2254
# check_model_function done ....
# Len P: 1183
# num_removed 183
# Len P AFTER 1182
# No reactions removed
# result 1.1
# Num. removed: 183 (37 core, 146 non-core); Num. remaining: 1182
# Reaction no.  38
# Attempting to remove reaction:  GLCt4_2 ...
# Initial PM reactions: 2254
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.053617000000031
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: ['CYTK3', 'CYTK14n', 'PHEtec'], inactive_NC:['GLCt4_2']
# Zero-expression evidence for reaction...
# 2254
# 2254
# check_model_function done ....
# Len P: 1182
# num_removed 183
# Len P AFTER 1181
# No reactions removed
# result 1.1
# Num. removed: 183 (37 core, 146 non-core); Num. remaining: 1181
# Reaction no.  39
# Attempting to remove reaction:  GALt4 ...
# Initial PM reactions: 2254
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.184827000000041
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: ['CYTK7n', 'COAtm', 'CYTK10', 'FACOAL246_1'], inactive_NC:['EX_tethex3(e)', 'EX_pydx(e)', 'RETI1', 'TETHEX3t', 'GALt4', 'PYDXtr']
# Zero-expression evidence for reaction...
# 2254
# 2254
# check_model_function done ....
# Len P: 1181
# num_removed 183
# Len P AFTER 1180
# No reactions removed
# result 1.1
# Num. removed: 183 (37 core, 146 non-core); Num. remaining: 1180
# Reaction no.  40
# Attempting to remove reaction:  GALt4_2 ...
# Initial PM reactions: 2254
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 8 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.1604520000000775
# check_model_consistency done ...
# Lengths all--> inactive_G: 9 , inactive_C: ['LALDD', 'LALDO', 'PHEtec', 'CYTK14n'], inactive_NC:['H2Otly', 'GALt2_2', 'GALt4_2', 'ABUTt4(2)r', 'Htr']
# Zero-expression evidence for reaction...
# 2254
# 2254
# check_model_function done ....
# Len P: 1180
# num_removed 183
# Len P AFTER 1179
# No reactions removed
# result 1.1
# Num. removed: 183 (37 core, 146 non-core); Num. remaining: 1179
# Reaction no.  41
# Attempting to remove reaction:  3HAO ...
# Initial PM reactions: 2254
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 11 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.0870219999999335
# check_model_consistency done ...
# Lengths all--> inactive_G: 12 , inactive_C: ['NNDPR', 'TRPO2', 'HKYNH', 'DCMPDA'], inactive_NC:['AM6SAD', '3HAO', 'KYN3OX', 'RETI1', 'PCLAD', 'FKYNH', 'AMCOXO', 'QUILSYN']
# Zero-expression evidence for reaction...
# 2254
# 2254
# check_model_function done ....
# Len P: 1179
# num_removed 183
# Len P AFTER 1178
# No reactions removed
# result 1.1
# Num. removed: 183 (37 core, 146 non-core); Num. remaining: 1178
# Reaction no.  42
# Attempting to remove reaction:  PROD2 ...
# Initial PM reactions: 2254
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 7 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.9333059999999023
# check_model_consistency done ...
# Lengths all--> inactive_G: 8 , inactive_C: ['P5CR', 'FACOAL205', 'LALDO', 'P5CRx'], inactive_NC:['TMNDNCt', 'PROD2', 'EX_tmndnc(e)', 'EX_fru(e)']
# Zero-expression evidence for reaction...
# 2254
# 2254
# check_model_function done ....
# Len P: 1178
# num_removed 183
# Len P AFTER 1177
# No reactions removed
# result 1.1
# Num. removed: 183 (37 core, 146 non-core); Num. remaining: 1177
# Reaction no.  43
# Attempting to remove reaction:  FRUt4 ...
# Initial PM reactions: 2254
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 10 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.102784000000156
# check_model_consistency done ...
# Lengths all--> inactive_G: 11 , inactive_C: ['G3PD1', 'FACOAL203', 'RAI3', 'CYTK14n', 'PHEtec'], inactive_NC:['FRUt4', 'EX_dlnlcg(e)', 'RETI1', 'DLNLCGt', 'EX_fru(e)', 'PROt2r']
# Zero-expression evidence for reaction...
# 2254
# 2254
# check_model_function done ....
# Len P: 1177
# num_removed 183
# Len P AFTER 1176
# No reactions removed
# result 1.1
# Num. removed: 183 (37 core, 146 non-core); Num. remaining: 1176
# Reaction no.  44
# Attempting to remove reaction:  MLTG1e ...
# Initial PM reactions: 2254
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.1549210000000585
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['EX_malttr(e)', 'MLTG1e']
# Zero-expression evidence for reaction...
# 2254
# 2254
# check_model_function done ....
# PM reactions (before): 2254
# Removed all inactive reactions
# PM reactions (after): 2252
# Num. removed: 185 (37 core, 148 non-core); Num. remaining: 1174
# Reaction no.  45
# Attempting to remove reaction:  MALTe ...
# Initial PM reactions: 2252
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.957916999999952
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: ['PUNP5', 'TAURt4(2)r', 'CYTK14n'], inactive_NC:['EX_taur(e)', 'MALTe']
# Zero-expression evidence for reaction...
# 2252
# 2252
# check_model_function done ....
# Len P: 1174
# num_removed 185
# Len P AFTER 1173
# No reactions removed
# result 1.1
# Num. removed: 185 (37 core, 148 non-core); Num. remaining: 1173
# Reaction no.  46
# Attempting to remove reaction:  H2Otm ...
# Initial PM reactions: 2252
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.434744000000137
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: ['FUM', 'CYTK14n', 'ORNt3m'], inactive_NC:['H2Otm']
# Zero-expression evidence for reaction...
# 2252
# 2252
# check_model_function done ....
# Len P: 1173
# num_removed 185
# Len P AFTER 1172
# No reactions removed
# result 1.1
# Num. removed: 185 (37 core, 148 non-core); Num. remaining: 1172
# Reaction no.  47
# Attempting to remove reaction:  MANt4 ...
# Initial PM reactions: 2252
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 5 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.9607390000001033
# check_model_consistency done ...
# Lengths all--> inactive_G: 6 , inactive_C: ['UMPK7', 'MANt1r', 'CYTK14n', 'PHEtec'], inactive_NC:['MANt4', 'RETI1']
# Zero-expression evidence for reaction...
# 2252
# 2252
# check_model_function done ....
# Len P: 1172
# num_removed 185
# Len P AFTER 1171
# No reactions removed
# result 1.1
# Num. removed: 185 (37 core, 148 non-core); Num. remaining: 1171
# Reaction no.  48
# Attempting to remove reaction:  INOSTO ...
# Initial PM reactions: 2252
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.04969600000004
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: ['MI1PS', 'NDPK7n', 'FUMm'], inactive_NC:['INOSTO', 'EX_fru(e)']
# Zero-expression evidence for reaction...
# 2252
# 2252
# check_model_function done ....
# Len P: 1171
# num_removed 185
# Len P AFTER 1170
# No reactions removed
# result 1.1
# Num. removed: 185 (37 core, 148 non-core); Num. remaining: 1170
# Reaction no.  49
# Attempting to remove reaction:  OCBTm ...
# Initial PM reactions: 2252
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.2935620000000654
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: ['CITRtm', 'CBPSam'], inactive_NC:['OCBTm', 'PROt2r']
# Zero-expression evidence for reaction...
# 2252
# 2252
# check_model_function done ....
# Len P: 1170
# num_removed 185
# Len P AFTER 1169
# No reactions removed
# result 1.1
# Num. removed: 185 (37 core, 148 non-core); Num. remaining: 1169
# Reaction no.  50
# Attempting to remove reaction:  P4502C19 ...
# Initial PM reactions: 2252
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 7 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.1475580000001173
# check_model_consistency done ...
# Lengths all--> inactive_G: 8 , inactive_C: ['UMPK7n', 'LALDO', 'UMPK3n'], inactive_NC:['OMEPRAZOLEte', 'P4502C19', '5HOMEPRAZOLEte', 'EX_5homeprazole(e)', 'EX_omeprazole(e)']
# Zero-expression evidence for reaction...
# 2252
# 2252
# check_model_function done ....
# Len P: 1169
# num_removed 185
# Len P AFTER 1168
# No reactions removed
# result 1.1
# Num. removed: 185 (37 core, 148 non-core); Num. remaining: 1168
# Reaction no.  51
# Attempting to remove reaction:  P4502F1 ...
# Initial PM reactions: 2252
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 6 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.9349580000000515
# check_model_consistency done ...
# Lengths all--> inactive_G: 7 , inactive_C: ['NDPK4m', 'CYTK14n'], inactive_NC:['EX_onpthl(e)', 'EX_npthl(e)', 'NPTHLte', 'P4502F1', 'ONPTHLte']
# Zero-expression evidence for reaction...
# 2252
# 2252
# check_model_function done ....
# Len P: 1168
# num_removed 185
# Len P AFTER 1167
# No reactions removed
# result 1.1
# Num. removed: 185 (37 core, 148 non-core); Num. remaining: 1167
# Reaction no.  52
# Attempting to remove reaction:  H2Ot ...
# Initial PM reactions: 2252
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.495676000000003
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: ['UMPK5'], inactive_NC:['NRPPHRtu', 'H2Ot', 'RETI1']
# Zero-expression evidence for reaction...
# 2252
# 2252
# check_model_function done ....
# PM reactions (before): 2252
# Removed all inactive reactions
# PM reactions (after): 2248
# Num. removed: 189 (38 core, 151 non-core); Num. remaining: 1164
# Reaction no.  53
# Attempting to remove reaction:  GALt2_2 ...
# Initial PM reactions: 2248
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.900032999999894
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: ['CYTK14n'], inactive_NC:['GLYtp', 'GALt2_2']
# Zero-expression evidence for reaction...
# 2248
# 2248
# check_model_function done ....
# Len P: 1164
# num_removed 189
# Len P AFTER 1163
# No reactions removed
# result 1.1
# Num. removed: 189 (38 core, 151 non-core); Num. remaining: 1163
# Reaction no.  54
# Attempting to remove reaction:  GLCt2_2 ...
# Initial PM reactions: 2248
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 11 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.7841859999998633
# check_model_consistency done ...
# Lengths all--> inactive_G: 12 , inactive_C: ['LALDO', 'SUCCt4_3', 'HSD11B1r', 'TAURt4(2)r', 'FACOAL1831', 'UMPK6'], inactive_NC:['EX_taur(e)', 'EX_lnlncg(e)', 'H2O2tp', 'GLCt2_2', 'HSD11B2r', 'LNLNCGt']
# Zero-expression evidence for reaction...
# 2248
# 2248
# check_model_function done ....
# Len P: 1163
# num_removed 189
# Len P AFTER 1162
# No reactions removed
# result 1.1
# Num. removed: 189 (38 core, 151 non-core); Num. remaining: 1162
# Reaction no.  55
# Attempting to remove reaction:  FACOAL40im ...
# Initial PM reactions: 2248
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 7 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.177208999999948
# check_model_consistency done ...
# Lengths all--> inactive_G: 8 , inactive_C: ['ACOAD1fm', 'PGMT', 'BUTt2m', 'UMPK3n', 'BUTt2r'], inactive_NC:['EX_but(e)', 'FACOAL40im', 'PROt2r']
# Zero-expression evidence for reaction...
# 2248
# 2248
# check_model_function done ....
# Len P: 1162
# num_removed 189
# Len P AFTER 1161
# No reactions removed
# result 1.1
# Num. removed: 189 (38 core, 151 non-core); Num. remaining: 1161
# Reaction no.  56
# Attempting to remove reaction:  PIt9 ...
# Initial PM reactions: 2248
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.0122780000001512
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: ['TAURt4(2)r'], inactive_NC:['PIt9', 'EX_taur(e)']
# Zero-expression evidence for reaction...
# 2248
# 2248
# check_model_function done ....
# Len P: 1161
# num_removed 189
# Len P AFTER 1160
# No reactions removed
# result 1.1
# Num. removed: 189 (38 core, 151 non-core); Num. remaining: 1160
# Reaction no.  57
# Attempting to remove reaction:  GLYt7(311)r ...
# Initial PM reactions: 2248
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.09452199999987
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: ['PGMT', 'TAURt4(2)r', 'CYTK14n'], inactive_NC:['GLYt7(311)r', 'EX_taur(e)']
# Zero-expression evidence for reaction...
# 2248
# 2248
# check_model_function done ....
# Len P: 1160
# num_removed 189
# Len P AFTER 1159
# No reactions removed
# result 1.1
# Num. removed: 189 (38 core, 151 non-core); Num. remaining: 1159
# Reaction no.  58
# Attempting to remove reaction:  CYOOm3 ...
# Initial PM reactions: 2248
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 25 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.6062339999998585
# check_model_consistency done ...
# Lengths all--> inactive_G: 26 , inactive_C: ['MALTSULtm', '3SALATAi', 'SULFOX', 'ETF', 'FUMm', 'L_LACDcm', '3SALAASPm', 'ORPT', 'OMPDC', 'ASPCTr', '3SALATAim', 'CBPS', 'ETFQO', 'DHORTS', 'FUMSO3tm', 'DHORD9', 'CYANSTm'], inactive_NC:['TSULt4_3', 'CYOOm3', '3SPYRSP', 'TCYNTtm', 'NADH2_u10m', 'CYANtm', '3SPYRSPm', 'EX_tsul(e)', 'CYOR_u10m']
# Zero-expression evidence for reaction...
# 2248
# 2248
# check_model_function done ....
# Len P: 1159
# num_removed 189
# Len P AFTER 1158
# No reactions removed
# result 1.1
# Num. removed: 189 (38 core, 151 non-core); Num. remaining: 1158
# Reaction no.  59
# Attempting to remove reaction:  UREAt5 ...
# Initial PM reactions: 2248
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.3141749999999774
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: ['FACOAL246_1', 'ARGN', 'ORNt3m', 'ARGtm', 'UREAtm', 'ARGNm'], inactive_NC:['TETHEX3t', 'UREAt5', 'EX_tethex3(e)', 'EX_urea(e)']
# Zero-expression evidence for reaction...
# 2248
# 2248
# check_model_function done ....
# Len P: 1158
# num_removed 189
# Len P AFTER 1157
# No reactions removed
# result 1.1
# Num. removed: 189 (38 core, 151 non-core); Num. remaining: 1157
# Reaction no.  60
# Attempting to remove reaction:  EX_debrisoquine(e) ...
# Initial PM reactions: 2248
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 7 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.0061379999999644
# check_model_consistency done ...
# Lengths all--> inactive_G: 8 , inactive_C: ['P4502D6', 'TAURt4(2)r', 'CYTK14n'], inactive_NC:['EX_taur(e)', '4HDEBRISOQUINEte', 'DEBRISOQUINEt', 'EX_debrisoquine(e)', 'EX_4hdebrisoquine(e)']
# Reaction EX_debrisoquine(e) is not in Z
# 2248
# 2248
# check_model_function done ....
# No reactions removed
# Num. removed: 189 (38 core, 151 non-core); Num. remaining: 1156
# Reaction no.  61
# Attempting to remove reaction:  EX_prostgf2(e) ...
# Initial PM reactions: 2248
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.3415779999997994
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: ['PGMT', 'PUNP5', 'ADNt', 'CBR2', 'CYTK8'], inactive_NC:['EX_prostge2(e)', 'PROSTGF2t', 'EX_prostgf2(e)', 'SO4t4_2', 'PROt2r']
# Reaction EX_prostgf2(e) is not in Z
# 2248
# 2248
# check_model_function done ....
# No reactions removed
# Num. removed: 189 (38 core, 151 non-core); Num. remaining: 1155
# Reaction no.  62
# Attempting to remove reaction:  EX_srtn(e) ...
# Initial PM reactions: 2248
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.763067000000092
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: ['5HLTDL'], inactive_NC:['EX_retfa(e)', 'EX_srtn(e)', 'SRTNtu']
# Reaction EX_srtn(e) is not in Z
# 2248
# 2248
# check_model_function done ....
# No reactions removed
# Num. removed: 189 (38 core, 151 non-core); Num. remaining: 1154
# Reaction no.  63
# Attempting to remove reaction:  EX_acgam(e) ...
# Initial PM reactions: 2248
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.84064699999999
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: ['GLUDym', 'TAURt4(2)r', 'CYTK14n', 'TPI'], inactive_NC:['EX_acgam(e)', 'EX_taur(e)', 'H2O2tp', 'EX_chtn(e)', 'CHTNASEe', 'SO4t4_2']
# Reaction EX_acgam(e) is not in Z
# 2248
# 2248
# check_model_function done ....
# No reactions removed
# Num. removed: 189 (38 core, 151 non-core); Num. remaining: 1153
# Reaction no.  64
# Attempting to remove reaction:  EX_chtn(e) ...
# Initial PM reactions: 2248
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 6 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.3120919999998932
# check_model_consistency done ...
# Lengths all--> inactive_G: 7 , inactive_C: ['TAURt4(2)r', 'CYTK14n', 'LDH_D'], inactive_NC:['EX_chtn(e)', 'CHTNASEe', 'EX_acgam(e)', 'EX_taur(e)']
# Reaction EX_chtn(e) is not in Z
# 2248
# 2248
# check_model_function done ....
# No reactions removed
# Num. removed: 189 (38 core, 151 non-core); Num. remaining: 1152
# Reaction no.  65
# Attempting to remove reaction:  EX_Tyr_ggn(e) ...
# Initial PM reactions: 2248
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 5 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.9944430000000466
# check_model_consistency done ...
# Lengths all--> inactive_G: 6 , inactive_C: ['AMY2e', 'CYTK14n', 'O16G1e'], inactive_NC:['GAMYe', 'EX_glygn2(e)', 'EX_Tyr_ggn(e)']
# Reaction EX_Tyr_ggn(e) is not in Z
# 2248
# 2248
# check_model_function done ....
# No reactions removed
# Num. removed: 189 (38 core, 151 non-core); Num. remaining: 1151
# Reaction no.  66
# Attempting to remove reaction:  EX_1glyc_hs(e) ...
# Initial PM reactions: 2248
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 5 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.9699819999998454
# check_model_consistency done ...
# Lengths all--> inactive_G: 6 , inactive_C: ['PUNP5', 'PUNP4', 'NDPK8'], inactive_NC:['LPS4e', 'EX_1glyc_hs(e)', 'EX_pglyc_hs(e)']
# Reaction EX_1glyc_hs(e) is not in Z
# 2248
# 2248
# check_model_function done ....
# No reactions removed
# Num. removed: 189 (38 core, 151 non-core); Num. remaining: 1150
# Reaction no.  67
# Attempting to remove reaction:  EX_pglyc_hs(e) ...
# Initial PM reactions: 2248
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 7 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.9170579999999973
# check_model_consistency done ...
# Lengths all--> inactive_G: 8 , inactive_C: ['CYTK14n', 'UMPK6', 'NDPK5'], inactive_NC:['EX_1glyc_hs(e)', 'EX_retinol(e)', 'LPS4e', 'EX_fru(e)', 'EX_pglyc_hs(e)']
# Reaction EX_pglyc_hs(e) is not in Z
# 2248
# 2248
# check_model_function done ....
# No reactions removed
# Num. removed: 189 (38 core, 151 non-core); Num. remaining: 1149
# Reaction no.  68
# Attempting to remove reaction:  EX_glyc(e) ...
# Initial PM reactions: 2248
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.155138000000079
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: ['CYTK7n', 'NDPK4m', 'MDH', 'PUNP4', 'FRUt1r', 'PHEtec', 'PUNP3'], inactive_NC:['GLYCt', 'EX_glyc(e)', 'EX_fru(e)']
# Reaction EX_glyc(e) is not in Z
# 2248
# 2248
# check_model_function done ....
# No reactions removed
# Num. removed: 189 (38 core, 151 non-core); Num. remaining: 1148
# Reaction no.  69
# Attempting to remove reaction:  5HOMEPRAZOLEte ...
# Initial PM reactions: 2248
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 11 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.673031999999921
# check_model_consistency done ...
# Lengths all--> inactive_G: 12 , inactive_C: ['UMPK3', 'SUCCt4_2', 'FACOAL184'], inactive_NC:['OMEPRAZOLEte', 'EX_dad_2(e)', 'P4502C19', 'SERGLYexR', '5HOMEPRAZOLEte', 'STRDNCt', 'EX_strdnc(e)', 'EX_5homeprazole(e)', 'EX_omeprazole(e)']
# Reaction 5HOMEPRAZOLEte is not in Z
# 2248
# 2248
# check_model_function done ....
# No reactions removed
# Num. removed: 189 (38 core, 151 non-core); Num. remaining: 1147
# Reaction no.  70
# Attempting to remove reaction:  NPTHLte ...
# Initial PM reactions: 2248
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 8 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.5536349999999857
# check_model_consistency done ...
# Lengths all--> inactive_G: 9 , inactive_C: ['COAtm', 'DAGK_hs', 'CYTK14n'], inactive_NC:['EX_onpthl(e)', 'EX_npthl(e)', 'NPTHLte', 'P4502F1', 'ONPTHLte', 'EX_fru(e)']
# Reaction NPTHLte is not in Z
# 2248
# 2248
# check_model_function done ....
# No reactions removed
# ...
# Reaction CYOR_u10m is not in Z
# 2103
# 2103
# check_model_function done ....
# No reactions removed
# Num. removed: 334 (38 core, 296 non-core); Num. remaining: 22
# Reaction no.  1147
# Attempting to remove reaction:  CDS ...
# Initial PM reactions: 2103
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.5547870000009425
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['CDS']
# Reaction CDS is not in Z
# 2103
# 2103
# check_model_function done ....
# Removed non-core inactive reactions
# PM reactions (after): 2102
# Num. removed: 335 (38 core, 297 non-core); Num. remaining: 21
# Reaction no.  1148
# Attempting to remove reaction:  AMACRp ...
# Initial PM reactions: 2102
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 22 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.216269000000466
# check_model_consistency done ...
# Lengths all--> inactive_G: 23 , inactive_C: ['HSD17B4x', 'CYTK14n', 'SCPx', 'VLCSp', 'LDH_D', 'BAAT1x', 'BAAT2x'], inactive_NC:['P4508B13r', 'AKR1D2', 'EX_gchola(e)', 'P45027A12m', 'GCHOLAtx', 'THCHOLSTOICtm', 'AKR1C42', 'P45027A11m', 'ACOX2x', 'AMACRp', 'P45027A13m', 'P4508B11r', 'EX_tchola(e)', 'TCHOLAtx', 'XOLDIOLONEt', 'XOLTRIOLtm']
# Reaction AMACRp is not in Z
# 2102
# 2102
# check_model_function done ....
# No reactions removed
# Num. removed: 335 (38 core, 297 non-core); Num. remaining: 20
# Reaction no.  1149
# Attempting to remove reaction:  AMACR2p ...
# Initial PM reactions: 2102
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 14 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.760072000000946
# check_model_consistency done ...
# Lengths all--> inactive_G: 15 , inactive_C: ['NDPK8', 'CYTK14n', 'FACOAL2252', 'FBA', 'PHEtec', 'SCP2x', 'BAAT3x', 'HSD17B42x'], inactive_NC:['DGCHOLtx', 'EX_CLPND(e)', 'AMACR2p', 'DGCHOLte', 'ACOX22x', 'EX_dgchol(e)', 'CLPNDt']
# Reaction AMACR2p is not in Z
# 2102
# 2102
# check_model_function done ....
# No reactions removed
# Num. removed: 335 (38 core, 297 non-core); Num. remaining: 19
# Reaction no.  1150
# Attempting to remove reaction:  AATAi ...
# Initial PM reactions: 2102
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 17 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.148730999997497
# check_model_consistency done ...
# Lengths all--> inactive_G: 18 , inactive_C: ['SACCD3m', 'ALATA_L', 'SACCD4m', 'LYStm', 'BTNDe'], inactive_NC:['AASAD3', 'LPCOXp', '2AMADPTm', 'LYSOXp', 'AASAD3m', 'THP2Ctp', 'AATAi', 'LYStip', 'AAPSAS', 'EX_btn(e)', '1PPDCRp', 'EX_biocyt(e)', 'PPD2CSPp']
# Reaction AATAi is not in Z
# 2102
# 2102
# check_model_function done ....
# No reactions removed
# Num. removed: 335 (38 core, 297 non-core); Num. remaining: 18
# Reaction no.  1151
# Attempting to remove reaction:  PYDXDH ...
# Initial PM reactions: 2102
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.3084989999988466
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: ['CYTK14n'], inactive_NC:['4PYRDX', 'PYDXDH', 'EX_4pyrdx(e)']
# Reaction PYDXDH is not in Z
# 2102
# 2102
# check_model_function done ....
# No reactions removed
# Num. removed: 335 (38 core, 297 non-core); Num. remaining: 17
# Reaction no.  1152
# Attempting to remove reaction:  PCHOLPr_hs ...
# Initial PM reactions: 2102
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 16 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.7025959999991755
# check_model_consistency done ...
# Lengths all--> inactive_G: 17 , inactive_C: ['PETOHMr_hs', 'FACOAL203', 'NDPK8', 'CYTK14n', 'PHEtec', 'FACOAL2252'], inactive_NC:['CHOLtr', 'EX_CLPND(e)', 'ABUTt2r', 'EX_dlnlcg(e)', 'PCHOLPr_hs', 'PA_HSter', 'AHCYStr', 'DLNLCGt', 'AMETr', 'CLPNDt', 'PE_HSter']
# Reaction PCHOLPr_hs is not in Z
# 2102
# 2102
# check_model_function done ....
# No reactions removed
# Num. removed: 335 (38 core, 297 non-core); Num. remaining: 16
# Reaction no.  1153
# Attempting to remove reaction:  PCHOLPm_hs ...
# Initial PM reactions: 2102
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 38 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.08596899999975
# check_model_consistency done ...
# Lengths all--> inactive_G: 39 , inactive_C: ['MI3PP', 'MI34PP', 'CDSm', 'MI4PP', 'MI145PK', 'FACOAL203', 'MI1345PP', 'DAGKn_hs', 'CDIPTr', 'BHMT', 'PIPLC', 'NDPK3m', 'PI45PLC', 'PI4PLC', 'MI145PP', 'UMPK3n', 'CYTDtm'], inactive_NC:['CDPDAGtm', 'CYTK1m', 'MI1P_Dtn', 'PIPLCn', 'CYTDK2m', 'MI134PP', 'PI4PLCn', 'GLYBtm', 'FALDtm', 'MI14P4P', 'MI14PP', 'PA_HStn', 'EX_dlnlcg(e)', 'DMGDHm', 'BETALDHxm', 'DMGtm', 'ABUTt2r', 'PAIL_HStn', 'CHOLD2m', 'MI14Ptn', 'DLNLCGt', 'PCHOLPm_hs']
# Reaction PCHOLPm_hs is not in Z
# 2102
# 2102
# check_model_function done ....
# No reactions removed
# Num. removed: 335 (38 core, 297 non-core); Num. remaining: 15
# Reaction no.  1154
# Attempting to remove reaction:  ICDHxm ...
# Initial PM reactions: 2102
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 6 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.319167000001471
# check_model_consistency done ...
# Lengths all--> inactive_G: 7 , inactive_C: ['ADKd', 'UMPK7', 'FRUt1r', 'NDPK7m', 'LEUtec', 'PPM'], inactive_NC:['ICDHxm']
# Reaction ICDHxm is not in Z
# 2102
# 2102
# check_model_function done ....
# No reactions removed
# Num. removed: 335 (38 core, 297 non-core); Num. remaining: 14
# Reaction no.  1155
# Attempting to remove reaction:  NAHCO3_HCLt ...
# Initial PM reactions: 2102
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.829148000000714
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['NAHCO3_HCLt']
# Reaction NAHCO3_HCLt is not in Z
# 2102
# 2102
# check_model_function done ....
# Removed non-core inactive reactions
# PM reactions (after): 2101
# Num. removed: 336 (38 core, 298 non-core); Num. remaining: 13
# Reaction no.  1156
# Attempting to remove reaction:  CGLYt3(2) ...
# Initial PM reactions: 2101
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.980176000000938
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: ['FACOAL2252'], inactive_NC:['CLPNDt', 'EX_CLPND(e)', 'AMPTASECG', 'CGLYt3(2)']
# Reaction CGLYt3(2) is not in Z
# 2101
# 2101
# check_model_function done ....
# No reactions removed
# Num. removed: 336 (38 core, 298 non-core); Num. remaining: 12
# Reaction no.  1157
# Attempting to remove reaction:  UGT1A5r2 ...
# Initial PM reactions: 2101
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.2454150000012305
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: ['ACACT1r', 'CYTK14n', 'FACOAL2252'], inactive_NC:['EX_CLPND(e)', 'RETNGLCt2r', 'UGT1A5r2', 'RETNtr2', 'EX_13_cis_retnglc(e)', 'RETNGLCt2', 'CLPNDt']
# Reaction UGT1A5r2 is not in Z
# 2101
# 2101
# check_model_function done ....
# No reactions removed
# Num. removed: 336 (38 core, 298 non-core); Num. remaining: 11
# Reaction no.  1158
# Attempting to remove reaction:  UGT1A2r ...
# Initial PM reactions: 2101
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 6 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.9909819999993488
# check_model_consistency done ...
# Lengths all--> inactive_G: 7 , inactive_C: ['FACOAL2252'], inactive_NC:['EX_CLPND(e)', 'UGT1A2r', 'BILDGLCURt', 'BILDGLCURtr', 'EX_bildglcur(e)', 'CLPNDt']
# Reaction UGT1A2r is not in Z
# 2101
# 2101
# check_model_function done ....
# No reactions removed
# Num. removed: 336 (38 core, 298 non-core); Num. remaining: 10
# Reaction no.  1159
# Attempting to remove reaction:  UGT1A1r ...
# Initial PM reactions: 2101
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 6 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.2055550000004587
# check_model_consistency done ...
# Lengths all--> inactive_G: 7 , inactive_C: ['ADNt', 'CYTK14n', 'ESTRONEGLCt', 'NCNt'], inactive_NC:['UGT1A1r', 'EX_estroneglc(e)', 'ESTRONEGLCtr']
# Reaction UGT1A1r is not in Z
# 2101
# 2101
# check_model_function done ....
# No reactions removed
# Num. removed: 336 (38 core, 298 non-core); Num. remaining: 9
# Reaction no.  1160
# Attempting to remove reaction:  UGT1A6r ...
# Initial PM reactions: 2101
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.366070000000036
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: ['ESTRADIOLGLCt2'], inactive_NC:['ESTRADIOLGLCtr', 'EX_estradiolglc(e)', 'UGT1A6r']
# Reaction UGT1A6r is not in Z
# 2101
# 2101
# check_model_function done ....
# No reactions removed
# Num. removed: 336 (38 core, 298 non-core); Num. remaining: 8
# Reaction no.  1161
# Attempting to remove reaction:  GGLUCT ...
# Initial PM reactions: 2101
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 6 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.745046000000002
# check_model_consistency done ...
# Lengths all--> inactive_G: 7 , inactive_C: ['DURIPP', 'FACOAL2252'], inactive_NC:['OPAHir', 'EX_CLPND(e)', 'GGLUCT', 'CLPNDt', 'GTMLTe']
# Reaction GGLUCT is not in Z
# 2101
# 2101
# check_model_function done ....
# No reactions removed
# Num. removed: 336 (38 core, 298 non-core); Num. remaining: 7
# Reaction no.  1162
# Attempting to remove reaction:  MTHFD2 ...
# Initial PM reactions: 2101
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.479393000001437
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: ['FACOAL2252', 'UMPK3n'], inactive_NC:['MTHFD2', 'CLPNDt', 'EX_CLPND(e)']
# Reaction MTHFD2 is not in Z
# 2101
# 2101
# check_model_function done ....
# No reactions removed
# Num. removed: 336 (38 core, 298 non-core); Num. remaining: 6
# Reaction no.  1163
# Attempting to remove reaction:  PIter ...
# Initial PM reactions: 2101
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 147 blocked (inactive) reactions
# Execution time of check_model_consistency:  4.6374049999976705
# check_model_consistency done ...
# Lengths all--> inactive_G: 148 , inactive_C: ['DPMVDx', 'PMEVKx', 'HSD17B4x', 'SOAT12', 'C4STMO2r', 'SBPP3er', 'LSTO2r', 'HMGCOARx', 'SOAT11', 'MEVK1x', 'VLCSp', 'BAAT2x', 'CH25H', 'HSD17B42x', 'PPAer', 'CSNAT2m', 'DHCR243r', 'C3STDH1Pr', 'SCP3x', 'C3STDH1r', 'CERT2rt', 'CHSTEROLt', 'LCAT1e', 'VLCS2p', 'DHCR241r', 'C4STMO2Pr', 'LNSTLSr', 'CYTK5', 'DHCR242r', 'EBP2r', 'G6PPer', 'BAAT3x', 'GBA', 'SQLEr', 'FACOAL2252', 'BAAT5x', 'UGCG', 'SLCBK1', 'GRTTx', 'CYTK14n', 'EBP1r', 'TAURtcx', 'SCPx', 'BAAT4x', 'BAAT1x', 'HSD3B7P', 'SQLSr', 'LSTO1r', 'P5CR', 'HSD3B7', 'IPDDIx', 'DMATTx', 'DHCR72r', 'P5CRx', 'CERT1rt', 'DHCRD2', 'C3STKR2r', 'C14STRr', 'CSNAT3x', 'DHCR71r', 'G6Pter', 'SCP2x', 'SBPP1er'], inactive_NC:['EX_xolest_hs(e)', 'PPItx', 'FADtru', 'GDCHOLAtx', 'GCHOLAtx', 'UDPGLCter', 'CO2ter', 'PIter', 'DGCHOLtx', 'PCRNtm', 'FADH2tru', 'P4507A1r', 'CLPNDt', 'C4STMO1r', 'FADH2tx', 'AKR1D', 'AMACR2p', 'CHSTEROLt3', 'EX_gdchola(e)', 'TDCHOLAtx', 'TCHOLAtx', 'AKR1D2', 'XOLTRI25te', 'ACOX22x', 'ATPtx', 'EX_xolest2_hs(e)', 'AKR1C41', 'P45027A14m', 'P45027A16m', 'NADPtxu', 'SPHINGStr', 'XOL7AH2tm', 'ACOX2x', 'EX_xoltri25(e)', 'P4507B11r', 'XOLTRI24te', 'DOLK_U', 'PROD2', 'CRNCAR3tp', 'XOLDIOLONEt', 'XOLTRIOLtm', 'XOLTRI24tc', 'EX_tchola(e)', 'P45027A12m', 'DHCHOLESTANATEtm', 'TDCHOLAte', 'AMPtp', 'FADtx', 'GDCHOLAte', 'AKR1C42', 'NAtx', 'CO2tp', 'P4508B13r', 'PItx', 'DOLPH_Uer', 'EX_xoltri24(e)', 'DGCHOLte', 'LNS14DMr', 'SPH1Ptr', 'EX_gchola(e)', 'XOL7AONEtr', 'ADPtx', 'DOLPH_Ler', 'P45027A13m', 'XOLTRI25tc', 'EX_dgchol(e)', 'SPHGNtr', 'AMACRp', 'DOLK_L', 'DOLICHOL_Lter', 'EX_CLPND(e)', 'P45027A15m', 'THCHOLSTOICtm', 'XOLESTte', 'P45039A1r', 'P45027A11m', 'CHSTEROLt2', 'FORtr', 'P4508B11r', 'NDP7er', 'DOLICHOL_Uter', 'NADPHtxu', 'FRDPtr', 'EX_tdchola(e)', 'P45046A1r']
# Reaction PIter is not in Z
# 2101
# 2101
# check_model_function done ....
# No reactions removed
# Num. removed: 336 (38 core, 298 non-core); Num. remaining: 5
# Reaction no.  1164
# Attempting to remove reaction:  HYPOE ...
# Initial PM reactions: 2101
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.970400999998674
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: ['NDPK6m'], inactive_NC:['HYPOE']
# Reaction HYPOE is not in Z
# 2101
# 2101
# check_model_function done ....
# No reactions removed
# Num. removed: 336 (38 core, 298 non-core); Num. remaining: 4
# Reaction no.  1165
# Attempting to remove reaction:  PYDXPP ...
# Initial PM reactions: 2101
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 8 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.4197629999980563
# check_model_consistency done ...
# Lengths all--> inactive_G: 9 , inactive_C: ['CYTK14n', 'PYDXK', 'UMPK7', 'CYTK8', 'NDPK8m'], inactive_NC:['4PYRDX', 'PYDXDH', 'EX_4pyrdx(e)', 'PYDXPP']
# Reaction PYDXPP is not in Z
# 2101
# 2101
# check_model_function done ....
# No reactions removed
# Num. removed: 336 (38 core, 298 non-core); Num. remaining: 3
# Reaction no.  1166
# Attempting to remove reaction:  PDXPP ...
# Initial PM reactions: 2101
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 6 blocked (inactive) reactions
# Execution time of check_model_consistency:  2.570627000000968
# check_model_consistency done ...
# Lengths all--> inactive_G: 7 , inactive_C: ['PUNP5', 'FACOAL184', 'NCNt'], inactive_NC:['PDXPP', 'ABUTt2r', 'STRDNCt', 'EX_strdnc(e)']
# Reaction PDXPP is not in Z
# 2101
# 2101
# check_model_function done ....
# No reactions removed
# Num. removed: 336 (38 core, 298 non-core); Num. remaining: 2
# Reaction no.  1167
# Attempting to remove reaction:  UGT1A10r ...
# Initial PM reactions: 2101
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 23 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.0551200000008976
# check_model_consistency done ...
# Lengths all--> inactive_G: 24 , inactive_C: ['ESTRONEGLCt', 'ESTRADIOLGLCt2', 'PHEtec', 'UMPK3n'], inactive_NC:['EX_estroneglc(e)', 'BILDGLCURt', 'EX_estradiolglc(e)', 'UGT1A6r', 'UGT1A5r2', 'RETNtr2', 'EX_13_cis_retnglc(e)', 'EX_bilglcur(e)', 'RETNGLCt2', 'BILIRUBtr', 'THRGLNexR', 'UGT1A10r', 'UGT1A2r', 'RETNGLCt2r', 'UGT1A1r', 'BILDGLCURtr', 'BILGLCURtr', 'EX_bildglcur(e)', 'ESTRONEGLCtr', 'ESTRADIOLGLCtr']
# Reaction UGT1A10r is not in Z
# 2101
# 2101
# check_model_function done ....
# No reactions removed
# Num. removed: 336 (38 core, 298 non-core); Num. remaining: 1
# Reaction no.  1168
# Attempting to remove reaction:  PTE3x ...
# Initial PM reactions: 2101
# check_model_function done ....
# Checking all reactions (FASTCC)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  3.5679180000006454
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: ['FACOAL2252', 'LALDO', 'FACOAL191', 'CYTK14n'], inactive_NC:['EX_CLPND(e)', 'ABUTt2r', 'PRISTCOAtx', 'PTE3x', 'PRISTtx', 'CLPNDt']
# Reaction PTE3x is not in Z
# 2101
# 2101
# check_model_function done ....
# No reactions removed
# Num. removed: 336 (38 core, 298 non-core); Num. remaining: 0
# prune_model done ....

# %%
len(PM.reactions)
# Out:
# 2101

# %%
len(PM.metabolites)
# Out:
# 1467

# %%
len(PM.genes)
# Out:
# 1337

# %%
pruneTime
# Out:
# 20839.916740999997

# %%
from cobra import *
# write out PM model
io.write_sbml_model(PM,"python_recon1_testInputs_method2.xml")
