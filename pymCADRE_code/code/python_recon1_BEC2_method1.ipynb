# %%
__author__ = "Nantia Leonidou"
__description__ = " Main script "
########################################
# copied from run_mcadre.py
########################################

from mcadre.mcadre import *
from test_Inputs.test_Inputs import *
import pandas as pd

# read model
model = io.read_sbml_model('../pre_processing/dataset/RECON1.xml')
# genes
G = pd.read_csv('../pre_processing/dataset/2_GPL571_GSE6802/2_GPL571_GSE6802_entrez_ids.csv')
G = list(G['ENTREZ_GENE_ID'])
# ubiquity scores
U = pd.read_csv('../pre_processing/dataset/2_GPL571_GSE6802/2_GPL571_GSE6802_ubiquity.csv', header=None)
U = U.rename(columns={0: "Scores"})
U = list(U['Scores'])
# confidence scores
confidence_scores = get_test_inputs('../testInputs.mat','../humanModel.mat')[3]

# %%
from rank.rank_reactions import *
GM, C, NC, P, Z, model_C = rank_reactions(model, G, U, confidence_scores, [], 1)
# Out:
# /Users/leonidou/Documents/mCADRE_PYTHON_code/code/rank/calc_expr_evidence.py:34 RuntimeWarning: All-NaN axis encountered
# /Users/leonidou/Documents/mCADRE_PYTHON_code/code/rank/calc_expr_evidence.py:58 RuntimeWarning: All-NaN axis encountered
# Checking all reactions (fastFVA)...
# Model consists of 1274 blocked (inactive) reactions
# Execution time of check_model_consistency:  15.142172000000002
# check_model_consistency done ...
# rank_reactions done ...

# %%
from prune.prune_model import *
print('Generic model passed precursor metabolites test')

##############################################################
# If generic functionality test is passed, prune reactions
###############################################################
print('Pruning reactions...')
t0 = process_time()
PM, cRes = prune_model(GM, P, C, Z, 1/3, '../pre_processing/dataset/key_metabolites_RECON1.txt', 1, 1)
# Stop the stopwatch / counter
t_stop = process_time()
# compute elapsed time
pruneTime = t_stop - t0
# Out:
# Generic model passed precursor metabolites test
# Pruning reactions...
# Reaction no.  1
# Attempting to remove reaction:  THMMPt4 ...
# Initial PM reactions: 2467
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.565969999999993
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['THMMPt4', 'EX_thmmp_e']
# Zero-expression evidence for reaction...
# 2467
# 2467
# check_model_function done ....
# PM reactions (before): 2467
# Removed all inactive reactions
# PM reactions (after): 2465
# Num. removed: 2 (0 core, 2 non-core); Num. remaining: 1542
# Reaction no.  2
# Attempting to remove reaction:  TRPt ...
# Initial PM reactions: 2465
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.636004999999983
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['TRPt']
# Zero-expression evidence for reaction...
# 2465
# 2465
# check_model_function done ....
# PM reactions (before): 2465
# Removed all inactive reactions
# PM reactions (after): 2464
# Num. removed: 3 (0 core, 3 non-core); Num. remaining: 1541
# Reaction no.  3
# Attempting to remove reaction:  34DHPHEt ...
# Initial PM reactions: 2464
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.215485000000001
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['EX_34dhphe_e', '34DHPHEt']
# Zero-expression evidence for reaction...
# 2464
# 2464
# check_model_function done ....
# PM reactions (before): 2464
# Removed all inactive reactions
# PM reactions (after): 2462
# Num. removed: 5 (0 core, 5 non-core); Num. remaining: 1539
# Reaction no.  4
# Attempting to remove reaction:  TXASr ...
# Initial PM reactions: 2462
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 5 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.595983999999987
# check_model_consistency done ...
# Lengths all--> inactive_G: 6 , inactive_C: [], inactive_NC:['TXA2tr', 'EX_txa2_e', 'PGSr', 'TXASr', 'TXA2te', 'ARACHDtr']
# Zero-expression evidence for reaction...
# 2462
# 2462
# check_model_function done ....
# PM reactions (before): 2462
# Removed all inactive reactions
# PM reactions (after): 2456
# Num. removed: 11 (0 core, 11 non-core); Num. remaining: 1533
# Reaction no.  5
# Attempting to remove reaction:  ADPRIBt ...
# Initial PM reactions: 2456
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.398663999999997
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['ADPRIBt']
# Zero-expression evidence for reaction...
# 2456
# 2456
# check_model_function done ....
# PM reactions (before): 2456
# Removed all inactive reactions
# PM reactions (after): 2455
# Num. removed: 12 (0 core, 12 non-core); Num. remaining: 1532
# Reaction no.  6
# Attempting to remove reaction:  SRTNtu ...
# Initial PM reactions: 2455
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.711941999999965
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['SRTNtu']
# Zero-expression evidence for reaction...
# 2455
# 2455
# check_model_function done ....
# PM reactions (before): 2455
# Removed all inactive reactions
# PM reactions (after): 2454
# Num. removed: 13 (0 core, 13 non-core); Num. remaining: 1531
# Reaction no.  7
# Attempting to remove reaction:  DEBRISOQUINEt ...
# Initial PM reactions: 2454
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.350291999999968
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: [], inactive_NC:['DEBRISOQUINEt', 'EX_4hdebrisoquine_e', 'EX_debrisoquine_e', '4HDEBRISOQUINEte', 'P4502D6']
# Zero-expression evidence for reaction...
# 2454
# 2454
# check_model_function done ....
# PM reactions (before): 2454
# Removed all inactive reactions
# PM reactions (after): 2449
# Num. removed: 18 (0 core, 18 non-core); Num. remaining: 1526
# Reaction no.  8
# Attempting to remove reaction:  CHATn ...
# Initial PM reactions: 2449
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.243711000000019
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: [], inactive_NC:['CHATn', 'ACHtn', 'COAtn', 'CHOLtn', 'ACCOAtn']
# Zero-expression evidence for reaction...
# 2449
# 2449
# check_model_function done ....
# PM reactions (before): 2449
# Removed all inactive reactions
# PM reactions (after): 2444
# Num. removed: 23 (0 core, 23 non-core); Num. remaining: 1521
# Reaction no.  9
# Attempting to remove reaction:  NRPPHRtu ...
# Initial PM reactions: 2444
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.195298999999977
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['NRPPHRtu']
# Zero-expression evidence for reaction...
# 2444
# 2444
# check_model_function done ....
# PM reactions (before): 2444
# Removed all inactive reactions
# PM reactions (after): 2443
# Num. removed: 24 (0 core, 24 non-core); Num. remaining: 1520
# Reaction no.  10
# Attempting to remove reaction:  HISTAtu ...
# Initial PM reactions: 2443
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.617766000000017
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['HISTAtu']
# Zero-expression evidence for reaction...
# 2443
# 2443
# check_model_function done ....
# PM reactions (before): 2443
# Removed all inactive reactions
# PM reactions (after): 2442
# Num. removed: 25 (0 core, 25 non-core); Num. remaining: 1519
# Reaction no.  11
# Attempting to remove reaction:  UREAt ...
# Initial PM reactions: 2442
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.526260000000036
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['UREAt']
# Zero-expression evidence for reaction...
# 2442
# 2442
# check_model_function done ....
# PM reactions (before): 2442
# Removed all inactive reactions
# PM reactions (after): 2441
# Num. removed: 26 (0 core, 26 non-core); Num. remaining: 1518
# Reaction no.  12
# Attempting to remove reaction:  THMTPt ...
# Initial PM reactions: 2441
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.174365000000023
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: ['THMt3'], inactive_NC:['EX_thm_e', 'EX_thmtp_e', 'THMTPt']
# Zero-expression evidence for reaction...
# 2441
# 2441
# check_model_function done ....
# PM reactions (before): 2441
# Removed all inactive reactions
# PM reactions (after): 2437
# Num. removed: 30 (1 core, 29 non-core); Num. remaining: 1515
# Reaction no.  13
# Attempting to remove reaction:  PROSTGF2t ...
# Initial PM reactions: 2437
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.204353999999967
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: ['CBR2'], inactive_NC:['EX_prostgf2_e', 'EX_prostge2_e', 'PROSTGF2t']
# Zero-expression evidence for reaction...
# 2437
# 2437
# check_model_function done ....
# PM reactions (before): 2437
# Removed all inactive reactions
# PM reactions (after): 2433
# Num. removed: 34 (2 core, 32 non-core); Num. remaining: 1512
# Reaction no.  14
# Attempting to remove reaction:  DOPAtu ...
# Initial PM reactions: 2433
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.605373000000043
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['DOPAtu']
# Zero-expression evidence for reaction...
# 2433
# 2433
# check_model_function done ....
# PM reactions (before): 2433
# Removed all inactive reactions
# PM reactions (after): 2432
# Num. removed: 35 (2 core, 33 non-core); Num. remaining: 1511
# Reaction no.  15
# Attempting to remove reaction:  5FTHFt2 ...
# Initial PM reactions: 2432
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.796852999999999
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: ['FTHFCL'], inactive_NC:['5FTHFt2', 'EX_5fthf_e']
# Zero-expression evidence for reaction...
# 2432
# 2432
# check_model_function done ....
# Len P: 1511
# num_removed 35
# Len P AFTER 1510
# No reactions removed
# result 1.1
# Num. removed: 35 (2 core, 33 non-core); Num. remaining: 1510
# Reaction no.  16
# Attempting to remove reaction:  ACGAM2E ...
# Initial PM reactions: 2432
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.533122999999989
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: ['AHEXASEly', 'UAG2EMA', 'SIAASEly', 'GASNASEly', 'GALASE1ly', 'ACNAMlt'], inactive_NC:['ACGAM2E', 'GALtly', 'S2L2N2M2MASNtly', 'ENGASEly']
# Zero-expression evidence for reaction...
# 2432
# 2432
# check_model_function done ....
# Len P: 1510
# num_removed 35
# Len P AFTER 1509
# No reactions removed
# result 1.1
# Num. removed: 35 (2 core, 33 non-core); Num. remaining: 1509
# Reaction no.  17
# Attempting to remove reaction:  HIStiDF ...
# Initial PM reactions: 2432
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.242641999999989
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['HIStiDF']
# Zero-expression evidence for reaction...
# 2432
# 2432
# check_model_function done ....
# PM reactions (before): 2432
# Removed all inactive reactions
# PM reactions (after): 2431
# Num. removed: 36 (2 core, 34 non-core); Num. remaining: 1508
# Reaction no.  18
# Attempting to remove reaction:  PHEtec ...
# Initial PM reactions: 2431
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.737789000000021
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['PHEtec']
# Zero-expression evidence for reaction...
# 2431
# 2431
# check_model_function done ....
# PM reactions (before): 2431
# Removed all inactive reactions
# PM reactions (after): 2430
# Num. removed: 37 (2 core, 35 non-core); Num. remaining: 1507
# Reaction no.  19
# Attempting to remove reaction:  AGTix ...
# Initial PM reactions: 2430
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.127017999999964
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: ['HPYRRy', 'HPYRR2x'], inactive_NC:['AGTix', 'EX_glyc__S_e', 'HPYRDC', 'GLYCK2', 'SPTix', 'HPYRtp', 'GLYC_St', 'SERtp']
# Zero-expression evidence for reaction...
# 2430
# 2430
# check_model_function done ....
# PM reactions (before): 2430
# Removed all inactive reactions
# PM reactions (after): 2420
# Num. removed: 47 (4 core, 43 non-core); Num. remaining: 1499
# Reaction no.  20
# Attempting to remove reaction:  FOLt2 ...
# Initial PM reactions: 2420
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.171514999999999
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: ['FOLR2'], inactive_NC:['FOLt2', 'EX_fol_e']
# Zero-expression evidence for reaction...
# 2420
# 2420
# check_model_function done ....
# Len P: 1499
# num_removed 47
# Len P AFTER 1498
# No reactions removed
# result 1.1
# Num. removed: 47 (4 core, 43 non-core); Num. remaining: 1498
# Reaction no.  21
# Attempting to remove reaction:  THYOXt2 ...
# Initial PM reactions: 2420
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.16231700000003
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['THYOXt2']
# Zero-expression evidence for reaction...
# 2420
# 2420
# check_model_function done ....
# PM reactions (before): 2420
# Removed all inactive reactions
# PM reactions (after): 2419
# Num. removed: 48 (4 core, 44 non-core); Num. remaining: 1497
# Reaction no.  22
# Attempting to remove reaction:  UREAtm ...
# Initial PM reactions: 2419
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.928636999999981
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: ['ARGNm', 'ARGtm'], inactive_NC:['UREAtm']
# Zero-expression evidence for reaction...
# 2419
# 2419
# check_model_function done ....
# Len P: 1497
# num_removed 48
# Len P AFTER 1496
# No reactions removed
# result 1.1
# Num. removed: 48 (4 core, 44 non-core); Num. remaining: 1496
# Reaction no.  23
# Attempting to remove reaction:  TRIODTHYt2 ...
# Initial PM reactions: 2419
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.184527000000003
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['TRIODTHYt2']
# Zero-expression evidence for reaction...
# 2419
# 2419
# check_model_function done ....
# PM reactions (before): 2419
# Removed all inactive reactions
# PM reactions (after): 2418
# Num. removed: 49 (4 core, 45 non-core); Num. remaining: 1495
# Reaction no.  24
# Attempting to remove reaction:  L_LACtcm ...
# Initial PM reactions: 2418
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.169236999999953
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['L_LACtcm']
# Zero-expression evidence for reaction...
# 2418
# 2418
# check_model_function done ....
# PM reactions (before): 2418
# Removed all inactive reactions
# PM reactions (after): 2417
# Num. removed: 50 (4 core, 46 non-core); Num. remaining: 1494
# Reaction no.  25
# Attempting to remove reaction:  It ...
# Initial PM reactions: 2417
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.191906000000017
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['It']
# Zero-expression evidence for reaction...
# 2417
# 2417
# check_model_function done ....
# PM reactions (before): 2417
# Removed all inactive reactions
# PM reactions (after): 2416
# Num. removed: 51 (4 core, 47 non-core); Num. remaining: 1493
# Reaction no.  26
# Attempting to remove reaction:  AMETt2m ...
# Initial PM reactions: 2416
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.243517999999995
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: ['CDSm', 'PETOHMm_hs', 'PCHOLPm_hs', 'CYTDtm', 'NDPK3m'], inactive_NC:['CYTDK2m', 'PCFLOPm', 'CDPDAGtm', 'AMETt2m', 'CYTK1m']
# Zero-expression evidence for reaction...
# 2416
# 2416
# check_model_function done ....
# Len P: 1493
# num_removed 51
# Len P AFTER 1492
# No reactions removed
# result 1.1
# Num. removed: 51 (4 core, 47 non-core); Num. remaining: 1492
# Reaction no.  27
# Attempting to remove reaction:  AMACRp ...
# Initial PM reactions: 2416
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 20 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.089556000000016
# check_model_consistency done ...
# Lengths all--> inactive_G: 21 , inactive_C: ['SCPx', 'HSD17B4x'], inactive_NC:['P45027A11m', 'AKR1D2', 'XOLDIOLONEt', 'EX_tchola_e', 'AKR1C42', 'AMACRp', 'P45027A12m', 'THCHOLSTOICtm', 'P4508B13r', 'TCHOLAtx', 'BAAT2x', 'P45027A13m', 'BAAT1x', 'P4508B11r', 'GCHOLAtx', 'VLCSp', 'EX_gchola_e', 'XOLTRIOLtm', 'ACOX2x']
# Zero-expression evidence for reaction...
# 2416
# 2416
# check_model_function done ....
# PM reactions (before): 2416
# Removed all inactive reactions
# PM reactions (after): 2395
# Num. removed: 72 (6 core, 66 non-core); Num. remaining: 1473
# Reaction no.  28
# Attempting to remove reaction:  TYRt ...
# Initial PM reactions: 2395
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.091493000000014
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['TYRt']
# Zero-expression evidence for reaction...
# 2395
# 2395
# check_model_function done ....
# PM reactions (before): 2395
# Removed all inactive reactions
# PM reactions (after): 2394
# Num. removed: 73 (6 core, 67 non-core); Num. remaining: 1472
# Reaction no.  29
# Attempting to remove reaction:  ACOX22x ...
# Initial PM reactions: 2394
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.000072999999929
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: ['SCP2x', 'HSD17B42x'], inactive_NC:['DGCHOLte', 'FADtx', 'AMACR2p', 'FADH2tx', 'EX_dgchol_e', 'DGCHOLtx', 'ACOX22x', 'BAAT3x']
# Zero-expression evidence for reaction...
# 2394
# 2394
# check_model_function done ....
# PM reactions (before): 2394
# Removed all inactive reactions
# PM reactions (after): 2384
# Num. removed: 83 (8 core, 75 non-core); Num. remaining: 1464
# Reaction no.  30
# Attempting to remove reaction:  DNDPt47m ...
# Initial PM reactions: 2384
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.043120999999928
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['DNDPt47m']
# Zero-expression evidence for reaction...
# 2384
# 2384
# check_model_function done ....
# PM reactions (before): 2384
# Removed all inactive reactions
# PM reactions (after): 2383
# Num. removed: 84 (8 core, 76 non-core); Num. remaining: 1463
# Reaction no.  31
# Attempting to remove reaction:  SERDGLYexR ...
# Initial PM reactions: 2383
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.005862999999977
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['SERDGLNexR', 'SERDGLYexR']
# Zero-expression evidence for reaction...
# 2383
# 2383
# check_model_function done ....
# PM reactions (before): 2383
# Removed all inactive reactions
# PM reactions (after): 2381
# Num. removed: 86 (8 core, 78 non-core); Num. remaining: 1461
# Reaction no.  32
# Attempting to remove reaction:  DNDPt38m ...
# Initial PM reactions: 2381
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.678948999999989
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['DNDPt38m']
# Zero-expression evidence for reaction...
# 2381
# 2381
# check_model_function done ....
# PM reactions (before): 2381
# Removed all inactive reactions
# PM reactions (after): 2380
# Num. removed: 87 (8 core, 79 non-core); Num. remaining: 1460
# Reaction no.  33
# Attempting to remove reaction:  PGDI ...
# Initial PM reactions: 2380
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.949910999999929
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: ['PROSTGD2t'], inactive_NC:['PGDI', 'PGS', 'EX_prostgd2_e']
# Zero-expression evidence for reaction...
# 2380
# 2380
# check_model_function done ....
# PM reactions (before): 2380
# Removed all inactive reactions
# PM reactions (after): 2376
# Num. removed: 91 (9 core, 82 non-core); Num. remaining: 1457
# Reaction no.  34
# Attempting to remove reaction:  PROSTGE2t2 ...
# Initial PM reactions: 2376
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.964616999999976
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['PROSTGE2t2']
# Zero-expression evidence for reaction...
# 2376
# 2376
# check_model_function done ....
# PM reactions (before): 2376
# Removed all inactive reactions
# PM reactions (after): 2375
# Num. removed: 92 (9 core, 83 non-core); Num. remaining: 1456
# Reaction no.  35
# Attempting to remove reaction:  DNDPt46m ...
# Initial PM reactions: 2375
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.019681999999989
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['DNDPt46m']
# Zero-expression evidence for reaction...
# 2375
# 2375
# check_model_function done ....
# PM reactions (before): 2375
# Removed all inactive reactions
# PM reactions (after): 2374
# Num. removed: 93 (9 core, 84 non-core); Num. remaining: 1455
# Reaction no.  36
# Attempting to remove reaction:  DNDPt22m ...
# Initial PM reactions: 2374
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.984964999999988
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['DNDPt22m']
# Zero-expression evidence for reaction...
# 2374
# 2374
# check_model_function done ....
# PM reactions (before): 2374
# Removed all inactive reactions
# PM reactions (after): 2373
# Num. removed: 94 (9 core, 85 non-core); Num. remaining: 1454
# Reaction no.  37
# Attempting to remove reaction:  DNDPt14m ...
# Initial PM reactions: 2373
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.946279000000004
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['DNDPt14m']
# Zero-expression evidence for reaction...
# 2373
# 2373
# check_model_function done ....
# PM reactions (before): 2373
# Removed all inactive reactions
# PM reactions (after): 2372
# Num. removed: 95 (9 core, 86 non-core); Num. remaining: 1453
# Reaction no.  38
# Attempting to remove reaction:  DNDPt37m ...
# Initial PM reactions: 2372
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.930235000000039
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['DNDPt37m']
# Zero-expression evidence for reaction...
# 2372
# 2372
# check_model_function done ....
# PM reactions (before): 2372
# Removed all inactive reactions
# PM reactions (after): 2371
# Num. removed: 96 (9 core, 87 non-core); Num. remaining: 1452
# Reaction no.  39
# Attempting to remove reaction:  TRPO2 ...
# Initial PM reactions: 2371
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.933934999999906
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: [], inactive_NC:['PCLAD', 'KYN3OX', 'TRPO2', 'QUILSYN', 'NNDPR', 'AM6SAD', '3HAO', 'AMCOXO', 'HKYNH', 'FKYNH']
# Zero-expression evidence for reaction...
# 2371
# 2371
# check_model_function done ....
# PM reactions (before): 2371
# Removed all inactive reactions
# PM reactions (after): 2361
# Num. removed: 106 (9 core, 97 non-core); Num. remaining: 1442
# Reaction no.  40
# Attempting to remove reaction:  BCDO ...
# Initial PM reactions: 2361
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.901912999999922
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: [], inactive_NC:['EX_caro_e', 'CAROtr', 'BCDO']
# Zero-expression evidence for reaction...
# 2361
# 2361
# check_model_function done ....
# PM reactions (before): 2361
# Removed all inactive reactions
# PM reactions (after): 2358
# Num. removed: 109 (9 core, 100 non-core); Num. remaining: 1439
# Reaction no.  41
# Attempting to remove reaction:  TRPHYDRO2 ...
# Initial PM reactions: 2358
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 7 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.63169999999991
# check_model_consistency done ...
# Lengths all--> inactive_G: 8 , inactive_C: [], inactive_NC:['TRPHYDRO2', 'SRTNt6_2_r', '5HLTDL', 'TRPt4', 'EX_trp__L_e', 'EX_srtn_e', '5HTRPVESSEC', 'EX_5htrp_e']
# Zero-expression evidence for reaction...
# 2358
# 2358
# check_model_function done ....
# PM reactions (before): 2358
# Removed all inactive reactions
# PM reactions (after): 2350
# Num. removed: 117 (9 core, 108 non-core); Num. remaining: 1431
# Reaction no.  42
# Attempting to remove reaction:  ALOX5 ...
# Initial PM reactions: 2350
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 12 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.22597200000007
# check_model_consistency done ...
# Lengths all--> inactive_G: 13 , inactive_C: ['LTC4Sr'], inactive_NC:['LTC4CP', 'ALOX52', 'GGT6', 'LEUKTRD4tr', 'GGT5r', 'LTD4DP', 'EX_leuktrC4_e', 'GLUtr', 'GTHRDtr', 'ALOX5', 'LEUKTRA4tr', 'LEUKTRC4t']
# Zero-expression evidence for reaction...
# 2350
# 2350
# check_model_function done ....
# PM reactions (before): 2350
# Removed all inactive reactions
# PM reactions (after): 2337
# Num. removed: 130 (10 core, 120 non-core); Num. remaining: 1419
# Reaction no.  43
# Attempting to remove reaction:  UGT1A5r ...
# Initial PM reactions: 2337
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.832147000000077
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: [], inactive_NC:['EX_retnglc_e', 'UGT1A5r', 'RETNtr', 'RETNGLCt', 'RETNGLCtr']
# Zero-expression evidence for reaction...
# 2337
# 2337
# check_model_function done ....
# PM reactions (before): 2337
# Removed all inactive reactions
# PM reactions (after): 2332
# Num. removed: 135 (10 core, 125 non-core); Num. remaining: 1414
# Reaction no.  44
# Attempting to remove reaction:  UGT1A2r ...
# Initial PM reactions: 2332
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.717626999999993
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: [], inactive_NC:['EX_bildglcur_e', 'BILDGLCURtr', 'UGT1A2r']
# Zero-expression evidence for reaction...
# 2332
# 2332
# check_model_function done ....
# PM reactions (before): 2332
# Removed all inactive reactions
# PM reactions (after): 2329
# Num. removed: 138 (10 core, 128 non-core); Num. remaining: 1411
# Reaction no.  45
# Attempting to remove reaction:  UGT1A5r2 ...
# Initial PM reactions: 2329
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.756289000000038
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: [], inactive_NC:['UGT1A5r2', 'RETNGLCt2', 'EX_13_cis_retnglc_e', 'RETNGLCt2r', 'RETNtr2']
# Zero-expression evidence for reaction...
# 2329
# 2329
# check_model_function done ....
# PM reactions (before): 2329
# Removed all inactive reactions
# PM reactions (after): 2324
# Num. removed: 143 (10 core, 133 non-core); Num. remaining: 1406
# Reaction no.  46
# Attempting to remove reaction:  UGT1A9r ...
# Initial PM reactions: 2324
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.769259000000034
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: [], inactive_NC:['5ADTSTSTERONEGLCtr', 'UGT1A9r', 'EX_5adtststeroneglc_e', '5ADTSTSTERONEGLCte', '5ADTSTSTERONEtr']
# Zero-expression evidence for reaction...
# 2324
# 2324
# check_model_function done ....
# PM reactions (before): 2324
# Removed all inactive reactions
# PM reactions (after): 2319
# Num. removed: 148 (10 core, 138 non-core); Num. remaining: 1401
# Reaction no.  47
# Attempting to remove reaction:  TYRDOPO ...
# Initial PM reactions: 2319
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.737721000000079
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['TYRDOPO']
# Zero-expression evidence for reaction...
# 2319
# 2319
# check_model_function done ....
# PM reactions (before): 2319
# Removed all inactive reactions
# PM reactions (after): 2318
# Num. removed: 149 (10 core, 139 non-core); Num. remaining: 1400
# Reaction no.  48
# Attempting to remove reaction:  HISDr ...
# Initial PM reactions: 2318
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.595141000000012
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: [], inactive_NC:['URCN', 'HISDr', 'IZPN', 'GluForTx', 'FTCD']
# Zero-expression evidence for reaction...
# 2318
# 2318
# check_model_function done ....
# PM reactions (before): 2318
# Removed all inactive reactions
# PM reactions (after): 2313
# Num. removed: 154 (10 core, 144 non-core); Num. remaining: 1395
# Reaction no.  49
# Attempting to remove reaction:  5MTHFt2 ...
# Initial PM reactions: 2313
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.640276999999969
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['5MTHFt2']
# Zero-expression evidence for reaction...
# 2313
# 2313
# check_model_function done ....
# PM reactions (before): 2313
# Removed all inactive reactions
# PM reactions (after): 2312
# Num. removed: 155 (10 core, 145 non-core); Num. remaining: 1394
# Reaction no.  50
# Attempting to remove reaction:  TYR3MO2 ...
# Initial PM reactions: 2312
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 7 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.246520999999802
# check_model_consistency done ...
# Lengths all--> inactive_G: 8 , inactive_C: [], inactive_NC:['3HLYTCL', 'TYRDOPO3', 'DOPACHRMISO', 'TYR3MO2', 'DM_melanin_c', 'DOPAQNISO1', 'TYRASE', 'DCT']
# Zero-expression evidence for reaction...
# 2312
# 2312
# check_model_function done ....
# PM reactions (before): 2312
# Removed all inactive reactions
# PM reactions (after): 2304
# Num. removed: 163 (10 core, 153 non-core); Num. remaining: 1386
# Reaction no.  51
# Attempting to remove reaction:  ADKd ...
# Initial PM reactions: 2304
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.758605999999872
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['ADKd']
# Zero-expression evidence for reaction...
# 2304
# 2304
# check_model_function done ....
# PM reactions (before): 2304
# Removed all inactive reactions
# PM reactions (after): 2303
# Num. removed: 164 (10 core, 154 non-core); Num. remaining: 1385
# Reaction no.  52
# Attempting to remove reaction:  ALADGLYexR ...
# Initial PM reactions: 2303
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.6486039999999775
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['ALADGLYexR']
# Zero-expression evidence for reaction...
# 2303
# 2303
# check_model_function done ....
# PM reactions (before): 2303
# Removed all inactive reactions
# PM reactions (after): 2302
# Num. removed: 165 (10 core, 155 non-core); Num. remaining: 1384
# Reaction no.  53
# Attempting to remove reaction:  UGT1A1r ...
# Initial PM reactions: 2302
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.6749620000000505
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: ['ESTRONEGLCt'], inactive_NC:['ESTRONEGLCtr', 'UGT1A1r', 'EX_estroneglc_e']
# Zero-expression evidence for reaction...
# 2302
# 2302
# check_model_function done ....
# PM reactions (before): 2302
# Removed all inactive reactions
# PM reactions (after): 2298
# Num. removed: 169 (11 core, 158 non-core); Num. remaining: 1381
# Reaction no.  54
# Attempting to remove reaction:  GCC2bim ...
# Initial PM reactions: 2298
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.644381000000067
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: [], inactive_NC:['GCC2cm', 'GCC2am', 'GCC2bim']
# Zero-expression evidence for reaction...
# 2298
# 2298
# check_model_function done ....
# PM reactions (before): 2298
# Removed all inactive reactions
# PM reactions (after): 2295
# Num. removed: 172 (11 core, 161 non-core); Num. remaining: 1378
# Reaction no.  55
# Attempting to remove reaction:  GCCbim ...
# Initial PM reactions: 2295
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.643700000000081
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: [], inactive_NC:['GCCcm', 'GCCbim', 'GCCam']
# Zero-expression evidence for reaction...
# 2295
# 2295
# check_model_function done ....
# PM reactions (before): 2295
# Removed all inactive reactions
# PM reactions (after): 2292
# Num. removed: 175 (11 core, 164 non-core); Num. remaining: 1375
# Reaction no.  56
# Attempting to remove reaction:  DNDPt7m ...
# Initial PM reactions: 2292
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.586203000000069
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['DNDPt7m']
# Zero-expression evidence for reaction...
# 2292
# 2292
# check_model_function done ....
# PM reactions (before): 2292
# Removed all inactive reactions
# PM reactions (after): 2291
# Num. removed: 176 (11 core, 165 non-core); Num. remaining: 1374
# Reaction no.  57
# Attempting to remove reaction:  DNDPt62m ...
# Initial PM reactions: 2291
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.632641000000149
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['DNDPt62m']
# Zero-expression evidence for reaction...
# 2291
# 2291
# check_model_function done ....
# PM reactions (before): 2291
# Removed all inactive reactions
# PM reactions (after): 2290
# Num. removed: 177 (11 core, 166 non-core); Num. remaining: 1373
# Reaction no.  58
# Attempting to remove reaction:  THFt2 ...
# Initial PM reactions: 2290
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.581032999999934
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: ['FTHFCL', 'FOLR2'], inactive_NC:['5MTHFt', '5FTHFt2', 'EX_fol_e', 'CLOHtex2', 'EX_5fthf_e', 'FOLt2', 'THFt2', 'EX_5mthf_e']
# Zero-expression evidence for reaction...
# 2290
# 2290
# check_model_function done ....
# PM reactions (before): 2290
# Removed all inactive reactions
# PM reactions (after): 2280
# Num. removed: 187 (13 core, 174 non-core); Num. remaining: 1367
# Reaction no.  59
# Attempting to remove reaction:  UGT1A6r ...
# Initial PM reactions: 2280
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.529728999999861
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: [], inactive_NC:['ESTRADIOLGLCtr', 'EX_estradiolglc_e', 'UGT1A6r']
# Zero-expression evidence for reaction...
# 2280
# 2280
# check_model_function done ....
# PM reactions (before): 2280
# Removed all inactive reactions
# PM reactions (after): 2277
# Num. removed: 190 (13 core, 177 non-core); Num. remaining: 1364
# Reaction no.  60
# Attempting to remove reaction:  DNDPt49m ...
# Initial PM reactions: 2277
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.541009000000031
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['DNDPt49m']
# Zero-expression evidence for reaction...
# 2277
# 2277
# check_model_function done ....
# PM reactions (before): 2277
# Removed all inactive reactions
# PM reactions (after): 2276
# Num. removed: 191 (13 core, 178 non-core); Num. remaining: 1363
# Reaction no.  61
# Attempting to remove reaction:  CYStec ...
# Initial PM reactions: 2276
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.551721999999927
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['CYStec']
# Zero-expression evidence for reaction...
# 2276
# 2276
# check_model_function done ....
# PM reactions (before): 2276
# Removed all inactive reactions
# PM reactions (after): 2275
# Num. removed: 192 (13 core, 179 non-core); Num. remaining: 1362
# Reaction no.  62
# Attempting to remove reaction:  DNDPt4m ...
# Initial PM reactions: 2275
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.563564000000042
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['DNDPt4m']
# Zero-expression evidence for reaction...
# 2275
# 2275
# check_model_function done ....
# PM reactions (before): 2275
# Removed all inactive reactions
# PM reactions (after): 2274
# Num. removed: 193 (13 core, 180 non-core); Num. remaining: 1361
# Reaction no.  63
# Attempting to remove reaction:  DNDPt5m ...
# Initial PM reactions: 2274
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.535035999999991
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['DNDPt5m']
# Zero-expression evidence for reaction...
# 2274
# 2274
# check_model_function done ....
# PM reactions (before): 2274
# Removed all inactive reactions
# PM reactions (after): 2273
# Num. removed: 194 (13 core, 181 non-core); Num. remaining: 1360
# Reaction no.  64
# Attempting to remove reaction:  DNDPt60m ...
# Initial PM reactions: 2273
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.536923999999999
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['DNDPt60m']
# Zero-expression evidence for reaction...
# 2273
# 2273
# check_model_function done ....
# PM reactions (before): 2273
# Removed all inactive reactions
# PM reactions (after): 2272
# Num. removed: 195 (13 core, 182 non-core); Num. remaining: 1359
# Reaction no.  65
# Attempting to remove reaction:  DNDPt61m ...
# Initial PM reactions: 2272
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.832498000000214
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['DNDPt61m']
# Zero-expression evidence for reaction...
# 2272
# 2272
# check_model_function done ....
# PM reactions (before): 2272
# Removed all inactive reactions
# PM reactions (after): 2271
# Num. removed: 196 (13 core, 183 non-core); Num. remaining: 1358
# Reaction no.  66
# Attempting to remove reaction:  THRGLYexR ...
# Initial PM reactions: 2271
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.513135000000148
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['THRGLYexR']
# Zero-expression evidence for reaction...
# 2271
# 2271
# check_model_function done ....
# PM reactions (before): 2271
# Removed all inactive reactions
# PM reactions (after): 2270
# Num. removed: 197 (13 core, 184 non-core); Num. remaining: 1357
# Reaction no.  67
# Attempting to remove reaction:  DNDPt8m ...
# Initial PM reactions: 2270
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.531338000000005
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['DNDPt8m']
# Zero-expression evidence for reaction...
# 2270
# 2270
# check_model_function done ....
# PM reactions (before): 2270
# Removed all inactive reactions
# PM reactions (after): 2269
# Num. removed: 198 (13 core, 185 non-core); Num. remaining: 1356
# Reaction no.  68
# Attempting to remove reaction:  DNDPt16m ...
# Initial PM reactions: 2269
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.658894999999802
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['DNDPt16m']
# Zero-expression evidence for reaction...
# 2269
# 2269
# check_model_function done ....
# PM reactions (before): 2269
# Removed all inactive reactions
# PM reactions (after): 2268
# Num. removed: 199 (13 core, 186 non-core); Num. remaining: 1355
# Reaction no.  69
# Attempting to remove reaction:  DNDPt9m ...
# Initial PM reactions: 2268
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.589999999999918
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['DNDPt9m']
# Zero-expression evidence for reaction...
# 2268
# 2268
# check_model_function done ....
# PM reactions (before): 2268
# Removed all inactive reactions
# PM reactions (after): 2267
# Num. removed: 200 (13 core, 187 non-core); Num. remaining: 1354
# Reaction no.  70
# Attempting to remove reaction:  DNDPt24m ...
# Initial PM reactions: 2267
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.46187800000007
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['DNDPt24m']
# Zero-expression evidence for reaction...
# 2267
# 2267
# check_model_function done ....
# PM reactions (before): 2267
# Removed all inactive reactions
# PM reactions (after): 2266
# Num. removed: 201 (13 core, 188 non-core); Num. remaining: 1353
# Reaction no.  71
# Attempting to remove reaction:  DNDPt40m ...
# Initial PM reactions: 2266
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.571177000000034
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['DNDPt40m']
# Zero-expression evidence for reaction...
# 2266
# 2266
# check_model_function done ....
# PM reactions (before): 2266
# Removed all inactive reactions
# PM reactions (after): 2265
# Num. removed: 202 (13 core, 189 non-core); Num. remaining: 1352
# Reaction no.  72
# Attempting to remove reaction:  DNDPt48m ...
# Initial PM reactions: 2265
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.427613999999949
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['DNDPt48m']
# Zero-expression evidence for reaction...
# 2265
# 2265
# check_model_function done ....
# PM reactions (before): 2265
# Removed all inactive reactions
# PM reactions (after): 2264
# Num. removed: 203 (13 core, 190 non-core); Num. remaining: 1351
# Reaction no.  73
# Attempting to remove reaction:  DNDPt52m ...
# Initial PM reactions: 2264
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.565428999999995
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['DNDPt52m']
# Zero-expression evidence for reaction...
# 2264
# 2264
# check_model_function done ....
# PM reactions (before): 2264
# Removed all inactive reactions
# PM reactions (after): 2263
# Num. removed: 204 (13 core, 191 non-core); Num. remaining: 1350
# Reaction no.  74
# Attempting to remove reaction:  DNDPt15m ...
# Initial PM reactions: 2263
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.53709600000002
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['DNDPt15m']
# Zero-expression evidence for reaction...
# 2263
# 2263
# check_model_function done ....
# PM reactions (before): 2263
# Removed all inactive reactions
# PM reactions (after): 2262
# Num. removed: 205 (13 core, 192 non-core); Num. remaining: 1349
# Reaction no.  75
# Attempting to remove reaction:  DNDPt33m ...
# Initial PM reactions: 2262
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.486873999999943
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['DNDPt33m']
# Zero-expression evidence for reaction...
# 2262
# 2262
# check_model_function done ....
# PM reactions (before): 2262
# Removed all inactive reactions
# PM reactions (after): 2261
# Num. removed: 206 (13 core, 193 non-core); Num. remaining: 1348
# Reaction no.  76
# Attempting to remove reaction:  DNDPt23m ...
# Initial PM reactions: 2261
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.532466000000113
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['DNDPt23m']
# Zero-expression evidence for reaction...
# 2261
# 2261
# check_model_function done ....
# PM reactions (before): 2261
# Removed all inactive reactions
# PM reactions (after): 2260
# Num. removed: 207 (13 core, 194 non-core); Num. remaining: 1347
# Reaction no.  77
# Attempting to remove reaction:  DNDPt34m ...
# Initial PM reactions: 2260
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.55252100000007
# check_model_consistency done ...
# ...
# Reaction FACOAL191 is not in Z
# 1371
# 1371
# check_model_function done ....
# No reactions removed
# Num. removed: 1096 (38 core, 1058 non-core); Num. remaining: 23
# Reaction no.  984
# Attempting to remove reaction:  FAEL183 ...
# Initial PM reactions: 1371
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  8.116197000001193
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['FAEL183']
# Reaction FAEL183 is not in Z
# 1371
# 1371
# check_model_function done ....
# Removed non-core inactive reactions
# PM reactions (after): 1370
# Num. removed: 1097 (38 core, 1059 non-core); Num. remaining: 22
# Reaction no.  985
# Attempting to remove reaction:  FAEL184 ...
# Initial PM reactions: 1370
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  8.239496000000145
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['FAEL184']
# Reaction FAEL184 is not in Z
# 1370
# 1370
# check_model_function done ....
# Removed non-core inactive reactions
# PM reactions (after): 1369
# Num. removed: 1098 (38 core, 1060 non-core); Num. remaining: 21
# Reaction no.  986
# Attempting to remove reaction:  FAEL204 ...
# Initial PM reactions: 1369
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  8.21769200000017
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['FAEL204']
# Reaction FAEL204 is not in Z
# 1369
# 1369
# check_model_function done ....
# Removed non-core inactive reactions
# PM reactions (after): 1368
# Num. removed: 1099 (38 core, 1061 non-core); Num. remaining: 20
# Reaction no.  987
# Attempting to remove reaction:  FAEL205 ...
# Initial PM reactions: 1368
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  8.4488620000011
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: ['FACOAL2252'], inactive_NC:['CLPNDt', 'FAEL205', 'EX_clpnd_e']
# Reaction FAEL205 is not in Z
# 1368
# 1368
# check_model_function done ....
# No reactions removed
# Num. removed: 1099 (38 core, 1061 non-core); Num. remaining: 19
# Reaction no.  988
# Attempting to remove reaction:  NAHCO3_HCLt ...
# Initial PM reactions: 1368
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.985108000000764
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['NAHCO3_HCLt']
# Reaction NAHCO3_HCLt is not in Z
# 1368
# 1368
# check_model_function done ....
# Removed non-core inactive reactions
# PM reactions (after): 1367
# Num. removed: 1100 (38 core, 1062 non-core); Num. remaining: 18
# Reaction no.  989
# Attempting to remove reaction:  NNMT ...
# Initial PM reactions: 1367
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 7 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.954147999998895
# check_model_consistency done ...
# Lengths all--> inactive_G: 8 , inactive_C: ['NP1', 'NADS2'], inactive_NC:['NNMT', 'NACt', 'EX_1mncam_e', '1MNCAMti', 'EX_nac_e', 'NNATr_copy2']
# Reaction NNMT is not in Z
# 1367
# 1367
# check_model_function done ....
# No reactions removed
# Num. removed: 1100 (38 core, 1062 non-core); Num. remaining: 17
# Reaction no.  990
# Attempting to remove reaction:  PHETHPTOX2 ...
# Initial PM reactions: 1367
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  8.028102000000217
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: ['PHEt4', 'TYRTA', 'THBPT4ACAMDASE', 'DHPR', 'MACACI'], inactive_NC:['EX_phe__L_e', 'PHETHPTOX2', 'FUMAC', 'HGNTOR', '34HPPOR']
# Reaction PHETHPTOX2 is not in Z
# 1367
# 1367
# check_model_function done ....
# No reactions removed
# Num. removed: 1100 (38 core, 1062 non-core); Num. remaining: 16
# Reaction no.  991
# Attempting to remove reaction:  GGLUCT ...
# Initial PM reactions: 1367
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 7 blocked (inactive) reactions
# Execution time of check_model_consistency:  8.182259000001068
# check_model_consistency done ...
# Lengths all--> inactive_G: 8 , inactive_C: ['AMPTASECG', 'AMPTASECGe', 'OPAH', 'GLUCYS', 'GTHS'], inactive_NC:['GTMLTe', 'GGLUCT', 'CGLYt3_2']
# Reaction GGLUCT is not in Z
# 1367
# 1367
# check_model_function done ....
# No reactions removed
# Num. removed: 1100 (38 core, 1062 non-core); Num. remaining: 15
# Reaction no.  992
# Attempting to remove reaction:  SO4OXAtex2 ...
# Initial PM reactions: 1367
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  8.100105999999869
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['SO4OXAtex2']
# Reaction SO4OXAtex2 is not in Z
# 1367
# 1367
# check_model_function done ....
# Removed non-core inactive reactions
# PM reactions (after): 1366
# Num. removed: 1101 (38 core, 1063 non-core); Num. remaining: 14
# Reaction no.  993
# Attempting to remove reaction:  MTHFD2i ...
# Initial PM reactions: 1366
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  8.07755200000065
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['MTHFD2i']
# Reaction MTHFD2i is not in Z
# 1366
# 1366
# check_model_function done ....
# Removed non-core inactive reactions
# PM reactions (after): 1365
# Num. removed: 1102 (38 core, 1064 non-core); Num. remaining: 13
# Reaction no.  994
# Attempting to remove reaction:  CLOXAtex2 ...
# Initial PM reactions: 1365
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 23 blocked (inactive) reactions
# Execution time of check_model_consistency:  8.049809999998615
# check_model_consistency done ...
# Lengths all--> inactive_G: 24 , inactive_C: ['ARABR', 'GLCAASE9ly', 'NACHEX27ly', 'GLCURtly', 'GLCAASE8ly', 'GCALDD', 'GLXO1', 'FBA4', 'OXAHCOtex', 'XYLUR'], inactive_NC:['ABTD', 'GULNter', 'DGULND', 'GULN3D', 'CLOXAtex2', 'EX_arab__L_e', 'KHK2', 'GLCURter', 'ARAB_Lt', 'HAtly', 'EX_oxa_e', 'GULNDer', 'XYLTD_D', 'EX_ha_e']
# Reaction CLOXAtex2 is not in Z
# 1365
# 1365
# check_model_function done ....
# No reactions removed
# Num. removed: 1102 (38 core, 1064 non-core); Num. remaining: 12
# Reaction no.  995
# Attempting to remove reaction:  SO4CLtex2 ...
# Initial PM reactions: 1365
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  8.095477000000756
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['SO4CLtex2']
# Reaction SO4CLtex2 is not in Z
# 1365
# 1365
# check_model_function done ....
# Removed non-core inactive reactions
# PM reactions (after): 1364
# Num. removed: 1103 (38 core, 1065 non-core); Num. remaining: 11
# Reaction no.  996
# Attempting to remove reaction:  PIter ...
# Initial PM reactions: 1364
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 151 blocked (inactive) reactions
# Execution time of check_model_consistency:  8.301045999998678
# check_model_consistency done ...
# Lengths all--> inactive_G: 152 , inactive_C: ['RTOTAL2CRNCPT1', 'C3STDH1r', 'SOAT12', 'EBP1r', 'CERT2rt', 'C3STKR2r', 'CERK', 'PPPGOm', 'G6PPer', 'PPBNGS', 'PPAer', 'P5CRx', 'BILIRED', 'IPDDIx', 'PNTK', 'HMGCOAS', 'FACOAL241', 'SQLEr', 'P5CR', 'RTOTAL2CRNt', 'DHCR72r', 'RTOTALCRNCPT2', 'ALASm', 'UGCG', 'FCLTm', 'LSTO2r', 'DMATTx', 'FACOAL260', 'RTOTALCRNCPT1', 'DHCR243r', 'RTOTALCRNt', 'DHCR241r', 'PTPATi', 'FACOAL240', 'PNTOt5', 'LSTO1r', 'GBA', 'G6Pter', 'HMBS', 'DHCR242r', 'PPCDC', 'CERT1rt', 'PMEVKx', 'PPNCL3', 'HOXG', 'C3STDH1Pr', 'CPPPGO', 'LCAT1e', 'UDPGD', 'C4STMO1r', 'LNS14DMr', 'UPPDC1', 'C4STMO2r', 'DPCOAK', 'HMGCOARx', 'UDPGLCAter', 'UDPDOLPT_L', 'DHCR71r', 'GRTTx', 'SOAT11', 'C4STMO2Pr', 'LNSTLSr', 'SBPP1er', 'UPP3S', 'FACOAL244_1', 'FACOAL245_1', 'DPMVDx', 'CHSTEROLt', 'DHCRD2', 'C14STRr', 'UDPDOLPT_U', 'SQLSr', 'RTOTAL2CRNCPT2', 'EBP2r'], inactive_NC:['XOLESTte', 'DOLGLCP_Lter', 'BILGLCURte', 'COt', 'TETTET6t', 'EX_lgnc_e', 'EX_tettet6_e', 'EX_nrvnc_e', 'UDPGLCter', 'DOLK_L', 'ARTPLM1m', 'RTOT_2', 'DOLPH_Uer', '5AOPtm', 'PItx', 'NDP7er', 'EX_tetpent6_e', 'DOLPH_Ler', 'FE2tm', 'FATP8t', 'BILGLCURtr', 'SPH1Pter', 'DOLICHOL_Lter', 'G6PDH1er_copy2', 'DOLGPP_Uer', 'ARTFR52', 'DOLGPP_Ler', 'ARTFR56', 'NADPtxu', 'EX_co_e', 'NADPHtxu', 'GLYtm', 'HEXCt', 'EX_pchol_hs_e', 'EX_crmp_hs_e', 'PPPG9tm', 'UGT1A10r', 'GLCMter', 'TETPENT6t', 'EX_pnto__R_e', 'HMGCOAtx', 'ATPtx', 'EX_xolest2_hs_e', 'ARTFR13', 'G6PDH2er', 'SPHGNtr', 'ARTFR45', 'EX_sph1p_e', 'FADtru', 'ADPtx', 'DOLK_U', 'FORtr', 'CHSTEROLt2', 'FADH2tru', 'BILIRUBtr', 'CRMPte', 'SPH1Pte', 'DOLICHOL_Uter', 'EX_xolest_hs_e', 'ARTFR54', 'ARTPLM2m', 'FRDPtr', 'CO2ter', 'PROD2', 'EX_bilglcur_e', 'PIter', 'PHEMEtm', 'ARTFR206', 'DOLGLCP_Uter', 'FATP9t', 'CHSTEROLt3', 'EX_lpchol_hs_e', 'CO2tp', 'EX_hexc_e', 'MEVK1x', 'ARTFR51', 'RTOT5', 'PPItx']
# Reaction PIter is not in Z
# 1364
# 1364
# check_model_function done ....
# No reactions removed
# Num. removed: 1103 (38 core, 1065 non-core); Num. remaining: 10
# Reaction no.  997
# Attempting to remove reaction:  CLHCO3tex2 ...
# Initial PM reactions: 1364
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.98398300000008
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['CLHCO3tex2']
# Reaction CLHCO3tex2 is not in Z
# 1364
# 1364
# check_model_function done ....
# Removed non-core inactive reactions
# PM reactions (after): 1363
# Num. removed: 1104 (38 core, 1066 non-core); Num. remaining: 9
# Reaction no.  998
# Attempting to remove reaction:  SPODMm ...
# Initial PM reactions: 1363
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  8.12197500000002
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['SPODMm']
# Reaction SPODMm is not in Z
# 1363
# 1363
# check_model_function done ....
# Removed non-core inactive reactions
# PM reactions (after): 1362
# Num. removed: 1105 (38 core, 1067 non-core); Num. remaining: 8
# Reaction no.  999
# Attempting to remove reaction:  PRO1xm ...
# Initial PM reactions: 1362
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  8.154898000000685
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['PRO1xm']
# Reaction PRO1xm is not in Z
# 1362
# 1362
# check_model_function done ....
# Removed non-core inactive reactions
# PM reactions (after): 1361
# Num. removed: 1106 (38 core, 1068 non-core); Num. remaining: 7
# Reaction no.  1000
# Attempting to remove reaction:  PROD2m ...
# Initial PM reactions: 1361
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  8.107105999999476
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: ['P5CRm', 'P5CRxm'], inactive_NC:['PROD2m']
# Reaction PROD2m is not in Z
# 1361
# 1361
# check_model_function done ....
# No reactions removed
# Num. removed: 1106 (38 core, 1068 non-core); Num. remaining: 6
# Reaction no.  1001
# Attempting to remove reaction:  RDH2 ...
# Initial PM reactions: 1361
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  8.03012200000012
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: ['RDH2a'], inactive_NC:['RDH2']
# Reaction RDH2 is not in Z
# 1361
# 1361
# check_model_function done ....
# No reactions removed
# Num. removed: 1106 (38 core, 1068 non-core); Num. remaining: 5
# Reaction no.  1002
# Attempting to remove reaction:  RDH3 ...
# Initial PM reactions: 1361
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  8.287710000000516
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: ['RDH3a'], inactive_NC:['RDH3']
# Reaction RDH3 is not in Z
# 1361
# 1361
# check_model_function done ....
# No reactions removed
# Num. removed: 1106 (38 core, 1068 non-core); Num. remaining: 4
# Reaction no.  1003
# Attempting to remove reaction:  RDH4 ...
# Initial PM reactions: 1361
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 5 blocked (inactive) reactions
# Execution time of check_model_consistency:  8.31840100000045
# check_model_consistency done ...
# Lengths all--> inactive_G: 6 , inactive_C: ['RDH1a', 'RAI3'], inactive_NC:['RADH4', 'RADH2', 'RDH4', 'RETI3']
# Reaction RDH4 is not in Z
# 1361
# 1361
# check_model_function done ....
# No reactions removed
# Num. removed: 1106 (38 core, 1068 non-core); Num. remaining: 3
# Reaction no.  1004
# Attempting to remove reaction:  PSDm_hs ...
# Initial PM reactions: 1361
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 39 blocked (inactive) reactions
# Execution time of check_model_consistency:  8.253333999999086
# check_model_consistency done ...
# Lengths all--> inactive_G: 40 , inactive_C: ['PIPLC', 'PCHOLPr_hs', 'MI145PP', 'PI5P4K', 'PIK4', 'CYTDt', 'CDIPTr', 'PI3P4K', 'MI14PP', 'MI3PP', 'PCHOLPm_hs', 'NDPK3m', 'PI45PLC', 'MI134PP', 'PETOHMr_hs', 'MI34PP', 'PETOHMm_hs', 'PI4PLC', 'NTD4e', 'CYTDtm', 'PI3P5K', 'MI1345PP', 'MI145PK', 'CDSm', 'PIK5', 'MI4PP'], inactive_NC:['CYTDK2m', 'CDPDAGtm', 'AHCYStr', 'PSDm_hs', 'CHLtm', 'PSFLIPm', 'PE_HStm', 'PA_HSter', 'AMETt2m', 'CHOLtr', 'CYTK1m', 'PE_HSter', 'AMETr', 'EX_cmp_e']
# Reaction PSDm_hs is not in Z
# 1361
# 1361
# check_model_function done ....
# No reactions removed
# Num. removed: 1106 (38 core, 1068 non-core); Num. remaining: 2
# Reaction no.  1005
# Attempting to remove reaction:  PPCOACm ...
# Initial PM reactions: 1361
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 26 blocked (inactive) reactions
# Execution time of check_model_consistency:  8.41524600000048
# check_model_consistency done ...
# Lengths all--> inactive_G: 27 , inactive_C: ['MMMm', 'PTDCACRNCPT1', 'OIVD3m', 'HPDCACRNt', 'PTDCACRNCPT2', 'HPDCACRNCPT2', 'ECOAH9m', 'FACOAL150', 'ACACT10m', 'HACD9m', 'ACOAD10m', 'FACOAL170', 'ILETAm', 'HPDCACRNCPT1', 'FAOXC150m', 'MMCDm', 'FAOXC170m', 'PTDCACRNt'], inactive_NC:['MMEm', 'EX_ile__L_e', 'EX_hpdca_e', 'ILEtmi', 'ILEtec', 'HPDCAt', 'EX_ptdca_e', 'PTDCAt', 'PPCOACm']
# Reaction PPCOACm is not in Z
# 1361
# 1361
# check_model_function done ....
# No reactions removed
# Num. removed: 1106 (38 core, 1068 non-core); Num. remaining: 1
# Reaction no.  1006
# Attempting to remove reaction:  PIt2m ...
# Initial PM reactions: 1361
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  8.52263800000037
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['PIt2m']
# Reaction PIt2m is not in Z
# 1361
# 1361
# check_model_function done ....
# Removed non-core inactive reactions
# PM reactions (after): 1360
# Num. removed: 1107 (38 core, 1069 non-core); Num. remaining: 0
# prune_model done ....

# %%
pruneTime
# Out:
# 12646.892923

# %%
len(PM.reactions)
# Out:
# 1360

# %%
len(PM.metabolites)
# Out:
# 1085

# %%
len(PM.genes)
# Out:
# 1123

# %%
# total cores and non-cores

# %%
from cobra import *
# write out PM model
io.write_sbml_model(PM,"python_recon1_BEC2_method1.xml")
