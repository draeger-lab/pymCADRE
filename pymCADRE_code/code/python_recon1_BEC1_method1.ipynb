# %%
__author__ = "Nantia Leonidou"
__description__ = " Main script "
########################################
# copied from run_mcadre.py
########################################

from test_Inputs.test_Inputs import *
import pandas as pd

# read model
model = io.read_sbml_model('../pre_processing/dataset/RECON1.xml')
# genes
G = pd.read_csv('../pre_processing/dataset/1_GPL570_GSE3397/1_GPL570_GSE3397_entrez_ids.csv')
G = list(G['ENTREZ_GENE_ID'])
# ubiquity scores
U = pd.read_csv('../pre_processing/dataset/1_GPL570_GSE3397/1_GPL570_GSE3397_ubiquity.csv', header=None)
U = U.rename(columns={0: "Scores"})
U = list(U['Scores'])
# confidence scores
confidence_scores = get_test_inputs('../testInputs.mat','../humanModel.mat')[3]

# %%
from rank.rank_reactions import *
GM, C, NC, P, Z, model_C = rank_reactions(model, G, U, confidence_scores, [], 1)
# Out:
# /Users/leonidou/Documents/mCADRE_PYTHON_code/code/rank/calc_expr_evidence.py:34 RuntimeWarning: All-NaN axis encountered
# /Users/leonidou/Documents/mCADRE_PYTHON_code/code/rank/calc_expr_evidence.py:58 RuntimeWarning: All-NaN axis encountered
# Checking all reactions (fastFVA)...
# Model consists of 1274 blocked (inactive) reactions
# Execution time of check_model_consistency:  16.280468000000003
# check_model_consistency done ...
# rank_reactions done ...

# %%
from prune.prune_model import *
print('Generic model passed precursor metabolites test')

##############################################################
# If generic functionality test is passed, prune reactions
###############################################################
print('Pruning reactions...')
t0 = process_time()
PM, cRes = prune_model(GM, P, C, Z, 1/3, '../pre_processing/dataset/key_metabolites_RECON1.txt', 1, 1)
# Stop the stopwatch / counter
t_stop = process_time()
# compute elapsed time
pruneTime = t_stop - t0
# Out:
# Generic model passed precursor metabolites test
# Pruning reactions...
# Reaction no.  1
# Attempting to remove reaction:  THMMPt4 ...
# Initial PM reactions: 2467
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.107522000000017
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['EX_thmmp_e', 'THMMPt4']
# Zero-expression evidence for reaction...
# 2467
# 2467
# check_model_function done ....
# PM reactions (before): 2467
# Removed all inactive reactions
# PM reactions (after): 2465
# Num. removed: 2 (0 core, 2 non-core); Num. remaining: 1606
# Reaction no.  2
# Attempting to remove reaction:  DCT ...
# Initial PM reactions: 2465
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 5 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.880831999999998
# check_model_consistency done ...
# Lengths all--> inactive_G: 6 , inactive_C: [], inactive_NC:['DM_melanin_c', 'TYRDOPO3', 'DCT', 'TYRASE', 'DOPAQNISO1', 'DOPACHRMISO']
# Zero-expression evidence for reaction...
# 2465
# 2465
# check_model_function done ....
# PM reactions (before): 2465
# Removed all inactive reactions
# PM reactions (after): 2459
# Num. removed: 8 (0 core, 8 non-core); Num. remaining: 1600
# Reaction no.  3
# Attempting to remove reaction:  ACOX22x ...
# Initial PM reactions: 2459
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 7 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.094561999999996
# check_model_consistency done ...
# Lengths all--> inactive_G: 8 , inactive_C: ['SCP2x'], inactive_NC:['BAAT3x', 'EX_dgchol_e', 'DGCHOLte', 'AMACR2p', 'HSD17B42x', 'DGCHOLtx', 'ACOX22x']
# Zero-expression evidence for reaction...
# 2459
# 2459
# check_model_function done ....
# PM reactions (before): 2459
# Removed all inactive reactions
# PM reactions (after): 2451
# Num. removed: 16 (1 core, 15 non-core); Num. remaining: 1593
# Reaction no.  4
# Attempting to remove reaction:  AMACRp ...
# Initial PM reactions: 2451
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 22 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.96823999999998
# check_model_consistency done ...
# Lengths all--> inactive_G: 23 , inactive_C: ['SCPx'], inactive_NC:['P45027A11m', 'AKR1D2', 'FADH2tx', 'P4508B11r', 'ACOX2x', 'P45027A13m', 'EX_tchola_e', 'P4508B13r', 'GCHOLAtx', 'TCHOLAtx', 'XOLDIOLONEt', 'THCHOLSTOICtm', 'EX_gchola_e', 'FADtx', 'HSD17B4x', 'BAAT2x', 'XOLTRIOLtm', 'VLCSp', 'AKR1C42', 'BAAT1x', 'AMACRp', 'P45027A12m']
# Zero-expression evidence for reaction...
# 2451
# 2451
# check_model_function done ....
# PM reactions (before): 2451
# Removed all inactive reactions
# PM reactions (after): 2428
# Num. removed: 39 (2 core, 37 non-core); Num. remaining: 1571
# Reaction no.  5
# Attempting to remove reaction:  34DHPHEt ...
# Initial PM reactions: 2428
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.039812000000012
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['EX_34dhphe_e', '34DHPHEt']
# Zero-expression evidence for reaction...
# 2428
# 2428
# check_model_function done ....
# PM reactions (before): 2428
# Removed all inactive reactions
# PM reactions (after): 2426
# Num. removed: 41 (2 core, 39 non-core); Num. remaining: 1569
# Reaction no.  6
# Attempting to remove reaction:  SRTNtu ...
# Initial PM reactions: 2426
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.7651200000000244
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['SRTNtu']
# Zero-expression evidence for reaction...
# 2426
# 2426
# check_model_function done ....
# PM reactions (before): 2426
# Removed all inactive reactions
# PM reactions (after): 2425
# Num. removed: 42 (2 core, 40 non-core); Num. remaining: 1568
# Reaction no.  7
# Attempting to remove reaction:  DEBRISOQUINEt ...
# Initial PM reactions: 2425
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.6715580000000045
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: [], inactive_NC:['P4502D6', 'DEBRISOQUINEt', '4HDEBRISOQUINEte', 'EX_debrisoquine_e', 'EX_4hdebrisoquine_e']
# Zero-expression evidence for reaction...
# 2425
# 2425
# check_model_function done ....
# PM reactions (before): 2425
# Removed all inactive reactions
# PM reactions (after): 2420
# Num. removed: 47 (2 core, 45 non-core); Num. remaining: 1563
# Reaction no.  8
# Attempting to remove reaction:  CHATn ...
# Initial PM reactions: 2420
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.636896999999976
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: [], inactive_NC:['ACHtn', 'CHATn', 'COAtn', 'CHOLtn', 'ACCOAtn']
# Zero-expression evidence for reaction...
# 2420
# 2420
# check_model_function done ....
# PM reactions (before): 2420
# Removed all inactive reactions
# PM reactions (after): 2415
# Num. removed: 52 (2 core, 50 non-core); Num. remaining: 1558
# Reaction no.  9
# Attempting to remove reaction:  CSNt ...
# Initial PM reactions: 2415
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.025738999999987
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: [], inactive_NC:['EX_csn_e', 'CSNt', 'CSND']
# Zero-expression evidence for reaction...
# 2415
# 2415
# check_model_function done ....
# PM reactions (before): 2415
# Removed all inactive reactions
# PM reactions (after): 2412
# Num. removed: 55 (2 core, 53 non-core); Num. remaining: 1555
# Reaction no.  10
# Attempting to remove reaction:  5FTHFt2 ...
# Initial PM reactions: 2412
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.726927999999987
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: [], inactive_NC:['5FTHFt2', 'EX_5fthf_e', 'FTHFCL']
# Zero-expression evidence for reaction...
# 2412
# 2412
# check_model_function done ....
# PM reactions (before): 2412
# Removed all inactive reactions
# PM reactions (after): 2409
# Num. removed: 58 (2 core, 56 non-core); Num. remaining: 1552
# Reaction no.  11
# Attempting to remove reaction:  ADPRIBt ...
# Initial PM reactions: 2409
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.641347999999994
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['ADPRIBt']
# Zero-expression evidence for reaction...
# 2409
# 2409
# check_model_function done ....
# PM reactions (before): 2409
# Removed all inactive reactions
# PM reactions (after): 2408
# Num. removed: 59 (2 core, 57 non-core); Num. remaining: 1551
# Reaction no.  12
# Attempting to remove reaction:  PGDI ...
# Initial PM reactions: 2408
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.597890000000007
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: ['PGS'], inactive_NC:['PROSTGD2t', 'PGDI', 'EX_prostgd2_e']
# Zero-expression evidence for reaction...
# 2408
# 2408
# check_model_function done ....
# PM reactions (before): 2408
# Removed all inactive reactions
# PM reactions (after): 2404
# Num. removed: 63 (3 core, 60 non-core); Num. remaining: 1548
# Reaction no.  13
# Attempting to remove reaction:  THMTPt ...
# Initial PM reactions: 2404
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.566521000000023
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: ['THMt3'], inactive_NC:['EX_thmtp_e', 'THMTPt', 'EX_thm_e']
# Zero-expression evidence for reaction...
# 2404
# 2404
# check_model_function done ....
# PM reactions (before): 2404
# Removed all inactive reactions
# PM reactions (after): 2400
# Num. removed: 67 (4 core, 63 non-core); Num. remaining: 1545
# Reaction no.  14
# Attempting to remove reaction:  AGTix ...
# Initial PM reactions: 2400
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.828904999999963
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: ['HPYRRy', 'HPYRR2x'], inactive_NC:['HPYRDC', 'SPTix', 'GLYCK2', 'GLYC_St', 'AGTix', 'EX_glyc__S_e', 'HPYRtp', 'SERtp']
# Zero-expression evidence for reaction...
# 2400
# 2400
# check_model_function done ....
# PM reactions (before): 2400
# Removed all inactive reactions
# PM reactions (after): 2390
# Num. removed: 77 (6 core, 71 non-core); Num. remaining: 1537
# Reaction no.  15
# Attempting to remove reaction:  PROSTGF2t ...
# Initial PM reactions: 2390
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.94807499999996
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: ['CBR2'], inactive_NC:['EX_prostge2_e', 'EX_prostgf2_e', 'PROSTGF2t']
# Zero-expression evidence for reaction...
# 2390
# 2390
# check_model_function done ....
# PM reactions (before): 2390
# Removed all inactive reactions
# PM reactions (after): 2386
# Num. removed: 81 (7 core, 74 non-core); Num. remaining: 1534
# Reaction no.  16
# Attempting to remove reaction:  ACGAM2E ...
# Initial PM reactions: 2386
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.580164000000025
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: ['GALASE1ly', 'ACNAMlt', 'UAG2EMA', 'SIAASEly', 'AHEXASEly', 'GASNASEly'], inactive_NC:['ENGASEly', 'GALtly', 'S2L2N2M2MASNtly', 'ACGAM2E']
# Zero-expression evidence for reaction...
# 2386
# 2386
# check_model_function done ....
# Len P: 1534
# num_removed 81
# Len P AFTER 1533
# No reactions removed
# result 1.1
# Num. removed: 81 (7 core, 74 non-core); Num. remaining: 1533
# Reaction no.  17
# Attempting to remove reaction:  THYMt ...
# Initial PM reactions: 2386
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.523409000000015
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['THYMt', 'EX_thym_e']
# Zero-expression evidence for reaction...
# 2386
# 2386
# check_model_function done ....
# PM reactions (before): 2386
# Removed all inactive reactions
# PM reactions (after): 2384
# Num. removed: 83 (7 core, 76 non-core); Num. remaining: 1531
# Reaction no.  18
# Attempting to remove reaction:  HIStiDF ...
# Initial PM reactions: 2384
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.664168000000018
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['HIStiDF']
# Zero-expression evidence for reaction...
# 2384
# 2384
# check_model_function done ....
# PM reactions (before): 2384
# Removed all inactive reactions
# PM reactions (after): 2383
# Num. removed: 84 (7 core, 77 non-core); Num. remaining: 1530
# Reaction no.  19
# Attempting to remove reaction:  TRPt ...
# Initial PM reactions: 2383
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.600310000000036
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['TRPt']
# Zero-expression evidence for reaction...
# 2383
# 2383
# check_model_function done ....
# PM reactions (before): 2383
# Removed all inactive reactions
# PM reactions (after): 2382
# Num. removed: 85 (7 core, 78 non-core); Num. remaining: 1529
# Reaction no.  20
# Attempting to remove reaction:  LCAT1e ...
# Initial PM reactions: 2382
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.55947500000002
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['EX_xolest2_hs_e', 'LCAT1e']
# Zero-expression evidence for reaction...
# 2382
# 2382
# check_model_function done ....
# PM reactions (before): 2382
# Removed all inactive reactions
# PM reactions (after): 2380
# Num. removed: 87 (7 core, 80 non-core); Num. remaining: 1527
# Reaction no.  21
# Attempting to remove reaction:  FOLt2 ...
# Initial PM reactions: 2380
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.4205989999999815
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: ['FOLR2'], inactive_NC:['EX_fol_e', 'FOLt2']
# Zero-expression evidence for reaction...
# 2380
# 2380
# check_model_function done ....
# Len P: 1527
# num_removed 87
# Len P AFTER 1526
# No reactions removed
# result 1.1
# Num. removed: 87 (7 core, 80 non-core); Num. remaining: 1526
# Reaction no.  22
# Attempting to remove reaction:  NNMT ...
# Initial PM reactions: 2380
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.479147000000012
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: ['NP1'], inactive_NC:['EX_nac_e', 'QUILSYN', '1MNCAMti', 'NCAMUP', 'NACt', 'EX_1mncam_e', 'NADS2', 'NNDPR', 'NNMT']
# Zero-expression evidence for reaction...
# 2380
# 2380
# check_model_function done ....
# PM reactions (before): 2380
# Removed all inactive reactions
# PM reactions (after): 2370
# Num. removed: 97 (8 core, 89 non-core); Num. remaining: 1517
# Reaction no.  23
# Attempting to remove reaction:  URAt ...
# Initial PM reactions: 2370
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.5255710000000136
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['EX_ura_e', 'URAt']
# Zero-expression evidence for reaction...
# 2370
# 2370
# check_model_function done ....
# PM reactions (before): 2370
# Removed all inactive reactions
# PM reactions (after): 2368
# Num. removed: 99 (8 core, 91 non-core); Num. remaining: 1515
# Reaction no.  24
# Attempting to remove reaction:  HYXNt ...
# Initial PM reactions: 2368
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.473370000000045
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['HYXNt', 'EX_hxan_e']
# Zero-expression evidence for reaction...
# 2368
# 2368
# check_model_function done ....
# PM reactions (before): 2368
# Removed all inactive reactions
# PM reactions (after): 2366
# Num. removed: 101 (8 core, 93 non-core); Num. remaining: 1513
# Reaction no.  25
# Attempting to remove reaction:  GUAt ...
# Initial PM reactions: 2366
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.466348000000039
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['EX_gua_e', 'GUAt']
# Zero-expression evidence for reaction...
# 2366
# 2366
# check_model_function done ....
# PM reactions (before): 2366
# Removed all inactive reactions
# PM reactions (after): 2364
# Num. removed: 103 (8 core, 95 non-core); Num. remaining: 1511
# Reaction no.  26
# Attempting to remove reaction:  L_LACtcm ...
# Initial PM reactions: 2364
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.353366999999935
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['L_LACtcm']
# Zero-expression evidence for reaction...
# 2364
# 2364
# check_model_function done ....
# PM reactions (before): 2364
# Removed all inactive reactions
# PM reactions (after): 2363
# Num. removed: 104 (8 core, 96 non-core); Num. remaining: 1510
# Reaction no.  27
# Attempting to remove reaction:  AMETt2m ...
# Initial PM reactions: 2363
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 9 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.417362999999909
# check_model_consistency done ...
# Lengths all--> inactive_G: 10 , inactive_C: ['PETOHMm_hs', 'CDSm', 'CYTDtm', 'NDPK3m'], inactive_NC:['CYTDK2m', 'CYTK1m', 'PCFLOPm', 'AMETt2m', 'CDPDAGtm', 'PCHOLPm_hs']
# Zero-expression evidence for reaction...
# 2363
# 2363
# check_model_function done ....
# Len P: 1510
# num_removed 104
# Len P AFTER 1509
# No reactions removed
# result 1.1
# Num. removed: 104 (8 core, 96 non-core); Num. remaining: 1509
# Reaction no.  28
# Attempting to remove reaction:  TXASr ...
# Initial PM reactions: 2363
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 5 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.4624359999999115
# check_model_consistency done ...
# Lengths all--> inactive_G: 6 , inactive_C: ['PGSr'], inactive_NC:['TXA2te', 'TXA2tr', 'EX_txa2_e', 'TXASr', 'ARACHDtr']
# Zero-expression evidence for reaction...
# 2363
# 2363
# check_model_function done ....
# PM reactions (before): 2363
# Removed all inactive reactions
# PM reactions (after): 2357
# Num. removed: 110 (9 core, 101 non-core); Num. remaining: 1504
# Reaction no.  29
# Attempting to remove reaction:  PROSTGE2t2 ...
# Initial PM reactions: 2357
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.382046999999943
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['PROSTGE2t2']
# Zero-expression evidence for reaction...
# 2357
# 2357
# check_model_function done ....
# PM reactions (before): 2357
# Removed all inactive reactions
# PM reactions (after): 2356
# Num. removed: 111 (9 core, 102 non-core); Num. remaining: 1503
# Reaction no.  30
# Attempting to remove reaction:  CPK1 ...
# Initial PM reactions: 2356
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.479874999999993
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['CPK1']
# Zero-expression evidence for reaction...
# 2356
# 2356
# check_model_function done ....
# PM reactions (before): 2356
# Removed all inactive reactions
# PM reactions (after): 2355
# Num. removed: 112 (9 core, 103 non-core); Num. remaining: 1502
# Reaction no.  31
# Attempting to remove reaction:  SERDGLYexR ...
# Initial PM reactions: 2355
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.367682999999943
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['SERDGLYexR', 'SERDGLNexR']
# Zero-expression evidence for reaction...
# 2355
# 2355
# check_model_function done ....
# PM reactions (before): 2355
# Removed all inactive reactions
# PM reactions (after): 2353
# Num. removed: 114 (9 core, 105 non-core); Num. remaining: 1500
# Reaction no.  32
# Attempting to remove reaction:  TYRt ...
# Initial PM reactions: 2353
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.362332999999921
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['TYRt']
# Zero-expression evidence for reaction...
# 2353
# 2353
# check_model_function done ....
# PM reactions (before): 2353
# Removed all inactive reactions
# PM reactions (after): 2352
# Num. removed: 115 (9 core, 106 non-core); Num. remaining: 1499
# Reaction no.  33
# Attempting to remove reaction:  CYTK6n ...
# Initial PM reactions: 2352
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.049942999999985
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['CYTK6n']
# Zero-expression evidence for reaction...
# 2352
# 2352
# check_model_function done ....
# PM reactions (before): 2352
# Removed all inactive reactions
# PM reactions (after): 2351
# Num. removed: 116 (9 core, 107 non-core); Num. remaining: 1498
# Reaction no.  34
# Attempting to remove reaction:  It ...
# Initial PM reactions: 2351
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.326559999999972
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['It']
# Zero-expression evidence for reaction...
# 2351
# 2351
# check_model_function done ....
# PM reactions (before): 2351
# Removed all inactive reactions
# PM reactions (after): 2350
# Num. removed: 117 (9 core, 108 non-core); Num. remaining: 1497
# Reaction no.  35
# Attempting to remove reaction:  ADEt ...
# Initial PM reactions: 2350
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.36910899999998
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['ADEt', 'EX_ade_e']
# Zero-expression evidence for reaction...
# 2350
# 2350
# check_model_function done ....
# PM reactions (before): 2350
# Removed all inactive reactions
# PM reactions (after): 2348
# Num. removed: 119 (9 core, 110 non-core); Num. remaining: 1495
# Reaction no.  36
# Attempting to remove reaction:  CYTK3 ...
# Initial PM reactions: 2348
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.41464899999994
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['CYTK3']
# Zero-expression evidence for reaction...
# 2348
# 2348
# check_model_function done ....
# PM reactions (before): 2348
# Removed all inactive reactions
# PM reactions (after): 2347
# Num. removed: 120 (9 core, 111 non-core); Num. remaining: 1494
# Reaction no.  37
# Attempting to remove reaction:  UMPK3n ...
# Initial PM reactions: 2347
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.431979999999953
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['UMPK3n']
# Zero-expression evidence for reaction...
# 2347
# 2347
# check_model_function done ....
# PM reactions (before): 2347
# Removed all inactive reactions
# PM reactions (after): 2346
# Num. removed: 121 (9 core, 112 non-core); Num. remaining: 1493
# Reaction no.  38
# Attempting to remove reaction:  CYTK9n ...
# Initial PM reactions: 2346
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.334549000000038
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['CYTK9n']
# Zero-expression evidence for reaction...
# 2346
# 2346
# check_model_function done ....
# PM reactions (before): 2346
# Removed all inactive reactions
# PM reactions (after): 2345
# Num. removed: 122 (9 core, 113 non-core); Num. remaining: 1492
# Reaction no.  39
# Attempting to remove reaction:  CYTK8n ...
# Initial PM reactions: 2345
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.247578999999973
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['CYTK8n']
# Zero-expression evidence for reaction...
# 2345
# 2345
# check_model_function done ....
# PM reactions (before): 2345
# Removed all inactive reactions
# PM reactions (after): 2344
# Num. removed: 123 (9 core, 114 non-core); Num. remaining: 1491
# Reaction no.  40
# Attempting to remove reaction:  CYTK10n ...
# Initial PM reactions: 2344
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.426060000000007
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['CYTK10n']
# Zero-expression evidence for reaction...
# 2344
# 2344
# check_model_function done ....
# PM reactions (before): 2344
# Removed all inactive reactions
# PM reactions (after): 2343
# Num. removed: 124 (9 core, 115 non-core); Num. remaining: 1490
# Reaction no.  41
# Attempting to remove reaction:  CYTK5n ...
# Initial PM reactions: 2343
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.382574999999974
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['CYTK5n']
# Zero-expression evidence for reaction...
# 2343
# 2343
# check_model_function done ....
# PM reactions (before): 2343
# Removed all inactive reactions
# PM reactions (after): 2342
# Num. removed: 125 (9 core, 116 non-core); Num. remaining: 1489
# Reaction no.  42
# Attempting to remove reaction:  ALADGLYexR ...
# Initial PM reactions: 2342
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.076073999999949
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['ALADGLYexR']
# Zero-expression evidence for reaction...
# 2342
# 2342
# check_model_function done ....
# PM reactions (before): 2342
# Removed all inactive reactions
# PM reactions (after): 2341
# Num. removed: 126 (9 core, 117 non-core); Num. remaining: 1488
# Reaction no.  43
# Attempting to remove reaction:  HISDr ...
# Initial PM reactions: 2341
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.126270999999974
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: [], inactive_NC:['FTCD', 'IZPN', 'URCN', 'HISDr', 'GluForTx']
# Zero-expression evidence for reaction...
# 2341
# 2341
# check_model_function done ....
# PM reactions (before): 2341
# Removed all inactive reactions
# PM reactions (after): 2336
# Num. removed: 131 (9 core, 122 non-core); Num. remaining: 1483
# Reaction no.  44
# Attempting to remove reaction:  GCC2bim ...
# Initial PM reactions: 2336
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.3251900000000205
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: [], inactive_NC:['GCC2am', 'GCC2bim', 'GCC2cm']
# Zero-expression evidence for reaction...
# 2336
# 2336
# check_model_function done ....
# PM reactions (before): 2336
# Removed all inactive reactions
# PM reactions (after): 2333
# Num. removed: 134 (9 core, 125 non-core); Num. remaining: 1480
# Reaction no.  45
# Attempting to remove reaction:  GCCbim ...
# Initial PM reactions: 2333
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.287373000000002
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: [], inactive_NC:['GCCcm', 'GCCam', 'GCCbim']
# Zero-expression evidence for reaction...
# 2333
# 2333
# check_model_function done ....
# PM reactions (before): 2333
# Removed all inactive reactions
# PM reactions (after): 2330
# Num. removed: 137 (9 core, 128 non-core); Num. remaining: 1477
# Reaction no.  46
# Attempting to remove reaction:  BCDO ...
# Initial PM reactions: 2330
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.211491000000024
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: [], inactive_NC:['EX_caro_e', 'CAROtr', 'BCDO']
# Zero-expression evidence for reaction...
# 2330
# 2330
# check_model_function done ....
# PM reactions (before): 2330
# Removed all inactive reactions
# PM reactions (after): 2327
# Num. removed: 140 (9 core, 131 non-core); Num. remaining: 1474
# Reaction no.  47
# Attempting to remove reaction:  ALOX5 ...
# Initial PM reactions: 2327
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 12 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.303919999999948
# check_model_consistency done ...
# Lengths all--> inactive_G: 13 , inactive_C: ['LTC4Sr'], inactive_NC:['GLUtr', 'LEUKTRC4t', 'EX_leuktrC4_e', 'LEUKTRD4tr', 'ALOX52', 'LEUKTRA4tr', 'LTC4CP', 'LTD4DP', 'ALOX5', 'GGT6', 'GGT5r', 'GTHRDtr']
# Zero-expression evidence for reaction...
# 2327
# 2327
# check_model_function done ....
# PM reactions (before): 2327
# Removed all inactive reactions
# PM reactions (after): 2314
# Num. removed: 153 (10 core, 143 non-core); Num. remaining: 1462
# Reaction no.  48
# Attempting to remove reaction:  TRPO2 ...
# Initial PM reactions: 2314
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 7 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.22840199999996
# check_model_consistency done ...
# Lengths all--> inactive_G: 8 , inactive_C: ['HKYNH'], inactive_NC:['FKYNH', 'PCLAD', 'AM6SAD', 'AMCOXO', 'KYN3OX', '3HAO', 'TRPO2']
# Zero-expression evidence for reaction...
# 2314
# 2314
# check_model_function done ....
# PM reactions (before): 2314
# Removed all inactive reactions
# PM reactions (after): 2306
# Num. removed: 161 (11 core, 150 non-core); Num. remaining: 1455
# Reaction no.  49
# Attempting to remove reaction:  CYTK12n ...
# Initial PM reactions: 2306
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.190172000000075
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['CYTK12n']
# Zero-expression evidence for reaction...
# 2306
# 2306
# check_model_function done ....
# PM reactions (before): 2306
# Removed all inactive reactions
# PM reactions (after): 2305
# Num. removed: 162 (11 core, 151 non-core); Num. remaining: 1454
# Reaction no.  50
# Attempting to remove reaction:  UMPK6n ...
# Initial PM reactions: 2305
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.215797000000066
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['UMPK6n']
# Zero-expression evidence for reaction...
# 2305
# 2305
# check_model_function done ....
# PM reactions (before): 2305
# Removed all inactive reactions
# PM reactions (after): 2304
# Num. removed: 163 (11 core, 152 non-core); Num. remaining: 1453
# Reaction no.  51
# Attempting to remove reaction:  UMPK2n ...
# Initial PM reactions: 2304
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.188182999999981
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['UMPK2n']
# Zero-expression evidence for reaction...
# 2304
# 2304
# check_model_function done ....
# PM reactions (before): 2304
# Removed all inactive reactions
# PM reactions (after): 2303
# Num. removed: 164 (11 core, 153 non-core); Num. remaining: 1452
# Reaction no.  52
# Attempting to remove reaction:  CYTK7n ...
# Initial PM reactions: 2303
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.271727000000055
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['CYTK7n', 'CYTK1n']
# Zero-expression evidence for reaction...
# 2303
# 2303
# check_model_function done ....
# PM reactions (before): 2303
# Removed all inactive reactions
# PM reactions (after): 2301
# Num. removed: 166 (11 core, 155 non-core); Num. remaining: 1450
# Reaction no.  53
# Attempting to remove reaction:  THFt2 ...
# Initial PM reactions: 2301
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.120972000000052
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['THFt2']
# Zero-expression evidence for reaction...
# 2301
# 2301
# check_model_function done ....
# PM reactions (before): 2301
# Removed all inactive reactions
# PM reactions (after): 2300
# Num. removed: 167 (11 core, 156 non-core); Num. remaining: 1449
# Reaction no.  54
# Attempting to remove reaction:  UMPK7n ...
# Initial PM reactions: 2300
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.2444540000001325
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['UMPK7n']
# Zero-expression evidence for reaction...
# 2300
# 2300
# check_model_function done ....
# PM reactions (before): 2300
# Removed all inactive reactions
# PM reactions (after): 2299
# Num. removed: 168 (11 core, 157 non-core); Num. remaining: 1448
# Reaction no.  55
# Attempting to remove reaction:  UMPK5n ...
# Initial PM reactions: 2299
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.231199999999944
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['UMPK5n']
# Zero-expression evidence for reaction...
# 2299
# 2299
# check_model_function done ....
# PM reactions (before): 2299
# Removed all inactive reactions
# PM reactions (after): 2298
# Num. removed: 169 (11 core, 158 non-core); Num. remaining: 1447
# Reaction no.  56
# Attempting to remove reaction:  UMPK4n ...
# Initial PM reactions: 2298
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.158517999999958
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['UMPKn', 'UMPK4n']
# Zero-expression evidence for reaction...
# 2298
# 2298
# check_model_function done ....
# PM reactions (before): 2298
# Removed all inactive reactions
# PM reactions (after): 2296
# Num. removed: 171 (11 core, 160 non-core); Num. remaining: 1445
# Reaction no.  57
# Attempting to remove reaction:  TYRDOPO ...
# Initial PM reactions: 2296
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.1731029999998555
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['TYRDOPO']
# Zero-expression evidence for reaction...
# 2296
# 2296
# check_model_function done ....
# PM reactions (before): 2296
# Removed all inactive reactions
# PM reactions (after): 2295
# Num. removed: 172 (11 core, 161 non-core); Num. remaining: 1444
# Reaction no.  58
# Attempting to remove reaction:  SO4OXAtex2 ...
# Initial PM reactions: 2295
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.127526999999873
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['SO4OXAtex2']
# Zero-expression evidence for reaction...
# 2295
# 2295
# check_model_function done ....
# PM reactions (before): 2295
# Removed all inactive reactions
# PM reactions (after): 2294
# Num. removed: 173 (11 core, 162 non-core); Num. remaining: 1443
# Reaction no.  59
# Attempting to remove reaction:  THRGLYexR ...
# Initial PM reactions: 2294
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.161448999999948
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['THRGLYexR']
# Zero-expression evidence for reaction...
# 2294
# 2294
# check_model_function done ....
# PM reactions (before): 2294
# Removed all inactive reactions
# PM reactions (after): 2293
# Num. removed: 174 (11 core, 163 non-core); Num. remaining: 1442
# Reaction no.  60
# Attempting to remove reaction:  TYR3MO2 ...
# Initial PM reactions: 2293
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.252615999999989
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['3HLYTCL', 'TYR3MO2']
# Zero-expression evidence for reaction...
# 2293
# 2293
# check_model_function done ....
# PM reactions (before): 2293
# Removed all inactive reactions
# PM reactions (after): 2291
# Num. removed: 176 (11 core, 165 non-core); Num. remaining: 1440
# Reaction no.  61
# Attempting to remove reaction:  BAAT4x ...
# Initial PM reactions: 2291
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 3 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.227055000000064
# check_model_consistency done ...
# Lengths all--> inactive_G: 4 , inactive_C: [], inactive_NC:['BAAT4x', 'EX_gdchola_e', 'GDCHOLAte', 'GDCHOLAtx']
# Zero-expression evidence for reaction...
# 2291
# 2291
# check_model_function done ....
# PM reactions (before): 2291
# Removed all inactive reactions
# PM reactions (after): 2287
# Num. removed: 180 (11 core, 169 non-core); Num. remaining: 1436
# Reaction no.  62
# Attempting to remove reaction:  BAAT5x ...
# Initial PM reactions: 2287
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 23 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.195496999999932
# check_model_consistency done ...
# Lengths all--> inactive_G: 24 , inactive_C: ['SCP3x'], inactive_NC:['HSD3B7', 'BAAT5x', 'P45027A14m', 'AMPtp', 'NAtx', 'P45027A16m', 'P4507A1r', 'HSD3B7P', 'TDCHOLAte', 'VLCS2p', 'P45027A15m', 'EX_tdchola_e', 'XOL7AH2tm', 'AKR1C41', 'PCRNtm', 'CRNCAR3tp', 'DHCHOLESTANATEtm', 'TDCHOLAtx', 'XOL7AONEtr', 'TAURtcx', 'CSNAT2m', 'CSNAT3x', 'AKR1D']
# Zero-expression evidence for reaction...
# 2287
# 2287
# check_model_function done ....
# PM reactions (before): 2287
# Removed all inactive reactions
# PM reactions (after): 2263
# Num. removed: 204 (12 core, 192 non-core); Num. remaining: 1413
# Reaction no.  63
# Attempting to remove reaction:  CYTK14n ...
# Initial PM reactions: 2263
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  5.99349200000006
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['CYTK14n']
# Zero-expression evidence for reaction...
# 2263
# 2263
# check_model_function done ....
# PM reactions (before): 2263
# Removed all inactive reactions
# PM reactions (after): 2262
# Num. removed: 205 (12 core, 193 non-core); Num. remaining: 1412
# Reaction no.  64
# Attempting to remove reaction:  CYTK3n ...
# Initial PM reactions: 2262
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.019624000000022
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: ['NDPK3n'], inactive_NC:['CYTK3n']
# Zero-expression evidence for reaction...
# 2262
# 2262
# check_model_function done ....
# Len P: 1412
# num_removed 205
# Len P AFTER 1411
# No reactions removed
# result 1.1
# Num. removed: 205 (12 core, 193 non-core); Num. remaining: 1411
# Reaction no.  65
# Attempting to remove reaction:  CYTK13n ...
# Initial PM reactions: 2262
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  5.9949320000000625
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: ['NDPK8n'], inactive_NC:['CYTK13n']
# Zero-expression evidence for reaction...
# 2262
# 2262
# check_model_function done ....
# Len P: 1411
# num_removed 205
# Len P AFTER 1410
# No reactions removed
# result 1.1
# Num. removed: 205 (12 core, 193 non-core); Num. remaining: 1410
# Reaction no.  66
# Attempting to remove reaction:  CYTK11n ...
# Initial PM reactions: 2262
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.02499899999998
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: ['NDPK5n'], inactive_NC:['CYTK11n']
# Zero-expression evidence for reaction...
# 2262
# 2262
# check_model_function done ....
# Len P: 1410
# num_removed 205
# Len P AFTER 1409
# No reactions removed
# result 1.1
# Num. removed: 205 (12 core, 193 non-core); Num. remaining: 1409
# Reaction no.  67
# Attempting to remove reaction:  CYTK4n ...
# Initial PM reactions: 2262
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.091126999999915
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: ['NDPK1n'], inactive_NC:['CYTK4n']
# Zero-expression evidence for reaction...
# 2262
# 2262
# check_model_function done ....
# Len P: 1409
# num_removed 205
# Len P AFTER 1408
# No reactions removed
# result 1.1
# Num. removed: 205 (12 core, 193 non-core); Num. remaining: 1408
# Reaction no.  68
# Attempting to remove reaction:  CYTK7 ...
# Initial PM reactions: 2262
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.009293000000071
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['CYTK7']
# Zero-expression evidence for reaction...
# 2262
# 2262
# check_model_function done ....
# PM reactions (before): 2262
# Removed all inactive reactions
# PM reactions (after): 2261
# Num. removed: 206 (12 core, 194 non-core); Num. remaining: 1407
# Reaction no.  69
# Attempting to remove reaction:  34HPPOR ...
# Initial PM reactions: 2261
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  5.9738629999999375
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: ['MACACI', 'FUMAC', 'TYRTA'], inactive_NC:['HGNTOR', '34HPPOR']
# Zero-expression evidence for reaction...
# 2261
# 2261
# check_model_function done ....
# Len P: 1407
# num_removed 206
# Len P AFTER 1406
# No reactions removed
# result 1.1
# Num. removed: 206 (12 core, 194 non-core); Num. remaining: 1406
# Reaction no.  70
# Attempting to remove reaction:  ALADGLNexR ...
# Initial PM reactions: 2261
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.136198999999806
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['ALADGLNexR']
# Zero-expression evidence for reaction...
# 2261
# 2261
# check_model_function done ....
# PM reactions (before): 2261
# Removed all inactive reactions
# PM reactions (after): 2260
# Num. removed: 207 (12 core, 195 non-core); Num. remaining: 1405
# Reaction no.  71
# Attempting to remove reaction:  THRD_L ...
# Initial PM reactions: 2260
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.119738999999981
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: [], inactive_NC:['EX_thr__L_e', 'THRD_L']
# Zero-expression evidence for reaction...
# 2260
# 2260
# check_model_function done ....
# PM reactions (before): 2260
# Removed all inactive reactions
# PM reactions (after): 2258
# Num. removed: 209 (12 core, 197 non-core); Num. remaining: 1403
# Reaction no.  72
# Attempting to remove reaction:  CSNATp ...
# Initial PM reactions: 2258
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 33 blocked (inactive) reactions
# Execution time of check_model_consistency:  6.042476000000079
# check_model_consistency done ...
# Lengths all--> inactive_G: 34 , inactive_C: ['HMGLx'], inactive_NC:['FAOXC183806x', 'CRNCARtp', 'FAOXC2452256x', 'TETHEX3COAtx', 'FAOXC200180x', 'FAOXC2452253x', 'CSNATp', 'FAOXC16080x', 'FAOXC260240x', 'FAOXC240200x', 'STCOAtx', 'FAOXC2442246x', 'TETPENT3COAtx', 'ARACHDCOAtx', 'TETTET6COAtx', 'LGNCCOAtx', 'OCCOAtx', 'FAOXC18480x', 'HEXCCOAtx', 'ODECOAtx', 'NRVNCCOAtx', 'FAOXC241181x', 'FAOXC246226x', 'FAOXC2242046x', 'FAOXC180x', 'TMNDNCCOAtx', 'ARACHCOAtx', 'TETPENT6COAtx', 'FAOXC2252053x', 'FAOXC226205x', 'FAOXC2251836x', 'FAOXC2051843x', 'ACACtx']
# Zero-expression evidence for reaction...
# 2258
# 2258
# check_model_function done ....
# PM reactions (before): 2258
# Removed all inactive reactions
# PM reactions (after): 2224
# Num. removed: 243 (13 core, 230 non-core); Num. remaining: 1370
# Reaction no.  73
# Attempting to remove reaction:  UMPK3 ...
# Initial PM reactions: 2224
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  5.868819999999914
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['UMPK3']
# Zero-expression evidence for reaction...
# 2224
# 2224
# check_model_function done ....
# PM reactions (before): 2224
# Removed all inactive reactions
# PM reactions (after): 2223
# Num. removed: 244 (13 core, 231 non-core); Num. remaining: 1369
# Reaction no.  74
# Attempting to remove reaction:  CYSTSERex ...
# Initial PM reactions: 2223
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  5.945502000000033
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['CYSTSERex']
# Zero-expression evidence for reaction...
# 2223
# 2223
# check_model_function done ....
# PM reactions (before): 2223
# Removed all inactive reactions
# PM reactions (after): 2222
# Num. removed: 245 (13 core, 232 non-core); Num. remaining: 1368
# Reaction no.  75
# Attempting to remove reaction:  CYSGLYex_copy1 ...
# Initial PM reactions: 2222
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  7.061754999999948
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['CYSGLYex_copy1']
# Zero-expression evidence for reaction...
# 2222
# 2222
# check_model_function done ....
# PM reactions (before): 2222
# Removed all inactive reactions
# PM reactions (after): 2221
# Num. removed: 246 (13 core, 233 non-core); Num. remaining: 1367
# Reaction no.  76
# Attempting to remove reaction:  CYSGLYex_copy2 ...
# Initial PM reactions: 2221
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  5.900814999999966
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['CYSGLYex_copy2']
# Zero-expression evidence for reaction...
# 2221
# 2221
# check_model_function done ....
# PM reactions (before): 2221
# ...
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 16 blocked (inactive) reactions
# Execution time of check_model_consistency:  9.74374699999862
# check_model_consistency done ...
# Lengths all--> inactive_G: 17 , inactive_C: ['GLCURtly', 'GALASE1ly', 'ACNAMlt', 'GLCAASE9ly', 'NACHEX27ly', 'SIAASEly', 'AHEXASEly', 'GLCAASE8ly', 'FUCASEe', 'GASNASEly'], inactive_NC:['ENGASEly', 'ATPasel', 'EX_ha_e', 'EX_s2l2fn2m2masn_e', 'GALtly', 'HAtly', 'S2L2N2M2MASNtly']
# Reaction ATPasel is not in Z
# 1349
# 1349
# check_model_function done ....
# No reactions removed
# Num. removed: 1118 (39 core, 1079 non-core); Num. remaining: 21
# Reaction no.  1066
# Attempting to remove reaction:  CITRtm ...
# Initial PM reactions: 1349
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  9.758952000000136
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['CITRtm']
# Reaction CITRtm is not in Z
# 1349
# 1349
# check_model_function done ....
# Removed non-core inactive reactions
# PM reactions (after): 1348
# Num. removed: 1119 (39 core, 1080 non-core); Num. remaining: 20
# Reaction no.  1067
# Attempting to remove reaction:  ETFQO ...
# Initial PM reactions: 1348
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  9.634572999999364
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: ['ETF'], inactive_NC:['ETFQO']
# Reaction ETFQO is not in Z
# 1348
# 1348
# check_model_function done ....
# No reactions removed
# Num. removed: 1119 (39 core, 1080 non-core); Num. remaining: 19
# Reaction no.  1068
# Attempting to remove reaction:  G6PPer ...
# Initial PM reactions: 1348
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  9.662998000001608
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: ['G6Pter'], inactive_NC:['G6PPer']
# Reaction G6PPer is not in Z
# 1348
# 1348
# check_model_function done ....
# No reactions removed
# Num. removed: 1119 (39 core, 1080 non-core); Num. remaining: 18
# Reaction no.  1069
# Attempting to remove reaction:  PPAer ...
# Initial PM reactions: 1348
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 165 blocked (inactive) reactions
# Execution time of check_model_consistency:  9.528904999999213
# check_model_consistency done ...
# Lengths all--> inactive_G: 166 , inactive_C: ['IPDDIx', 'LNSTLSr', 'SQLEr', 'HMGCOARx', 'C3STDH1r', 'C4STMO2Pr', 'HMBS', 'ALASm', 'C4STMO2r', 'C4STMO1r', 'MEVK1x', 'UGCG', 'CERT1rt', 'FACOAL245_1', 'PPCDC', 'DHCR241r', 'UGT1A1r', 'CPPPGO', 'PNTK', 'RTOTAL2CRNt', 'SOAT11', 'C14STRr', 'RAI3', 'BILIRED', 'UGT1A5r2', 'DHCRD2', 'DPCOAK', 'LNS14DMr', 'UPP3S', 'LSTO2r', 'PMEVKx', 'CERT2rt', 'FACOAL260', 'DHCR72r', 'DHCR243r', 'RTOTAL2CRNCPT1', 'FACOAL244_1', 'GRTTx', 'FACOAL241', 'DMATTx', 'UDPGLCAter', 'PTPATi', 'RTOTALCRNt', 'DPMVDx', 'G6Pter', 'RTOTALCRNCPT1', 'RTOTAL2CRNCPT2', 'UGT1A5r', 'SOAT12', 'C3STDH1Pr', 'UDPDOLPT_U', 'PPPGOm', 'DHCR242r', 'UGT1A2r', 'SQLSr', 'FACOAL240', 'DHCR71r', 'GBA', 'UPPDC1', 'UGT1A6r', 'CERK', 'HMGCOAS', 'EBP1r', 'EBP2r', 'UDPDOLPT_L', 'LSTO1r', 'PPNCL3', 'HOXG', 'ESTRADIOLGLCt2', 'SBPP1er', 'RTOTALCRNCPT2'], inactive_NC:['RETNtr2', 'DOLPH_Ler', 'FADH2tru', 'G6PPer', 'NRVNCt', 'COAtp', 'DOLK_L', 'DOLGPP_Uer', 'ADPtx', 'SPHGNtr', 'EX_co_e', 'EX_pnto__R_e', 'NADPHtxu', 'EX_estrones_e', 'EX_nrvnc_e', 'ESTRONEGLCt', 'EX_bildglcur_e', 'PPBNGS', 'RETNGLCt2r', 'ARTFR56', 'PItx', 'ATPtx', 'CHSTEROLt3', 'ARTPLM2m', 'RETNtr', 'FADtru', 'PHEMEtm', 'EX_estroneglc_e', 'TETTET6t', 'ARTFR206', 'FORtr', 'DOLGLCP_Uter', 'DOLPH_Uer', 'PNTOt5', '5AOPtm', 'ARTFR45', 'CHSTEROLt2', 'EX_hexc_e', 'CO2ter', 'ESTRADIOLGLCtr', 'CRMPte', 'EX_lgnc_e', 'EX_tettet6_e', 'RTOT5', 'O2ter', 'TETPENT6t', 'HEXCt', 'BILDGLCURtr', 'DOLGLCP_Lter', 'LGNCt', 'ESTRONESt', 'PPPG9tm', 'ARTFR51', 'RTOT_2', 'EX_retn_e', 'RETNGLCt2', 'GLYtm', 'ARTFR13', 'PIter', 'COt', 'FRDPtr', 'FCLTm', 'GLCMter', 'EX_crmp_hs_e', 'DOLICHOL_Uter', 'PPAer', 'BILDGLCURte', 'BILIRUBtr', 'RETNGLCt', 'C3STKR2r', 'ARTFR54', 'ARTPLM1m', 'NDP7er', 'EX_tetpent6_e', 'XOLESTte', 'DOLGPP_Ler', 'EX_13_cis_retnglc_e', 'EX_retnglc_e', 'FE2tm', 'HMGCOAtx', 'NADPtxu', 'ESTRONEGLCtr', 'SPH1Pter', 'CO2tp', 'EX_estradiolglc_e', 'DOLK_U', 'DOLICHOL_Lter', 'UDPGLCter', 'SPH1Pte', 'EX_sph1p_e', 'RETNt', 'EX_xolest_hs_e', 'ARTFR52', 'RETNGLCtr', 'PPItx']
# Reaction PPAer is not in Z
# 1348
# 1348
# check_model_function done ....
# No reactions removed
# Num. removed: 1119 (39 core, 1080 non-core); Num. remaining: 17
# Reaction no.  1070
# Attempting to remove reaction:  L_LACDcm ...
# Initial PM reactions: 1348
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  9.571860000000015
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['L_LACDcm']
# Reaction L_LACDcm is not in Z
# 1348
# 1348
# check_model_function done ....
# Removed non-core inactive reactions
# PM reactions (after): 1347
# Num. removed: 1120 (39 core, 1081 non-core); Num. remaining: 16
# Reaction no.  1071
# Attempting to remove reaction:  SO4t4_2 ...
# Initial PM reactions: 1347
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 1 blocked (inactive) reactions
# Execution time of check_model_consistency:  9.683641999999963
# check_model_consistency done ...
# Lengths all--> inactive_G: 2 , inactive_C: ['SO4HCOtex'], inactive_NC:['SO4t4_2']
# Reaction SO4t4_2 is not in Z
# 1347
# 1347
# check_model_function done ....
# No reactions removed
# Num. removed: 1120 (39 core, 1081 non-core); Num. remaining: 15
# Reaction no.  1072
# Attempting to remove reaction:  3HCO3_NAt ...
# Initial PM reactions: 1347
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  9.617719999998371
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['3HCO3_NAt']
# Reaction 3HCO3_NAt is not in Z
# 1347
# 1347
# check_model_function done ....
# Removed non-core inactive reactions
# PM reactions (after): 1346
# Num. removed: 1121 (39 core, 1082 non-core); Num. remaining: 14
# Reaction no.  1073
# Attempting to remove reaction:  2HCO3_NAt ...
# Initial PM reactions: 1346
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  9.554645000000164
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['2HCO3_NAt']
# Reaction 2HCO3_NAt is not in Z
# 1346
# 1346
# check_model_function done ....
# Removed non-core inactive reactions
# PM reactions (after): 1345
# Num. removed: 1122 (39 core, 1083 non-core); Num. remaining: 13
# Reaction no.  1074
# Attempting to remove reaction:  PDE4 ...
# Initial PM reactions: 1345
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  9.567096000000674
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['PDE4']
# Reaction PDE4 is not in Z
# 1345
# 1345
# check_model_function done ....
# Removed non-core inactive reactions
# PM reactions (after): 1344
# Num. removed: 1123 (39 core, 1084 non-core); Num. remaining: 12
# Reaction no.  1075
# Attempting to remove reaction:  B_MANNASEly ...
# Initial PM reactions: 1344
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 18 blocked (inactive) reactions
# Execution time of check_model_consistency:  9.521131000001333
# check_model_consistency done ...
# Lengths all--> inactive_G: 19 , inactive_C: ['GALASE1ly', 'ACNAMlt', 'SIAASEly', 'AHEXASE2ly', 'A_MANASEly', 'GASNASE2ly', 'AHEXASEly', 'FUCASEe', 'GASNASEly'], inactive_NC:['EX_n2m2nmasn_e', 'ENGASEly', 'ENGASE2ly', 'B_MANNASEly', 'MANtly', 'EX_s2l2fn2m2masn_e', 'GALtly', 'S2L2N2M2MASNtly', 'N2M2NMASNtly', 'DM_Asn_X_Ser_Thr_l']
# Reaction B_MANNASEly is not in Z
# 1344
# 1344
# check_model_function done ....
# No reactions removed
# Num. removed: 1123 (39 core, 1084 non-core); Num. remaining: 11
# Reaction no.  1076
# Attempting to remove reaction:  ORNt3m ...
# Initial PM reactions: 1344
# check_model_function done ....
# Num. removed: 1123 (39 core, 1084 non-core); Num. remaining: 10
# Reaction no.  1077
# Attempting to remove reaction:  ARGtm ...
# Initial PM reactions: 1344
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 15 blocked (inactive) reactions
# Execution time of check_model_consistency:  9.449526000000333
# check_model_consistency done ...
# Lengths all--> inactive_G: 16 , inactive_C: ['UREAt', 'CBPSam', 'LYSt4', 'ARGt4', 'ARGSL', 'ARGLYSex', 'ARGSS', 'LYSt5r', 'ARGNm', 'ARGt5r'], inactive_NC:['EX_arg__L_e', 'ORNt4m', 'ARGtm', 'EX_urea_e', 'OCBTm', 'UREAtm']
# Reaction ARGtm is not in Z
# 1344
# 1344
# check_model_function done ....
# No reactions removed
# Num. removed: 1123 (39 core, 1084 non-core); Num. remaining: 9
# Reaction no.  1078
# Attempting to remove reaction:  ORNt4m ...
# Initial PM reactions: 1344
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 4 blocked (inactive) reactions
# Execution time of check_model_consistency:  9.557860000000801
# check_model_consistency done ...
# Lengths all--> inactive_G: 5 , inactive_C: ['ARGSS', 'ARGSL', 'CBPSam'], inactive_NC:['ORNt4m', 'OCBTm']
# Reaction ORNt4m is not in Z
# 1344
# 1344
# check_model_function done ....
# No reactions removed
# Num. removed: 1123 (39 core, 1084 non-core); Num. remaining: 8
# Reaction no.  1079
# Attempting to remove reaction:  MTHFD2i ...
# Initial PM reactions: 1344
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  9.621827000000849
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['MTHFD2i']
# Reaction MTHFD2i is not in Z
# 1344
# 1344
# check_model_function done ....
# Removed non-core inactive reactions
# PM reactions (after): 1343
# Num. removed: 1124 (39 core, 1085 non-core); Num. remaining: 7
# Reaction no.  1080
# Attempting to remove reaction:  PIter ...
# Initial PM reactions: 1343
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 165 blocked (inactive) reactions
# Execution time of check_model_consistency:  9.491041999999652
# check_model_consistency done ...
# Lengths all--> inactive_G: 166 , inactive_C: ['IPDDIx', 'LNSTLSr', 'SQLEr', 'HMGCOARx', 'C3STDH1r', 'C4STMO2Pr', 'HMBS', 'ALASm', 'C4STMO2r', 'C4STMO1r', 'MEVK1x', 'UGCG', 'CERT1rt', 'FACOAL245_1', 'PPCDC', 'DHCR241r', 'UGT1A1r', 'CPPPGO', 'PNTK', 'RTOTAL2CRNt', 'SOAT11', 'C14STRr', 'RAI3', 'BILIRED', 'UGT1A5r2', 'DHCRD2', 'DPCOAK', 'LNS14DMr', 'UPP3S', 'LSTO2r', 'PMEVKx', 'CERT2rt', 'FACOAL260', 'DHCR72r', 'DHCR243r', 'RTOTAL2CRNCPT1', 'FACOAL244_1', 'GRTTx', 'FACOAL241', 'DMATTx', 'UDPGLCAter', 'PTPATi', 'RTOTALCRNt', 'DPMVDx', 'G6Pter', 'RTOTALCRNCPT1', 'RTOTAL2CRNCPT2', 'UGT1A5r', 'SOAT12', 'C3STDH1Pr', 'UDPDOLPT_U', 'PPPGOm', 'DHCR242r', 'UGT1A2r', 'SQLSr', 'FACOAL240', 'DHCR71r', 'GBA', 'UPPDC1', 'UGT1A6r', 'CERK', 'HMGCOAS', 'EBP1r', 'EBP2r', 'UDPDOLPT_L', 'LSTO1r', 'PPNCL3', 'HOXG', 'ESTRADIOLGLCt2', 'SBPP1er', 'RTOTALCRNCPT2'], inactive_NC:['RETNtr2', 'DOLPH_Ler', 'FADH2tru', 'G6PPer', 'NRVNCt', 'COAtp', 'DOLK_L', 'DOLGPP_Uer', 'ADPtx', 'SPHGNtr', 'EX_co_e', 'EX_pnto__R_e', 'NADPHtxu', 'EX_estrones_e', 'EX_nrvnc_e', 'ESTRONEGLCt', 'EX_bildglcur_e', 'PPBNGS', 'RETNGLCt2r', 'ARTFR56', 'PItx', 'ATPtx', 'CHSTEROLt3', 'ARTPLM2m', 'RETNtr', 'FADtru', 'PHEMEtm', 'EX_estroneglc_e', 'TETTET6t', 'ARTFR206', 'FORtr', 'DOLGLCP_Uter', 'DOLPH_Uer', 'PNTOt5', '5AOPtm', 'ARTFR45', 'CHSTEROLt2', 'EX_hexc_e', 'CO2ter', 'ESTRADIOLGLCtr', 'CRMPte', 'EX_lgnc_e', 'EX_tettet6_e', 'RTOT5', 'O2ter', 'TETPENT6t', 'HEXCt', 'BILDGLCURtr', 'DOLGLCP_Lter', 'LGNCt', 'ESTRONESt', 'PPPG9tm', 'ARTFR51', 'RTOT_2', 'EX_retn_e', 'RETNGLCt2', 'GLYtm', 'ARTFR13', 'PIter', 'COt', 'FRDPtr', 'FCLTm', 'GLCMter', 'EX_crmp_hs_e', 'DOLICHOL_Uter', 'PPAer', 'BILDGLCURte', 'BILIRUBtr', 'RETNGLCt', 'C3STKR2r', 'ARTFR54', 'ARTPLM1m', 'NDP7er', 'EX_tetpent6_e', 'XOLESTte', 'DOLGPP_Ler', 'EX_13_cis_retnglc_e', 'EX_retnglc_e', 'FE2tm', 'HMGCOAtx', 'NADPtxu', 'ESTRONEGLCtr', 'SPH1Pter', 'CO2tp', 'EX_estradiolglc_e', 'DOLK_U', 'DOLICHOL_Lter', 'UDPGLCter', 'SPH1Pte', 'EX_sph1p_e', 'RETNt', 'EX_xolest_hs_e', 'ARTFR52', 'RETNGLCtr', 'PPItx']
# Reaction PIter is not in Z
# 1343
# 1343
# check_model_function done ....
# No reactions removed
# Num. removed: 1124 (39 core, 1085 non-core); Num. remaining: 6
# Reaction no.  1081
# Attempting to remove reaction:  PHETHPTOX2 ...
# Initial PM reactions: 1343
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 2 blocked (inactive) reactions
# Execution time of check_model_consistency:  9.492996999999377
# check_model_consistency done ...
# Lengths all--> inactive_G: 3 , inactive_C: ['DHPR', 'THBPT4ACAMDASE'], inactive_NC:['PHETHPTOX2']
# Reaction PHETHPTOX2 is not in Z
# 1343
# 1343
# check_model_function done ....
# No reactions removed
# Num. removed: 1124 (39 core, 1085 non-core); Num. remaining: 5
# Reaction no.  1082
# Attempting to remove reaction:  PRO1xm ...
# Initial PM reactions: 1343
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 0 blocked (inactive) reactions
# Execution time of check_model_consistency:  9.606395000000703
# check_model_consistency done ...
# Lengths all--> inactive_G: 1 , inactive_C: [], inactive_NC:['PRO1xm']
# Reaction PRO1xm is not in Z
# 1343
# 1343
# check_model_function done ....
# Removed non-core inactive reactions
# PM reactions (after): 1342
# Num. removed: 1125 (39 core, 1086 non-core); Num. remaining: 4
# Reaction no.  1083
# Attempting to remove reaction:  PROD2m ...
# Initial PM reactions: 1342
# check_model_function done ....
# Num. removed: 1125 (39 core, 1086 non-core); Num. remaining: 3
# Reaction no.  1084
# Attempting to remove reaction:  PSDm_hs ...
# Initial PM reactions: 1342
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 25 blocked (inactive) reactions
# Execution time of check_model_consistency:  9.543845000000147
# check_model_consistency done ...
# Lengths all--> inactive_G: 26 , inactive_C: ['2HBt2', 'CYSTS', 'NDPK3m', 'PETOHMr_hs', '2HBO', 'PETOHMm_hs', 'CDSm', 'METS', 'CYTDtm', 'AHCi'], inactive_NC:['AMETr', 'CYSTGL', 'CYTDK2m', 'PE_HStm', 'PSDm_hs', 'EX_2hb_e', 'AHCYStr', 'CHLtm', 'CYTK1m', 'PSFLIPm', 'AMETt2m', 'PCHOL_HSter', 'CDPDAGtm', 'EX_met__L_e', 'PCHOLPm_hs', 'PE_HSter']
# Reaction PSDm_hs is not in Z
# 1342
# 1342
# check_model_function done ....
# No reactions removed
# Num. removed: 1125 (39 core, 1086 non-core); Num. remaining: 2
# Reaction no.  1085
# Attempting to remove reaction:  PPCOACm ...
# Initial PM reactions: 1342
# check_model_function done ....
# Checking all reactions (fastFVA)...
# Model consists of 23 blocked (inactive) reactions
# Execution time of check_model_consistency:  9.677850999998554
# check_model_consistency done ...
# Lengths all--> inactive_G: 24 , inactive_C: ['HPDCACRNt', 'FACOAL170', 'MMEm', 'ILETAm', 'PTDCACRNCPT1', 'HPDCACRNCPT1', 'FAOXC150m', 'HACD9m', 'ACOAD10m', 'HPDCACRNCPT2', 'PTDCACRNCPT2', 'PTDCACRNt', 'FAOXC170m', 'FACOAL150', 'OIVD3m', 'ECOAH9m'], inactive_NC:['ACACT10m', 'ILEtmi', 'EX_hpdca_e', 'EX_ile__L_e', 'PPCOACm', 'HPDCAt', 'PTDCAt', 'EX_ptdca_e']
# Reaction PPCOACm is not in Z
# 1342
# 1342
# check_model_function done ....
# No reactions removed
# Num. removed: 1125 (39 core, 1086 non-core); Num. remaining: 1
# Reaction no.  1086
# Attempting to remove reaction:  PIt2m ...
# Initial PM reactions: 1342
# check_model_function done ....
# Num. removed: 1125 (39 core, 1086 non-core); Num. remaining: 0
# prune_model done ....

# %%
len(PM.reactions)
# Out:
# 1342

# %%
len(PM.metabolites)
# Out:
# 1084

# %%
len(PM.genes)
# Out:
# 1041

# %%
pruneTime
# Out:
# 13623.831509

# %%
# cores and non-cores removed

# %%
from cobra import *
# write out PM model
io.write_sbml_model(PM,"python_recon1_BEC1_method1.xml")
